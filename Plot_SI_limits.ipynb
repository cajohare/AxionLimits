# %% [markdown]
# # SI Plots
# * Code to load in CYGNUS limit data for spin-independent WIMP-proton cross section
# * Also loads in neutrino floor for xenon and fluorine
# * Also loads in current limits (2018) on the cross section

# %% [markdown]
# ## First load in data

# %%
from numpy import *
import matplotlib.pyplot as plt
import matplotlib.cm as cm


fname = ["" for x in range(0,8)]
fname[0] ="Ideal"
fname[1] ="Pixel"
fname[2] ="Strip"
fname[3] ="Optical"
fname[4] ="Wire"
fname[5] ="Pad"
fname[6] ="Planar"
fname[7] ="Nondirectional"

# CYGNUS-1000
data_all = zeros(shape=(8,50))
data_all1 = zeros(shape=(8,50))

for i in range(0,8):
    data = loadtxt("../data/CYGNUS1000-"+fname[i]+".txt")
    m,F,He = data[0,:], data[1,:], data[2,:]
    He[He==0] = 1
    F[F==0] = 1 # set all zeros to large number so minimum() can find interpolate between He and F
    data_all[i,:] = minimum(He,F)

for i in [0,1,7]:
    data = loadtxt("../data/CYGNUS100k-"+fname[i]+".txt")
    m1,F,He = data[0,:], data[1,:], data[2,:]
    He[He==0] = 1
    F[F==0] = 1 # set all zeros to large number so minimum() can find interpolate between He and F
    data_all1[i,:] = minimum(He,F)
    
    
# 2018 Current limits
data = loadtxt("../data/SIlimits_2018.txt",delimiter=',')
mlim,slim = data[0,:],data[1,:]

# Xe and F neutrino floors
data = loadtxt("../data/nufloor_Xe.txt",delimiter=',')
m2,nu_Xe = data[0,:],data[1,:]
data = loadtxt("../data/nufloor_F.txt",delimiter=',')
m3,nu_F = data[0,:],data[1,:]

# %% [markdown]
# ## Then plot

# %%
# Plot
plt.rcParams['axes.linewidth'] = 2
fig = plt.figure(figsize=(8,7))
ax = fig.add_subplot(111)

col = cm.Dark2(linspace(0,1,8))


# Close-up range
#xmin = 0.5
#xmax = 1.0e2
#ymax = 1.0e-40
#ymin = 1.0e-47

# Full range
xmin = 0.1
xmax = 1.0e3
ymax = 1.0e-40
ymin = 1.0e-50

# Neutrino floor
plt.fill_between(m2, nu_Xe, y2=ymin,facecolor='Gray',alpha= 0.2)
plt.fill_between(m2, nu_F, y2=ymin,facecolor='Gray',alpha=0.5)

# Expt limits
plt.fill_between(mlim, slim, y2=ymax,facecolor='LightGray')
plt.loglog(mlim, slim,"-",linewidth=3,color='k')


lsty = ["" for x in range(0,8)]
lsty[0] ="--"
lsty[1] ="-"
lsty[2] ="-"
lsty[3] ="-"
lsty[4] ="-"
lsty[5] ="-"
lsty[6] ="-"
lsty[7] ="--"
# Plot lines
for i in [0,7]:
    plt.loglog(m,data_all[i,:],'-',color=col[i,:],linewidth=3,label=fname[i]+r" 1000 m$^3$"+r"$\times$ 3 yrs")
    plt.loglog(m1,data_all1[i,:],'--',color=col[i,:],linewidth=3,label=fname[i]+r" 100k m$^3$"+r"$\times$ 3 yrs")



# Labels
plt.legend(loc='upper right',fontsize=15,frameon=False)
plt.xlabel(r"$m_\chi$ [GeV]",fontsize=25)
plt.ylabel(r"$\sigma_p$ [cm$^2$]",fontsize=25)

# Limits
ax.set_xlim(left=xmin, right=xmax)
ax.set_ylim(bottom=ymin, top=ymax)


# Style
plt.rc('text', usetex=True)
plt.rc('font', family='serif')
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)