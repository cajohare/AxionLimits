# %% [markdown]
# # This notebook creates partially filled plots, intended for talks

# %%
# %matplotlib inline
from numpy import *
import matplotlib.pyplot as plt
from PlotFuncs import FigSetup, AxionPhoton, MySaveFig, BlackHoleSpins, FilledLimit


fig,ax = FigSetup(Shape='Rectangular',ylab='$|g_{a\gamma}|$ [GeV$^{-1}$]',mathpazo=True)

MySaveFig(fig,'AxionPhoton_Blank1')

# %%
fig,ax = FigSetup(Shape='Rectangular',ylab='$|g_{a\gamma}|$ [GeV$^{-1}$]',mathpazo=True)

AxionPhoton.QCDAxion(ax,C_center=abs(5/3-1.92)*(44/3-1.92)/2,C_width=0.7,vmax=1.1)

MySaveFig(fig,'AxionPhoton_Blank2')

# %%
fig,ax = FigSetup(Shape='Rectangular',ylab='$|g_{a\gamma}|$ [GeV$^{-1}$]',mathpazo=True)

AxionPhoton.QCDAxion(ax,C_center=abs(5/3-1.92)*(44/3-1.92)/2,C_width=0.7,vmax=1.1)
AxionPhoton.LSW(ax)
AxionPhoton.PVLAS(ax,text_col='w')
AxionPhoton.OSQAR(ax,text_col='w')
MySaveFig(fig,'AxionPhoton_Blank3')


AxionPhoton.ALPS(ax,projection=True,block=False)
MySaveFig(fig,'AxionPhoton_Blank3_alt')

# %%
fig,ax = FigSetup(Shape='Rectangular',ylab='$|g_{a\gamma}|$ [GeV$^{-1}$]',mathpazo=True)

AxionPhoton.QCDAxion(ax,C_center=abs(5/3-1.92)*(44/3-1.92)/2,C_width=0.7,vmax=1.1)
AxionPhoton.LSW(ax)
AxionPhoton.StellarBounds(ax)
AxionPhoton.SolarBasin(ax,text_col='k')
AxionPhoton.WhiteDwarfs(ax,text_col='#2ec763')

MySaveFig(fig,'AxionPhoton_Blank4')

# %%
fig,ax = FigSetup(Shape='Rectangular',ylab='$|g_{a\gamma}|$ [GeV$^{-1}$]',mathpazo=True)

AxionPhoton.QCDAxion(ax,C_center=abs(5/3-1.92)*(44/3-1.92)/2,C_width=0.7,vmax=1.1)
AxionPhoton.LSW(ax)
AxionPhoton.StellarBounds(ax)
AxionPhoton.SolarBasin(ax,text_col='k')
AxionPhoton.Helioscopes(ax)
AxionPhoton.WhiteDwarfs(ax,text_col='#2ec763')

MySaveFig(fig,'AxionPhoton_Blank5')

AxionPhoton.Helioscopes(ax,projection=True,text_on=False)
MySaveFig(fig,'AxionPhoton_Blank5_alt')

# %%
fig,ax = FigSetup(Shape='Rectangular',ylab='$|g_{a\gamma}|$ [GeV$^{-1}$]',mathpazo=True)

AxionPhoton.QCDAxion(ax,C_center=abs(5/3-1.92)*(44/3-1.92)/2,C_width=0.7,vmax=1.1)
AxionPhoton.LSW(ax)
AxionPhoton.StellarBounds(ax)
AxionPhoton.SolarBasin(ax,text_col='k')
AxionPhoton.Helioscopes(ax)
AxionPhoton.LowMassAstroBounds(ax)
AxionPhoton.WhiteDwarfs(ax,text_col='#2ec763')

MySaveFig(fig,'AxionPhoton_Blank6')

# %%
fig,ax = FigSetup(Shape='Rectangular',ylab='$|g_{a\gamma}|$ [GeV$^{-1}$]',mathpazo=True)

AxionPhoton.QCDAxion(ax,C_center=abs(5/3-1.92)*(44/3-1.92)/2,C_width=0.7,vmax=1.1)
AxionPhoton.LSW(ax)
AxionPhoton.Cosmology(ax)
AxionPhoton.StellarBounds(ax)
AxionPhoton.SolarBasin(ax)
AxionPhoton.Helioscopes(ax)
AxionPhoton.LowMassAstroBounds(ax)
AxionPhoton.WhiteDwarfs(ax,text_col='#2ec763')

MySaveFig(fig,'AxionPhoton_Blank7')

# %%
fig,ax = FigSetup(Shape='Rectangular',ylab='$|g_{a\gamma}|$ [GeV$^{-1}$]',mathpazo=True)

AxionPhoton.QCDAxion(ax,C_center=abs(5/3-1.92)*(44/3-1.92)/2,C_width=0.7,vmax=1.1)
AxionPhoton.LSW(ax)
AxionPhoton.Cosmology(ax)
AxionPhoton.StellarBounds(ax)
AxionPhoton.SolarBasin(ax)
AxionPhoton.Helioscopes(ax)
AxionPhoton.LowMassAstroBounds(ax)
AxionPhoton.ALPdecay(ax)

MySaveFig(fig,'AxionPhoton_Blank8')

# %%
fig,ax = FigSetup(Shape='Rectangular',ylab='$|g_{a\gamma}|$ [GeV$^{-1}$]',mathpazo=True)

AxionPhoton.QCDAxion(ax,C_center=abs(5/3-1.92)*(44/3-1.92)/2,C_width=0.7,vmax=1.1)
AxionPhoton.LSW(ax)
AxionPhoton.Cosmology(ax)
AxionPhoton.StellarBounds(ax)
AxionPhoton.SolarBasin(ax)
AxionPhoton.Helioscopes(ax)
AxionPhoton.Haloscopes(ax)
AxionPhoton.LowMassAstroBounds(ax)
AxionPhoton.ALPdecay(ax)

MySaveFig(fig,'AxionPhoton_Blank9')

# %%
fig,ax = FigSetup(Shape='Rectangular',ylab='$|g_{a\gamma}|$ [GeV$^{-1}$]',mathpazo=True)

AxionPhoton.QCDAxion(ax,C_center=abs(5/3-1.92)*(44/3-1.92)/2,C_width=0.7,vmax=1.1)
AxionPhoton.LSW(ax)
AxionPhoton.Cosmology(ax)
AxionPhoton.StellarBounds(ax)
AxionPhoton.SolarBasin(ax)
AxionPhoton.Helioscopes(ax)
AxionPhoton.Haloscopes(ax)
AxionPhoton.LowMassAstroBounds(ax)
AxionPhoton.ALPdecay(ax)
AxionPhoton.NeutronStars(ax)
AxionPhoton.AxionStarExplosions(ax)

MySaveFig(fig,'AxionPhoton_Blank10')

# %%
fig,ax = FigSetup(Shape='Rectangular',ylab='$|g_{a\gamma}|$ [GeV$^{-1}$]',mathpazo=True)

AxionPhoton.QCDAxion(ax,C_center=abs(5/3-1.92)*(44/3-1.92)/2,C_width=0.7,vmax=1.1)
AxionPhoton.Cosmology(ax)
AxionPhoton.StellarBounds(ax)
AxionPhoton.SolarBasin(ax)
AxionPhoton.Haloscopes(ax)
AxionPhoton.Helioscopes(ax)
AxionPhoton.LSW(ax)
AxionPhoton.LowMassAstroBounds(ax)
AxionPhoton.ALPdecay(ax)
AxionPhoton.NeutronStars(ax)
BlackHoleSpins(ax,(1/137)*(1/(2*pi)),[2.1e-12,1.5e-17],rotation=-90,alpha=0.3)

MySaveFig(fig,'AxionPhoton_Blank11')
