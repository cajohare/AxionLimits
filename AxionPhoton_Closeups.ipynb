# %% [markdown]
# # Closeup on future helioscopes

# %%
# %matplotlib inline
from numpy import *
import matplotlib.pyplot as plt
from PlotFuncs import BlackHoleSpins, AxionPhoton, MySaveFig, UpperFrequencyAxis,col_alpha,FigSetup

fig,ax = FigSetup(Shape='Rectangular',ylab='$|g_{a\gamma\gamma}|$ [GeV$^{-1}$]',mathpazo=True,\
                 m_min=1e-6,m_max=3e-4,g_min=2e-16,g_max=1e-9,tfs=30,xtick_rotation=0,FrequencyAxis=True,N_Hz=1e6,upper_xlabel=r"Frequency [MHz]",xlabel_pad=20)

y2 = 1e-9

ADMX_col = 'crimson'


# CAST
AxionPhoton.Helioscopes(ax,projection=False,text_on=False)
plt.gcf().text(0.2*(1-0.005),0.805*(1+0.005),r'{\bf CAST}',color='k',fontsize=40,rotation=0,rotation_mode='anchor',ha='center',va='center')
plt.gcf().text(0.2,0.805,r'{\bf CAST}',color=col_alpha(ADMX_col,0.0),fontsize=40,rotation=0,rotation_mode='anchor',ha='center',va='center')

# QCD axion
AxionPhoton.QCDAxion(ax,text_on=False,C_center=abs(5/3-1.92)*(44/3-1.92)/2,C_width=0.7)
def g_x(C_ag,m_a):
        return 2e-10*C_ag*m_a
mvals = array([1e-6,3e-4])
plt.plot(mvals,g_x(44/3-1.95,mvals),'--',lw=3,color='brown',zorder=0.0,alpha=0.2)
plt.plot(mvals,g_x(abs(5/3-1.92),mvals),'--',lw=3,color='brown',zorder=0.1,alpha=0.2)
plt.gcf().text(0.89,0.53,r'$E/N = 44/3$',fontsize=20,color='brown',rotation=13,rotation_mode='anchor',ha='right',alpha=0.9)
plt.gcf().text(0.89,0.305,r'$E/N = 5/3$',fontsize=20,color='brown',rotation=13,rotation_mode='anchor',ha='right',alpha=0.9)
plt.gcf().text(0.89,0.438,r'KSVZ',fontsize=20,color='darkred',rotation=13,rotation_mode='anchor',ha='right',alpha=1)
plt.gcf().text(0.89,0.36,r'DFSZ',fontsize=20,color='darkred',rotation=13,rotation_mode='anchor',ha='right',alpha=1)



# RBF/UF
UF_col = [0.8,0,0]
RBF_col = 'Darkred'
dat = loadtxt("limit_data/AxionPhoton/RBF_UF_Haloscopes.txt")
plt.fill_between(dat[:,0],dat[:,1],y2=y2,edgecolor='k',facecolor='darkred',zorder=0.1)
dat = loadtxt("limit_data/AxionPhoton/UF.txt")
plt.fill_between(dat[:,0],dat[:,1],y2=y2,edgecolor='k',facecolor=[0.8,0,0],zorder=0.1)
plt.gcf().text(0.36*(1-0.003),0.32*(1+0.003),r'{\bf UF}',color='k',fontsize=30,rotation=0,rotation_mode='anchor',ha='center',va='center')
plt.gcf().text(0.36,0.32,r'{\bf UF}',color=col_alpha(UF_col,1),fontsize=30,rotation=0,rotation_mode='anchor',ha='center',va='center')
plt.gcf().text(0.413*(1-0.003),0.55*(1+0.003),r'{\bf RBF}',color='k',fontsize=30,rotation=0,rotation_mode='anchor',ha='center',va='center')
plt.gcf().text(0.413,0.55,r'{\bf RBF}',color=col_alpha(RBF_col,0.1),fontsize=30,rotation=0,rotation_mode='anchor',ha='center',va='center')


# ADMX
dat = loadtxt("limit_data/AxionPhoton/ADMX.txt")
plt.fill_between(dat[:,0],dat[:,1],y2=y2,edgecolor='k',facecolor=ADMX_col,zorder=0.1)
dat = loadtxt("limit_data/AxionPhoton/ADMX2018.txt")
plt.fill_between(dat[:,0],dat[:,1],y2=y2,edgecolor='k',facecolor=ADMX_col,zorder=0.1)
dat = loadtxt("limit_data/AxionPhoton/ADMX2019_1.txt")
plt.fill_between(dat[:,0],dat[:,1],y2=y2,edgecolor='k',facecolor=ADMX_col,zorder=0.1)
dat = loadtxt("limit_data/AxionPhoton/ADMX2019_2.txt")
plt.fill_between(dat[:,0],dat[:,1],y2=y2,edgecolor='k',facecolor=ADMX_col,zorder=0.1)
dat = loadtxt("limit_data/AxionPhoton/ADMX2021.txt")
plt.fill_between(dat[:,0],dat[:,1],y2=y2,edgecolor='k',facecolor=ADMX_col,zorder=0.1)
plt.gcf().text(0.24*(1-0.005),0.4*(1+0.005),r'{\bf ADMX}',color='k',fontsize=35,rotation=90,rotation_mode='anchor',ha='center',va='center')
plt.gcf().text(0.24,0.4,r'{\bf ADMX}',color=col_alpha(ADMX_col,0.2),fontsize=35,rotation=90,rotation_mode='anchor',ha='center',va='center')

# HAYSTAC
HAYSTAC_col = 'orangered'
dat = loadtxt("limit_data/AxionPhoton/HAYSTAC_highres.txt")
dat2 = loadtxt("limit_data/AxionPhoton/HAYSTAC_2020_highres.txt")
plt.fill_between(dat[:,0],dat[:,1],y2=y2,edgecolor='k',facecolor=HAYSTAC_col,zorder=0.1)
plt.fill_between(dat2[:,0],dat2[:,1],y2=y2,edgecolor='k',facecolor=HAYSTAC_col,zorder=0.1)
plt.gcf().text(0.505,0.357,r'{\bf HAYSTAC}',color=col_alpha(HAYSTAC_col,1),fontsize=17,rotation=90,rotation_mode='anchor',ha='center',va='center')
plt.gcf().text(0.546,0.42,r'{\bf HAYSTAC}',color=col_alpha(HAYSTAC_col,1),fontsize=17,rotation=90,rotation_mode='anchor',ha='center',va='center')


# CAPP
CAPP_col = [1, 0.1, 0.37]
dat1 = loadtxt("limit_data/AxionPhoton/CAPP-1.txt")
dat2 = loadtxt("limit_data/AxionPhoton/CAPP-2.txt")
dat3 = loadtxt("limit_data/AxionPhoton/CAPP-3.txt")
plt.fill_between(dat1[:,0],dat1[:,1],y2=y2,edgecolor='k',facecolor=CAPP_col,zorder=0.1)
plt.fill_between(dat2[:,0],dat2[:,1],y2=y2,edgecolor='k',facecolor=CAPP_col,zorder=0.1)
plt.fill_between(dat3[:,0],dat3[:,1],y2=y2,edgecolor='k',facecolor=CAPP_col,zorder=0.1)
plt.gcf().text(0.44,0.31,r'{\bf CAPP}',color=col_alpha(CAPP_col,1),fontsize=20,rotation=90,rotation_mode='anchor',ha='center',va='center')
plt.gcf().text(0.49,0.45,r'{\bf CAPP}',color=col_alpha(CAPP_col,1),fontsize=15,rotation=-90,rotation_mode='anchor',ha='center',va='center')
plt.gcf().text(0.393,0.35,r'{\bf CAPP}',color=col_alpha(CAPP_col,1),fontsize=15,rotation=-90,rotation_mode='anchor',ha='center',va='center')

# ORGAN
ORGAN_col = [0.7,0.2,0.05]
AxionPhoton.ORGAN(ax,text_on=False,col=ORGAN_col)
plt.gcf().text(0.755,0.615,r'{\bf ORGAN}',color=col_alpha(ORGAN_col,1),fontsize=20,rotation=90,rotation_mode='anchor',ha='center',va='center')

# GrAHal
GrAHal_col = '#b53e5a'
AxionPhoton.GrAHal(ax,text_on=False,col=GrAHal_col)
plt.gcf().text(0.575,0.51,r'{\bf GrAHal}',color=col_alpha(GrAHal_col,1),fontsize=15,rotation=-90,rotation_mode='anchor',ha='center',va='center')


# ADMX Sidecar
dat = loadtxt("limit_data/AxionPhoton/ADMX_Sidecar.txt")
plt.fill_between(dat[:,0],dat[:,1],y2=y2,edgecolor='k',facecolor=ADMX_col,zorder=0.1)
dat = loadtxt("limit_data/AxionPhoton/ADMX_Sidecar_JTWPA.txt")
plt.fill_between(dat[:,0],dat[:,1],y2=y2,edgecolor='k',facecolor=ADMX_col,zorder=0.1)
plt.gcf().text(0.545,0.54,r'{\bf ADMX}',color=ADMX_col,fontsize=20,rotation=90,rotation_mode='anchor',ha='center',va='center')


# QUAX
QUAX_col = [0.6,0.1,0.3]
dat = loadtxt("limit_data/AxionPhoton/QUAX.txt")
dat2 = loadtxt("limit_data/AxionPhoton/QUAX2.txt")
plt.plot([dat[0,0],dat[0,0]],[dat[0,1],y2],color=QUAX_col,lw=2,zorder=0.05)
plt.plot([dat2[0,0],dat2[0,0]],[dat2[0,1],y2],color=QUAX_col,lw=2,zorder=0.05)
plt.gcf().text(0.627,0.479,r'{\bf QUAX}-$a\gamma$',color=col_alpha(QUAX_col,1),fontsize=20,rotation=90,rotation_mode='anchor',ha='center',va='center')


# RADES
RADES_col = [0.95,0.1,0.1]
dat = loadtxt("limit_data/AxionPhoton/RADES.txt")
plt.plot([dat[0,0],dat[0,0]],[dat[0,1],y2],color=RADES_col,lw=2,zorder=0.05)
plt.gcf().text(0.602,0.53,r'{\bf RADES}',color=col_alpha(RADES_col,1),fontsize=15,rotation=90,rotation_mode='anchor',ha='center',va='center')


# Neutron stars
# dat = loadtxt('limit_data/AxionPhoton/NeutronStars_GreenBank.txt')
# plt.fill_between(dat[:,0],dat[:,1],y2=y2,edgecolor='k',facecolor='ForestGreen',zorder=0.11)
# dat = loadtxt('limit_data/AxionPhoton/NeutronStars_VLA.txt')
# plt.fill_between(dat[:,0],dat[:,1],y2=y2,edgecolor='k',facecolor='SeaGreen',zorder=0.11)
# dat = loadtxt('limit_data/AxionPhoton/NeutronStars_Battye.txt') 
# plt.plot(dat[:,0],dat[:,1],color='k',lw=1,zorder=0.2)
# plt.fill_between(dat[:,0],dat[:,1],y2=1e0,zorder=0.2,color='#4ad46a')
# plt.gcf().text(0.53*(1-0.005),0.81*(1+0.005),r'{\bf Neutron Stars}',color='k',fontsize=30,rotation=0,rotation_mode='anchor',ha='center',va='center')
# plt.gcf().text(0.53,0.81,r'{\bf Neutron Stars}',color=col_alpha('Green',0.4),fontsize=30,rotation=0,rotation_mode='anchor',ha='center',va='center')
# plt.gcf().text(0.41*(1-0.001),0.76*(1+0.001),r'{\bf Foster et al.}',color='k',fontsize=25,rotation=0,rotation_mode='anchor',ha='center',va='center',multialignment='center')
# plt.gcf().text(0.41,0.76,r'Foster et al.',color=col_alpha('ForestGreen',0.7),fontsize=25,rotation=0,rotation_mode='anchor',ha='center',va='center',multialignment='center')
# plt.gcf().text(0.52*(1-0.001),0.76*(1+0.001),r'{\bf Darling}',color='k',fontsize=25,rotation=0,rotation_mode='anchor',ha='center',va='center',multialignment='center')
# plt.gcf().text(0.52,0.76,r'Darling',color=col_alpha('SeaGreen',0.7),fontsize=25,rotation=0,rotation_mode='anchor',ha='center',va='center',multialignment='center')
# plt.gcf().text(0.65*(1-0.001),0.76*(1+0.001),r'{\bf Battye et al.}',color='k',fontsize=25,rotation=0,rotation_mode='anchor',ha='center',va='center',multialignment='center')
# plt.gcf().text(0.65,0.76,r'Battye et al.',color=col_alpha('#20c742',0.7),fontsize=25,rotation=0,rotation_mode='anchor',ha='center',va='center',multialignment='center')

plt.title('0',color='w',pad=10)
#plt.gcf().text(0.89,0.15,r'$\rho_0 = 0.45$ GeV cm$^{-3}$',fontsize=30,ha='right')

MySaveFig(fig,'AxionPhoton_RadioFreqCloseup_noNS')

plt.gcf().text(0.55*(1-0.002),0.76*(1+0.002),r'{\bf Neutron Stars}',color='k',fontsize=20,rotation=0,rotation_mode='anchor',ha='center',va='center')
plt.gcf().text(0.55,0.76,r'{\bf Neutron Stars}',color=col_alpha('ForestGreen',0.4),fontsize=20,rotation=0,rotation_mode='anchor',ha='center',va='center')
dat = loadtxt('limit_data/AxionPhoton/NeutronStars_BreakthroughListen.txt')
plt.fill_between(dat[:,0],dat[:,1],y2=y2,edgecolor='k',facecolor='ForestGreen',zorder=0.11)








MySaveFig(fig,'AxionPhoton_RadioFreqCloseup')

# %%
# %matplotlib inline
from numpy import *
import matplotlib.pyplot as plt
from PlotFuncs import BlackHoleSpins, AxionPhoton, MySaveFig, col_alpha, FigSetup
import matplotlib.patheffects as pe
fig,ax = FigSetup(Shape='Rectangular',ylab='$|g_{a\gamma}|$ [GeV$^{-1}$]',mathpazo=True,xtick_rotation=0,tfs=30)

AxionPhoton.Helioscopes(ax,projection=False,text_on=False)

ax.set_ylim([1e-12,1e-9])
ax.set_xlim([1e-10,1e1])
y2 = ax.get_ylim()[1]

zo=0.01
IAXO_col = 'Navy'
IAXO = loadtxt("limit_data/AxionPhoton/Projections/babyIAXO.txt")
plt.plot(IAXO[:,0],IAXO[:,1],'--',linewidth=2,color=IAXO_col,zorder=0)
plt.fill_between(IAXO[:,0],IAXO[:,1],y2=y2,edgecolor=None,facecolor=IAXO_col,zorder=zo,alpha=0.1)

IAXO = loadtxt("limit_data/AxionPhoton/Projections/IAXO.txt")
plt.plot(IAXO[:,0],IAXO[:,1],'--',linewidth=3,color=IAXO_col,zorder=zo)
plt.fill_between(IAXO[:,0],IAXO[:,1],y2=y2,edgecolor=None,facecolor=IAXO_col,zorder=zo,alpha=0.1)

IAXO = loadtxt("limit_data/AxionPhoton/Projections/IAXO_plus.txt")
plt.plot(IAXO[:,0],IAXO[:,1],'--',linewidth=2,color=IAXO_col,zorder=zo)
plt.fill_between(IAXO[:,0],IAXO[:,1],y2=y2,edgecolor=None,facecolor=IAXO_col,zorder=zo,alpha=0.1)

IAXO = loadtxt("limit_data/AxionPhoton/Projections/IAXO_plus_SN_Spica1.txt")
plt.plot(IAXO[:,0],IAXO[:,1],':',linewidth=3,color=IAXO_col,zorder=zo)
plt.fill_between(IAXO[:,0],IAXO[:,1],y2=y2,edgecolor=None,facecolor=IAXO_col,zorder=zo,alpha=0.1)


AxionPhoton.ALPS(ax,projection=True,text_on=False,lsty_proj='--',lw_proj=3,col_proj='k',block=True)

ADMX_col = 'darkred'
AxionPhoton.ADMX(ax,text_on=False,col=ADMX_col)
AxionPhoton.RBF_UF(ax,text_on=False,col='darkred')
AxionPhoton.HAYSTAC(ax,text_on=False,col='darkred')
AxionPhoton.ABRACADABRA(ax,text_on=False)
AxionPhoton.SHAFT(ax,text_on=False)
AxionPhoton.CAPP(ax,text_on=False,col='darkred')
AxionPhoton.ORGAN(ax,text_on=False,col='darkred')
AxionPhoton.QUAX(ax,text_on=False,col='darkred')
AxionPhoton.Mrk421(ax,text_on=False,col='SeaGreen',lw=1)
AxionPhoton.NGC1275(ax,text_on=False,col='SeaGreen',lw=1)
AxionPhoton.HESS(ax,text_on=False,col='SeaGreen',lw=1)
AxionPhoton.StarClusters(ax,text_on=False,col='SeaGreen',lw=1)
AxionPhoton.SN1987A_gamma(ax,text_on=False,col='SeaGreen',lw=1)
AxionPhoton.Fermi(ax,text_on=False,col='SeaGreen',lw=1)
AxionPhoton.MUSE(ax,col='seagreen',text_on=False,lw=1)
AxionPhoton.VIMOS(ax,col='seagreen',text_on=False,lw=1)
AxionPhoton.MWDPolarisation(ax,col='seagreen',text_on=False,lw=1)
AxionPhoton.MWDXrays(ax,col='seagreen',text_on=False,lw=1)
AxionPhoton.HAWC(ax,col='seagreen',text_on=False,lw=1)
AxionPhoton.ALPdecay(ax,projection=False,text_on=False)
AxionPhoton.QCDAxion(ax,text_on=False)
AxionPhoton.StellarBounds(ax,text_on=False)
AxionPhoton.NeutronStars(ax,text_on=False,col='#329c7e')


plt.gcf().text(0.4*(1-0.005),0.72*(1+0.005),r'{\bf CAST}',color='k',fontsize=40,rotation=0,rotation_mode='anchor',ha='center',va='center')
plt.gcf().text(0.4,0.72,r'{\bf CAST}',color=col_alpha(ADMX_col,0.0),fontsize=40,rotation=0,rotation_mode='anchor',ha='center',va='center')


plt.gcf().text(0.81*(1-0.002),0.595*(1+0.002),r'{\bf Horizontal Branch}',color='k',fontsize=24,rotation=0,rotation_mode='anchor',ha='center',va='center')
plt.gcf().text(0.81,0.595,r'{\bf Horizontal Branch}',color='w',fontsize=24,rotation=0,rotation_mode='anchor',ha='center',va='center')

plt.gcf().text(0.50*(1-0.002),0.595*(1+0.002),r'{\bf Neutron Stars}',color='k',fontsize=25,rotation=0,rotation_mode='anchor',ha='center',va='center')
plt.gcf().text(0.50,0.595,r'{\bf Neutron Stars}',color='#329c7e',fontsize=25,rotation=0,rotation_mode='anchor',ha='center',va='center')


plt.gcf().text(0.21*(1-0.001),0.75*(1+0.001),r'{\bf ABRA}',color='k',fontsize=30,rotation=0,rotation_mode='anchor',ha='center',va='center')
plt.gcf().text(0.21,0.75,r'{\bf ABRA}',color='w',fontsize=30,rotation=0,rotation_mode='anchor',ha='center',va='center')
plt.gcf().text(0.21,0.71,r'10 cm',color='w',fontsize=30,rotation=0,rotation_mode='anchor',ha='center',va='center')

plt.gcf().text(0.162*(1-0.002),0.61*(1+0.002),r'{\bf SHAFT}',color='k',fontsize=23,rotation=27,rotation_mode='anchor',ha='center',va='center')
plt.gcf().text(0.162,0.61,r'{\bf SHAFT}',color='w',fontsize=23,rotation=27,rotation_mode='anchor',ha='center',va='center')

ya = 0.44
xa = 0.33
plt.gcf().text(xa*(1-0.004),ya*(1+0.004),r'{\bf High}',color='k',fontsize=38,rotation=0,rotation_mode='anchor',ha='center',va='center')
plt.gcf().text(xa*(1-0.005),(ya-0.05)*(1+0.005),r'{\bf energy}',color='k',fontsize=38,rotation=0,rotation_mode='anchor',ha='center',va='center')
plt.gcf().text(xa*(1-0.005),(ya-0.1)*(1+0.005),r'{\bf astro}',color='k',fontsize=38,rotation=0,rotation_mode='anchor',ha='center',va='center')
plt.gcf().text(xa,ya,r'{\bf High}',color=col_alpha('Seagreen',0.2),fontsize=38,rotation=0,rotation_mode='anchor',ha='center',va='center')
plt.gcf().text(xa,ya-0.05,r'{\bf energy}',color=col_alpha('Seagreen',0.2),fontsize=38,rotation=0,rotation_mode='anchor',ha='center',va='center')
plt.gcf().text(xa,ya-0.1,r'{\bf astro}',color=col_alpha('Seagreen',0.2),fontsize=38,rotation=0,rotation_mode='anchor',ha='center',va='center')


plt.gcf().text(0.60,0.52,r'{\bf ALPS-II}',color='k',fontsize=24,rotation=0,rotation_mode='anchor',ha='center',va='center')
plt.gcf().text(0.605,0.4,r'{\bf babyIAXO}',color=IAXO_col,fontsize=24,rotation=0,rotation_mode='anchor',ha='center',va='center')
plt.gcf().text(0.6,0.3,r'{\bf IAXO}',color=IAXO_col,fontsize=28,rotation=0,rotation_mode='anchor',ha='center',va='center')
plt.gcf().text(0.6,0.21,r'{\bf IAXO+}',color=IAXO_col,fontsize=24,rotation=0,rotation_mode='anchor',ha='center',va='center')
plt.gcf().text(0.78,0.25,r'{\bf IAXO} (SN)',color=IAXO_col,fontsize=20,rotation=0,rotation_mode='anchor',ha='center',va='center')

plt.gcf().text(0.848,0.13,r'{\bf Telescopes}',color=col_alpha('Green',1),fontsize=25,rotation=90,rotation_mode='anchor',ha='left',va='center')

plt.gcf().text(0.64,0.13,r'KSVZ',color='#572006',fontsize=21,rotation=67,rotation_mode='anchor',ha='left',va='center')
plt.gcf().text(0.695,0.13,r'DFSZ-II',color='#572006',fontsize=21,rotation=67,rotation_mode='anchor',ha='left',va='center')

MySaveFig(fig,'AxionPhoton_IAXOCloseup')

# %% [markdown]
# # High energy astrophysics bounds close-up

# %%
# %matplotlib inline
from numpy import *
import matplotlib.pyplot as plt
from PlotFuncs import BlackHoleSpins, AxionPhoton, MySaveFig, col_alpha, FigSetup
import matplotlib.patheffects as pe
pek=[pe.Stroke(linewidth=5, foreground='k',alpha=1), pe.Normal()]


fig,ax = FigSetup(Shape='Rectangular',ylab='$|g_{a\gamma\gamma}|$ [GeV$^{-1}$]',mathpazo=True,xtick_rotation=0,tfs=30,\
                 m_min=1e-14,m_max=1e-5,g_min=2e-14,g_max=1e-9)
y2 = ax.get_ylim()[1]


AxionPhoton.Helioscopes(ax,projection=False,text_on=False)
AxionPhoton.LowMassAstroBounds(ax,projection=False,text_on=False,lw=1.5)
AxionPhoton.ALPdecay(ax,projection=False,text_on=False) 
    
    
# Experiments
plt.gcf().text(0.25*(1-0.003),0.81*(1+0.003),r'{\bf CAST}',color='k',fontsize=41,rotation=0,rotation_mode='anchor',ha='center',va='center')
plt.gcf().text(0.25,0.81,r'{\bf CAST}',color='w',fontsize=41,rotation=0,rotation_mode='anchor',ha='center',va='center')

# DSNALP
plt.gcf().text(0.15*(1-0.003),0.74*(1+0.003),r'{\bf Diffuse SN}',color='k',fontsize=27,rotation=0,rotation_mode='anchor',ha='left',va='center')
plt.gcf().text(0.15,0.74,r'{\bf Diffuse SN}',color='w',fontsize=27,rotation=0,rotation_mode='anchor',ha='left',va='center')
plt.plot([0.7e-13,1e-13],[1e-10,5.5e-11],'-',lw=2,color='w',path_effects=pek)
plt.plot(1e-13,5.5e-11,'ko',lw=3,markersize=10,mfc='w',mew=1.5)


# Fermi SN
plt.gcf().text(0.135*(1-0.001),0.64*(1+0.001),r'{\bf Fermi SNe}-$\gamma$',color='k',fontsize=25,rotation=0,rotation_mode='anchor',ha='left',va='center')
plt.gcf().text(0.135,0.64,r'{\bf Fermi SNe}-$\gamma$',color='w',fontsize=25,rotation=0,rotation_mode='anchor',ha='left',va='center')

# Hydra A
plt.gcf().text(0.135*(1-0.001),0.57*(1+0.001),r'{\bf Hydra-A}',color='k',fontsize=28,rotation=0,rotation_mode='anchor',ha='left',va='center')
plt.gcf().text(0.135,0.57,r'{\bf Hydra-A}',color='w',fontsize=28,rotation=0,rotation_mode='anchor',ha='left',va='center')

# Super star cluster
plt.gcf().text(0.135*(1-0.001),0.515*(1+0.001),r'{\bf Super star clusters}',color='k',fontsize=27,rotation=0,rotation_mode='anchor',ha='left',va='center')
plt.gcf().text(0.135,0.515,r'{\bf Super star clusters}',color='w',fontsize=27,rotation=0,rotation_mode='anchor',ha='left',va='center')

# M87
plt.gcf().text(0.135*(1-0.001),0.45*(1+0.001),r'{\bf M87}',color='k',fontsize=29,rotation=0,rotation_mode='anchor',ha='left',va='center')
plt.gcf().text(0.135,0.45,r'{\bf M87}',color='w',fontsize=29,rotation=0,rotation_mode='anchor',ha='left',va='center')

# Chandra
plt.gcf().text(0.135*(1-0.001),0.4*(1+0.001),r'{\bf NGC1275} (Chandra)',color='k',fontsize=25,rotation=0,rotation_mode='anchor',ha='left',va='center')
plt.gcf().text(0.135,0.4,r'{\bf NGC1275} (Chandra)',color='w',fontsize=25,rotation=0,rotation_mode='anchor',ha='left',va='center')

# Distance ladder
dat = loadtxt("limit_data/AxionPhoton/Projections/SN_distances.txt")
#plt.fill_between(dat[:,0],dat[:,1],y2=y2,edgecolor=None,facecolor='green',zorder=0.09)
plt.plot(dat[:,0],dat[:,1],'g--',lw=1.5,zorder=0.091,alpha=0.7,color='darkgreen')
plt.text(0.13e-13,3.5e-13,r'{\bf SN distance ladder}',color='darkgreen',alpha=0.7,fontsize=23,rotation=0,rotation_mode='anchor',ha='left',va='center')
#plt.plot([1.5e-13,2e-13],[2e-13,6e-13],'k-',lw=3,color='green',path_effects=pek)
#plt.plot(2e-13,6e-13,'ko',lw=3,markersize=10,mfc='green',mew=1.5)


# Fermi galactic SN
dat = loadtxt("limit_data/AxionPhoton/Projections/FermiSN.txt")
plt.plot(dat[:,0],dat[:,1],'--',color='darkgreen',lw=1.5,zorder=-0.01,alpha=0.7)
plt.text(0.13e-13,1.4e-13,r'{\bf Fermi (Galactic SN)}',color='darkgreen',alpha=0.7,fontsize=23,rotation=0,zorder=0.0,rotation_mode='anchor',ha='left',va='center')


# SN1987
plt.text(0.24e-10,2e-12,r'{\bf SN1987A}-$\gamma$',color=[0.05, 0.5, 0.06],fontsize=23,rotation=0,rotation_mode='anchor',ha='left',va='center')
plt.plot([1.5e-10,2e-10],[3e-12,1e-11],'-',lw=2,color=[0.05, 0.5, 0.06],path_effects=pek)
plt.plot(2e-10,1e-11,'ko',lw=3,markersize=10,mfc=[0.05, 0.5, 0.06],mew=1.5)

# Fermi
plt.gcf().text(0.592*(1-0.001),0.56*(1+0.001),r'{\bf NGC1275}',color='k',fontsize=21,rotation=0,rotation_mode='anchor',ha='center',va='center')
plt.gcf().text(0.592,0.56,r'{\bf NGC1275}',color='w',fontsize=21,rotation=0,rotation_mode='anchor',ha='center',va='center')
plt.gcf().text(0.592,0.534,r'(Fermi)',color='w',fontsize=21,rotation=0,rotation_mode='anchor',ha='center',va='center')

# Mrk 421
plt.gcf().text(0.61*(1-0.002),0.66*(1+0.002),r'{\bf Mrk 421}',color='k',fontsize=25,rotation=0,rotation_mode='anchor',ha='center',va='center')
plt.gcf().text(0.61,0.66,r'{\bf Mrk 421}',color='w',fontsize=25,rotation=0,rotation_mode='anchor',ha='center',va='center')

# HESS
plt.text(3.4e-8,1.6e-11,r'{\bf PKS}',color='#2a5736',fontsize=19,rotation=0,rotation_mode='anchor',ha='center',va='center')
plt.text(3.4e-8,1.6e-11/1.4,r'{\bf 2155-304}',color='#2a5736',fontsize=19,rotation=0,rotation_mode='anchor',ha='center',va='center')
plt.text(3.4e-8,1.6e-11/1.4**2,r'{\bf (HESS)}',color='#2a5736',fontsize=19,rotation=0,rotation_mode='anchor',ha='center',va='center')

# MWD X-rays
plt.text(1.7e-6*(1-0.02),1.5e-10*(1+0.02),r'{\bf MWD X-rays}',color='k',fontsize=25,rotation=0,rotation_mode='anchor',ha='center',va='center')
plt.text(1.7e-6,1.5e-10,r'{\bf MWD X-rays}',color='w',fontsize=25,rotation=0,rotation_mode='anchor',ha='center',va='center')
plt.plot([1.5e-6,2e-6],[5.5e-11,1.15e-10],'-',lw=2,color='w',path_effects=pek)
plt.plot(1.5e-6,5.5e-11,'ko',lw=3,markersize=10,mfc='w',mew=1.5)

# HAWC
plt.text(2.5e-7,2.3e-11,r'{\bf TeV blazars}',color='#2b5e4e',fontsize=19.5,rotation=0,rotation_mode='anchor',ha='center',va='center')
plt.text(2.5e-7,1.6e-11,r'{\bf (HAWC)}',color='#2b5e4e',fontsize=19.5,rotation=0,rotation_mode='anchor',ha='center',va='center')

# MWD Pol.
plt.text(5.9e-7,0.2e-11,r'{\bf MWD}',color='#32a852',fontsize=23,rotation=0,rotation_mode='anchor',ha='center',va='center')
plt.text(5.9e-7,0.13e-11,r'{\bf Polarisation}',color='#32a852',fontsize=18,rotation=0,rotation_mode='anchor',ha='center',va='center')
plt.plot([2.4e-7,4e-7],[0.9e-11,0.3e-11],'-',lw=2,color='#32a852',path_effects=pek)
plt.plot(2.4e-7,0.9e-11,'ko',lw=3,markersize=10,mfc='#32a852',mew=1.5)

# Betelgeuse
dat = loadtxt('limit_data/AxionPhoton/Betelgeuse.txt')
plt.plot(dat[:,0],dat[:,1],'k-',zorder=0.235,lw=1.5)
plt.fill_between(dat[:,0],dat[:,1],y2=1e0,color='seagreen',zorder=0.235)
plt.gcf().text(0.135*(1-0.002),0.613*(1+0.002),r'{\bf Betelgeuse}',color='k',fontsize=20,rotation=0,rotation_mode='anchor',ha='left',va='center')
plt.gcf().text(0.135,0.613,r'{\bf Betelgeuse}',color='w',fontsize=20,rotation=0,rotation_mode='anchor',ha='left',va='center')


# ALP dark matter
plt.arrow(0.675, 0.485, 0.00, -0.025, head_width=0.01, head_length=0.015, linewidth=4, color='k', length_includes_head=False,transform=fig.transFigure,figure=fig)
plt.arrow(0.433, 0.255, 0.00, -0.025, head_width=0.01, head_length=0.015, linewidth=4, color='k', length_includes_head=False,transform=fig.transFigure,figure=fig)
plt.gcf().text(0.465*(1-0.006),0.255*(1-0.006),r'{\bf ALP dark matter}',fontsize=30,rotation=34,color='w')
plt.gcf().text(0.465*(1+0.006),0.255*(1-0.006),r'{\bf ALP dark matter}',fontsize=30,rotation=34,color='w')
plt.gcf().text(0.465*(1-0.006),0.255*(1+0.006),r'{\bf ALP dark matter}',fontsize=30,rotation=34,color='w')
plt.gcf().text(0.465*(1+0.006),0.255*(1+0.006),r'{\bf ALP dark matter}',fontsize=30,rotation=34,color='w')

plt.gcf().text(0.465,0.255,r'ALP dark matter',fontsize=30,rotation=34)
dat = loadtxt("limit_data/AxionPhoton/ALP_CDM.txt")
plt.plot(dat[:,0],dat[:,1],'k--',lw=2.5,zorder=0.0,alpha=1)

MySaveFig(fig,'AxionPhoton_AstroCloseUp_withoutHaloscopes')


AxionPhoton.ADMX(ax,text_on=False,zorder=0.05)
AxionPhoton.RBF_UF(ax,text_on=False,zorder=0.05)
AxionPhoton.ADMX_SLIC(ax,text_on=True,fs=15,text_shift=[0.55,1])
AxionPhoton.CAPP(ax,text_on=False)
AxionPhoton.SHAFT(ax,text_on=False,lw=1.0,edgealpha=1)
AxionPhoton.ABRACADABRA(ax,text_on=False,lw=1.5,edgealpha=1)
#AxionPhoton.BASE(ax,text_on=False)

plt.text(2.4e-6,0.8e-12,r'{\bf ADMX}',color='w',rotation=90,fontsize=25)
plt.text(5.5e-6,0.3e-12,r'{\bf RBF + UF + CAPP}',color='w',rotation=90,fontsize=25)

plt.gcf().text(0.575*(1-0.001),0.83*(1+0.001),r'{\bf ABRA}',color='k',fontsize=30,rotation=0,rotation_mode='anchor',ha='center',va='center')
plt.gcf().text(0.575,0.83,r'{\bf ABRA}',color='w',fontsize=30,rotation=0,rotation_mode='anchor',ha='center',va='center')
plt.gcf().text(0.575,0.79,r'10 cm',color='w',fontsize=30,rotation=0,rotation_mode='anchor',ha='center',va='center')
plt.gcf().text(0.46*(1-0.001),0.76*(1+0.001),r'{\bf SHAFT}',color='k',fontsize=29,rotation=0,rotation_mode='anchor',ha='center',va='center')
plt.gcf().text(0.46,0.76,r'{\bf SHAFT}',color='w',fontsize=29,rotation=0,rotation_mode='anchor',ha='center',va='center')

MySaveFig(fig,'AxionPhoton_AstroCloseUp')
