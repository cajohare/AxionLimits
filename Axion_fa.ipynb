# %% [markdown]
# # Constraints on $1/f_a$ scale versus axion mass
#
# QCD axion line defined by
# \begin{equation}
# m_{a}=5.70(7) \mu \mathrm{eV}\left(\frac{10^{12} \,\mathrm{GeV}}{f_{a}}\right)
# \end{equation}
#
# This can be related to the EDM coupling (the characteristic coupling of the QCD axion) via:
# \begin{equation}
# g_{a n \gamma}=-g_{a p \gamma}=e \frac{C_{\mathrm{EDM}}}{f_{a}}=(3.7 \pm 1.5) \times 10^{-3}\left(\frac{1}{f_{a}}\right) \frac{1}{\mathrm{GeV}}
# \end{equation}
#
#
# It must be noted that this plot and the EDM-coupling plot are, at best, challenging to interpret from any theoretical point of view. They should not be taken any more seriously than simply a comparison of experimental sensitivities. The area outside of the QCD line here requires significant (and rarely natural) model-building. In essence one needs a "QCD" axion whose mass is different from than the mass arising just from the anomalous gluon coupling of the axion (which defines 1/f_a). There are very few models that achieve this naturally, such as the Z_N axion model of Hook (https://arxiv.org/abs/1802.10093), and developed phenomenologically by Di Luzio et al. (https://arxiv.org/pdf/2102.00012.pdf)

# %%
from numpy import *
import matplotlib.pyplot as plt
from PlotFuncs import BlackHoleSpins,Axion_fa,MySaveFig, FigSetup, line_background, UpperFrequencyAxis_Simple, AlternativeCouplingAxis
    
fig,ax = FigSetup(Shape='Rectangular',ylab=r'$1/f_a$ [GeV$^{-1}$]',mathpazo=True,\
                              g_min=1e-20,g_max=1e-4,m_min=1e-20,m_max=10)
UpperFrequencyAxis_Simple(ax)
AlternativeCouplingAxis(ax,scale=3.7e-3,ylabel=r'$|g_{an\gamma}|$ [GeV$^{-2}$]')

BlackHoleSpins(ax,1,[4e-11,1e-17],fs=27,whichfile='Hoof',rotation=-90,text_col='w',alpha=1,facecolor='gray',text_on=False,zorder=0.1)
BlackHoleSpins(ax,1,[4e-11,1e-17],fs=27,whichfile='Witte',rotation=-90,text_col='w',alpha=1,facecolor='gray',text_on=False,zorder=0.1)
#BlackHoleSpins(ax,1,[4e-11*(1+0.01),1e-17*(1+0.02)],fs=27,whichfile='Baryakhtar',rotation=-90,text_col='k',alpha=1,facecolor='darkgray',text_on=True)
#BlackHoleSpins(ax,1,[4e-11*(1+0.01),1e-17*(1+0.02)],fs=27,whichfile='Unal',rotation=-90,text_col='k',alpha=1,facecolor='lightgray',text_on=False,zorder=0.05)

Axion_fa.QCDAxion(ax)
Axion_fa.nEDM(ax)
Axion_fa.BeamEDM(ax)
Axion_fa.HfF(ax)
Axion_fa.I2Ca(ax)
Axion_fa.RbQuartz(ax)
Axion_fa.SolarCore(ax)
Axion_fa.WhiteDwarfs(ax)
Axion_fa.Pulsars(ax)
Axion_fa.SN1987A(ax)
Axion_fa.GW170817(ax)
Axion_fa.BBN(ax)
Axion_fa.PlanckBAO(ax)
Axion_fa.Axinovae(ax)
Axion_fa.NeutronStarCooling(ax)
Axion_fa.ONIX(ax)

plt.text(0.8e-12,1e-18,r'{\bf Stellar BH spins}',fontsize=20,rotation=90)
plt.text(1.5e-19,0.1e-18,r'{\bf SMBH spins}',fontsize=20,rotation=90)



#plt.text(0.5e-11,0.02e-15,'Hoof et al.',fontsize=20,rotation=90)
#plt.text(0.6e-12,1e-18,'Baryakhtar et al.',fontsize=20,rotation=90)
#plt.text(0.3e-19,0.2e-18,r'\"Unal et al.',fontsize=20,rotation=90)

# plt.text(9e-17,1.7e-19,'SMBHs')
# plt.plot([1.2e-17,8e-17],[1e-19,2e-19],'k-',lw=2)

# plt.text(2.5e-10,0.5e-13,'Stellar BHs')
# plt.plot([1.5e-11,2e-10],[1e-14,5e-14],'k-',lw=2)


MySaveFig(fig,'Axion_fa')

# %%
from numpy import *
import matplotlib.pyplot as plt
from PlotFuncs import BlackHoleSpins,Axion_fa,MySaveFig, FigSetup, line_background, UpperFrequencyAxis_Simple, AlternativeCouplingAxis
        
fig,ax = FigSetup(Shape='Rectangular',ylab=r'$1/f_a$ [GeV$^{-1}$]',mathpazo=True,\
                              g_min=1e-20,g_max=1e-4,m_min=1e-20,m_max=10)
UpperFrequencyAxis_Simple(ax)
AlternativeCouplingAxis(ax,scale=3.7e-3,ylabel=r'$|g_{an\gamma}|$ [GeV$^{-2}$]')


BlackHoleSpins(ax,1,[4e-11,1e-17],fs=27,whichfile='Hoof',rotation=-90,text_col='w',alpha=1,facecolor='gray',text_on=False,zorder=0.1)
BlackHoleSpins(ax,1,[4e-11,1e-17],fs=27,whichfile='Witte',rotation=-90,text_col='w',alpha=1,facecolor='gray',text_on=False,zorder=0.1)
#BlackHoleSpins(ax,1,[4e-11*(1+0.01),1e-17*(1+0.02)],fs=27,whichfile='Baryakhtar',rotation=-90,text_col='k',alpha=1,facecolor='darkgray',text_on=True)
#BlackHoleSpins(ax,1,[4e-11*(1+0.01),1e-17*(1+0.02)],fs=27,whichfile='Unal',rotation=-90,text_col='k',alpha=1,facecolor='lightgray',text_on=False,zorder=0.05)

Axion_fa.QCDAxion(ax,QCD_label_mass=1e-5)
Axion_fa.nEDM(ax)
Axion_fa.BeamEDM(ax)
Axion_fa.HfF(ax)
Axion_fa.I2Ca(ax)
Axion_fa.RbQuartz(ax)
Axion_fa.SolarCore(ax)
Axion_fa.WhiteDwarfs(ax)
Axion_fa.Pulsars(ax)
Axion_fa.GW170817(ax)
Axion_fa.SN1987A(ax)
Axion_fa.Inspirals(ax,zorder=-5)
#Axion_fa.NeutronStars(ax)
Axion_fa.BBN(ax)
Axion_fa.PlanckBAO(ax)
Axion_fa.Axinovae(ax)
Axion_fa.NeutronStarCooling(ax)
Axion_fa.ONIX(ax)

#Axion_fa.StorageRingEDM(ax)
Axion_fa.CASPEr(ax)
Axion_fa.PiezoaxionicEffect(ax,fs=15,text_pos=[7.6e-10,0.05e-14])
#Axion_fa.PolarisationHaloscope(ax)

plt.text(0.8e-12,1e-18,r'{\bf Stellar BH spins}',fontsize=20,rotation=90)
plt.text(1.5e-19,0.2e-18,r'{\bf SMBH spins}',fontsize=20,rotation=90)

# plt.text(13e-16,1e-19,r'{\bf Black hole}',fontsize=25,ha='center')
# plt.text(13e-16,0.3e-19,r'{\bf spins}',fontsize=25,ha='center')
# plt.plot([1.7e-17,4e-17],[3e-19,2e-19],'k-',lw=2.5)
# plt.plot(array([1.7e-14,4e-14])*2.1,[2e-19,3e-19],'k-',lw=2.5)

# plt.text(0.5e-11,0.02e-15,'Mehta et al.',fontsize=20,rotation=90)
# plt.text(0.6e-12,1e-18,'Baryakhtar et al.',fontsize=20,rotation=90)
#plt.text(0.3e-19,0.2e-18,r'\"Unal et al.',fontsize=20,rotation=90)


MySaveFig(fig,'Axion_fa_with_Projections')
