# %%
# %matplotlib inline
from numpy import *
import matplotlib.pyplot as plt
from PlotFuncs import MyDoublePlot_Vertical,AxionPhoton,MySaveFig,UpperFrequencyAxis,col_alpha,FigSetup,line_background

fig,ax1,ax2 = MyDoublePlot_Vertical('','$|g_{a\gamma\gamma}|$ [GeV$^{-1}$]','$m_a$ [eV]')

ax1.set_xlim([1e-6,3e-4])
ax1.set_ylim([2e-16,1e-9])
ax2.set_xlim([1e-6,3e-4])
ax2.set_ylim([0,1])
             
ax1.set_yscale('log')
ax1.set_xscale('log')
ax2.set_xscale('log')

ax1.set_xticklabels([])
ax2.set_yticks([])
UpperFrequencyAxis(ax1,N_Hz=1e6,tfs=30,xlabel=r"Frequency [MHz]",xlabel_pad=20)


y2 = 1e-9




# CAST
AxionPhoton.Helioscopes(ax1,projection=False,text_on=False)
plt.gcf().text(0.2,0.815,r'{\bf CAST}',color=col_alpha('crimson',0.0),fontsize=40,rotation=0,rotation_mode='anchor',ha='center',va='center',path_effects=line_background(1.5,'k'))


# Globular clusters
AxionPhoton.StellarBounds(ax1,text_on=False)
plt.text(2.2e-4,2.7e-11,r'{\bf Globular}',color=[0.0, 0.66, 0.42],fontsize=20,path_effects=line_background(1,'k'),ha='center')
plt.text(2.2e-4,1.5e-11,r'{\bf clusters}',color=[0.0, 0.66, 0.42],fontsize=20,path_effects=line_background(1,'k'),ha='center')

# Pulars
AxionPhoton.PulsarPolarCap(ax1,text_on=False)
plt.text(1.1e-6,3.5e-12,r'{\bf Pulsars}',color='w',rotation=-2,fontsize=23,path_effects=line_background(1.5,'k'))

AxionPhoton.SN1987A_gamma(ax1,text_on=False)
plt.text(1.04e-6,2.5e-11,r'{\bf SN1987A}',color='w',rotation=0,fontsize=20,path_effects=line_background(1.5,'k'))

AxionPhoton.NuSTAR_Sun(ax1,text_on=False)
plt.text(1.04e-6,0.9e-11,r'{\bf NuSTAR}',color='w',rotation=4,fontsize=20,path_effects=line_background(1.5,'k'))



# QCD axion
AxionPhoton.QCDAxion(ax1,text_on=False,C_center=abs(5/3-1.92)*(44/3-1.92)/2,C_width=0.7)
def g_x(C_ag,m_a):
        return 2e-10*C_ag*m_a
mvals = array([1e-6,3e-4])
ax1.plot(mvals,g_x(44/3-1.95,mvals),'--',lw=3,color='brown',zorder=0.0,alpha=0.2)
ax1.plot(mvals,g_x(abs(5/3-1.92),mvals),'--',lw=3,color='brown',zorder=0.1,alpha=0.2)
plt.gcf().text(0.89,0.635,r'$E/N = 44/3$',fontsize=20,color='brown',rotation=13,rotation_mode='anchor',ha='right',alpha=0.9)
plt.gcf().text(0.89,0.47,r'$E/N = 5/3$',fontsize=20,color='brown',rotation=13,rotation_mode='anchor',ha='right',alpha=0.9)
plt.gcf().text(0.89,0.568,r'KSVZ',fontsize=20,color='darkred',rotation=13.5,rotation_mode='anchor',ha='right',alpha=1)
plt.gcf().text(0.89,0.508,r'DFSZ',fontsize=20,color='darkred',rotation=13.5,rotation_mode='anchor',ha='right',alpha=1)



# RBF/UF
UF_col = [0.8,0,0]
RBF_col = 'Darkred'
dat = loadtxt("limit_data/AxionPhoton/RBF.txt")
plt.fill_between(dat[:,0],dat[:,1],y2=y2,edgecolor='k',facecolor='darkred',zorder=0.1)
dat = loadtxt("limit_data/AxionPhoton/UF.txt")
plt.fill_between(dat[:,0],dat[:,1],y2=y2,edgecolor='k',facecolor=[0.8,0,0],zorder=0.09)
plt.gcf().text(0.37,0.48,r'{\bf UF}',color=col_alpha(UF_col,1),fontsize=28,rotation=90,rotation_mode='anchor',ha='center',va='center',path_effects=line_background(1.5,'k'))
plt.gcf().text(0.407,0.65,r'{\bf RBF}',color=col_alpha(RBF_col,0.1),fontsize=23,rotation=0,rotation_mode='anchor',ha='center',va='center',path_effects=line_background(1.5,'k'))


# ADMX
ADMX_col = 'crimson'
dat = loadtxt("limit_data/AxionPhoton/ADMX.txt")
plt.fill_between(dat[:,0],dat[:,1],y2=y2,edgecolor='k',facecolor=ADMX_col,zorder=0.1)
dat = loadtxt("limit_data/AxionPhoton/ADMX2018.txt")
plt.fill_between(dat[:,0],dat[:,1],y2=y2,edgecolor='k',facecolor=ADMX_col,zorder=0.1)
dat = loadtxt("limit_data/AxionPhoton/ADMX2019_1.txt")
plt.fill_between(dat[:,0],dat[:,1],y2=y2,edgecolor='k',facecolor=ADMX_col,zorder=0.1)
dat = loadtxt("limit_data/AxionPhoton/ADMX2019_2.txt")
plt.fill_between(dat[:,0],dat[:,1],y2=y2,edgecolor='k',facecolor=ADMX_col,zorder=0.1)
dat = loadtxt("limit_data/AxionPhoton/ADMX2021.txt")
plt.fill_between(dat[:,0],dat[:,1],y2=y2,edgecolor='k',facecolor=ADMX_col,zorder=0.1)
dat = loadtxt("limit_data/AxionPhoton/ADMX2024.txt")
plt.fill_between(dat[:,0],dat[:,1],y2=y2,edgecolor='k',facecolor=ADMX_col,zorder=0.1)
dat = loadtxt("limit_data/AxionPhoton/ADMX2025.txt")
plt.fill_between(dat[:,0],dat[:,1],y2=y2,edgecolor='k',facecolor=ADMX_col,zorder=0.1)
plt.gcf().text(0.24,0.55,r'{\bf ADMX}',color=col_alpha(ADMX_col,0.2),fontsize=35,rotation=90,rotation_mode='anchor',ha='center',va='center',path_effects=line_background(1.5,'k'))

# HAYSTAC
HAYSTAC_col = 'orangered'
dat1 = loadtxt("limit_data/AxionPhoton/HAYSTAC_PhaseI.txt")
dat2 = loadtxt("limit_data/AxionPhoton/HAYSTAC_PhaseII_ab.txt")
dat3 = loadtxt("limit_data/AxionPhoton/HAYSTAC_PhaseII_cd.txt")
plt.fill_between(dat1[:,0],dat1[:,1],y2=y2,edgecolor='k',facecolor=HAYSTAC_col,zorder=0.1)
plt.fill_between(dat2[:,0],dat2[:,1],y2=y2,edgecolor='k',facecolor=HAYSTAC_col,zorder=0.1)
plt.fill_between(dat3[:,0],dat3[:,1],y2=y2,edgecolor='k',facecolor=HAYSTAC_col,zorder=0.1)
plt.gcf().text(0.505,0.52,r'{\bf HAYSTAC}',color=col_alpha(HAYSTAC_col,1),fontsize=17,rotation=90,rotation_mode='anchor',ha='center',va='center')
plt.gcf().text(0.567,0.54,r'{\bf HAYSTAC}',color=col_alpha(HAYSTAC_col,1),fontsize=17,rotation=90,rotation_mode='anchor',ha='center',va='center')


# CAPP
CAPP_col = 'deeppink'
dat1 = loadtxt("limit_data/AxionPhoton/CAPP-1.txt")
dat2 = loadtxt("limit_data/AxionPhoton/CAPP-2.txt")
dat3 = loadtxt("limit_data/AxionPhoton/CAPP-3.txt")
dat4 = loadtxt("limit_data/AxionPhoton/CAPP-4.txt")
dat5 = loadtxt("limit_data/AxionPhoton/CAPP-5.txt")
dat6 = loadtxt("limit_data/AxionPhoton/CAPP-6.txt")
dat7 = loadtxt("limit_data/AxionPhoton/CAPP-7.txt")
dat8 = loadtxt("limit_data/AxionPhoton/CAPP-8.txt")
dat9 = loadtxt("limit_data/AxionPhoton/CAPP-MAX.txt")

plt.fill_between(dat1[:,0],dat1[:,1],y2=y2,edgecolor='k',facecolor=CAPP_col,zorder=0.1)
plt.fill_between(dat2[:,0],dat2[:,1],y2=y2,edgecolor='k',facecolor=CAPP_col,zorder=0.1)
plt.fill_between(dat3[:,0],dat3[:,1],y2=y2,edgecolor='k',facecolor=CAPP_col,zorder=0.1)
plt.fill_between(dat4[:,0],dat4[:,1],y2=y2,edgecolor='k',facecolor=CAPP_col,zorder=0.1)
plt.fill_between(dat5[:,0],dat5[:,1],y2=y2,edgecolor='k',facecolor=CAPP_col,zorder=0.1)
plt.fill_between(dat6[:,0],dat6[:,1],y2=y2,edgecolor='k',facecolor=CAPP_col,zorder=0.1)
plt.fill_between(dat7[:,0],dat7[:,1],y2=y2,edgecolor='k',facecolor=CAPP_col,zorder=0.1)
plt.fill_between(dat8[:,0],dat8[:,1],y2=y2,edgecolor='k',facecolor=CAPP_col,zorder=0.1)
plt.fill_between(dat9[:,0],dat9[:,1],y2=y2,edgecolor='k',facecolor=CAPP_col,zorder=0.1)

plt.gcf().text(0.455,0.49,r'{\bf CAPP}',color=col_alpha(CAPP_col,1),fontsize=20,rotation=-90,rotation_mode='anchor',ha='center',va='center')
plt.gcf().text(0.49,0.59,r'{\bf CAPP}',color=col_alpha(CAPP_col,1),fontsize=15,rotation=-90,rotation_mode='anchor',ha='center',va='center')
plt.gcf().text(0.393,0.5,r'{\bf CAPP}',color=col_alpha(CAPP_col,1),fontsize=15,rotation=-90,rotation_mode='anchor',ha='center',va='center')
plt.gcf().text(0.537,0.5,r'{\bf CAPP}',color=col_alpha(CAPP_col,1),fontsize=15,rotation=-90,rotation_mode='anchor',ha='center',va='center')
plt.gcf().text(0.425,0.52,r'{\bf CAPP}',color=col_alpha(CAPP_col,1),fontsize=14,rotation=90,rotation_mode='anchor',ha='center',va='center')

# ORGAN
ORGAN_col = [0.7,0.2,0.05]
AxionPhoton.ORGAN(ax1,text_on=False,col=ORGAN_col)
plt.gcf().text(0.757,0.715,r'{\bf ORGAN}',color=col_alpha(ORGAN_col,1),fontsize=18,rotation=90,rotation_mode='anchor',ha='center',va='center')
plt.gcf().text(0.682,0.715,r'{\bf ORGAN}',color=col_alpha(ORGAN_col,1),fontsize=18,rotation=90,rotation_mode='anchor',ha='center',va='center')
plt.gcf().text(0.575,0.69,r'{\bf ORGAN}',color=col_alpha(ORGAN_col,1),fontsize=18,rotation=-90,rotation_mode='anchor',ha='center',va='center')

# CAST-CAPP
dat = loadtxt("limit_data/AxionPhoton/CAST-CAPP.txt")
plt.fill_between(dat[:,0],dat[:,1],y2=y2,edgecolor='k',facecolor=CAPP_col,zorder=0.1)
plt.gcf().text(0.542,0.635,r'{\bf CAST-CAPP}',color='w',fontsize=14,rotation=90,rotation_mode='anchor',ha='center',va='center')


# ADMX Sidecar
dat = loadtxt("limit_data/AxionPhoton/ADMX_Sidecar.txt")
plt.fill_between(dat[:,0],dat[:,1],y2=y2,edgecolor='k',facecolor=ADMX_col,zorder=0.1)
plt.gcf().text(0.547,0.705,r'{\bf ADMX}',color='w',fontsize=14,rotation=90,rotation_mode='anchor',ha='center',va='center')

# QUAX
QUAX_col = [0.6,0.1,0.3]
dat = loadtxt("limit_data/AxionPhoton/QUAX.txt")
dat2 = loadtxt("limit_data/AxionPhoton/QUAX2.txt")
dat3 = loadtxt("limit_data/AxionPhoton/QUAX4.txt") # supersedes QUAX3.txt
dat4 = loadtxt("limit_data/AxionPhoton/QUAX5.txt")
plt.fill_between(dat[:,0],dat[:,1],y2=y2,edgecolor=QUAX_col,facecolor=ADMX_col,zorder=0.1)
plt.fill_between(dat2[:,0],dat2[:,1],y2=y2,edgecolor=QUAX_col,facecolor=ADMX_col,zorder=0.1)
plt.fill_between(dat3[:,0],dat3[:,1],y2=y2,edgecolor=QUAX_col,facecolor=ADMX_col,zorder=0.1)
plt.fill_between(dat4[:,0],dat4[:,1],y2=y2,edgecolor=QUAX_col,facecolor=ADMX_col,zorder=0.1)
plt.gcf().text(0.648,0.613,r'{\bf QUAX}-$a\gamma$',color=col_alpha(QUAX_col,1),fontsize=19,rotation=90,rotation_mode='anchor',ha='center',va='center')


# RADES
RADES_col = [0.95,0.1,0.1]
dat = loadtxt("limit_data/AxionPhoton/RADES.txt")
plt.plot([dat[0,0],dat[0,0]],[dat[0,1],y2],color=RADES_col,lw=2,zorder=0.05)
dat = loadtxt("limit_data/AxionPhoton/RADES2.txt")
plt.plot(dat[:,0],dat[:,1],color=RADES_col,lw=2,zorder=0.05)
plt.gcf().text(0.602,0.63,r'{\bf RADES}',color=col_alpha(RADES_col,1),fontsize=15,rotation=90,rotation_mode='anchor',ha='center',va='center')

# GrAHal
GrAHal_col = '#b53e5a'
AxionPhoton.GrAHal(ax1,text_on=False,col=GrAHal_col)
plt.gcf().text(0.575,0.62,r'{\bf GrAHal}',color=col_alpha(GrAHal_col,1),fontsize=15,rotation=-90,rotation_mode='anchor',ha='center',va='center')

# TASEH
TASEH_col = '#a84e32'
dat = loadtxt("limit_data/AxionPhoton/TASEH.txt")
plt.fill_between(dat[:,0],dat[:,1],y2=y2,edgecolor='k',facecolor=TASEH_col,zorder=0.4)
plt.gcf().text(0.535,0.555,r'{\bf TASEH}',color=col_alpha(TASEH_col,1),fontsize=14,rotation=-90,rotation_mode='anchor',ha='center',va='center')

# MADMAX
dat = loadtxt('limit_data/AxionPhoton/MADMAX.txt')
plt.fill_between(dat[:,0],dat[:,1],y2=y2,edgecolor='#6b2e25',facecolor='#6b2e25',zorder=0.11)
plt.text(75e-6,2.4e-12,r'{\bf MADMAX}',color='#6b2e25',rotation=90,fontsize=16)

# GigaBREAD
dat = loadtxt("limit_data/AxionPhoton/GigaBREAD.txt")
plt.fill_between(dat[:,0],dat[:,1],y2=y2,edgecolor='k',facecolor='darkmagenta',zorder=0.1)
plt.text(48.5e-6,0.72e-11,r'{\bf GigaBREAD}',color='darkmagenta',fontsize=14,rotation=90,rotation_mode='anchor',ha='center',va='center')


# Neutron stars
plt.gcf().text(0.55,0.79,r'{\bf Neutron Stars}',color=col_alpha('#2ab0a3',0.4),fontsize=20,rotation=0,rotation_mode='anchor',ha='center',va='center',path_effects=line_background(1,'k'))
dat = loadtxt('limit_data/AxionPhoton/NeutronStars_BreakthroughListen.txt')
plt.fill_between(dat[:,0],dat[:,1],y2=y2,edgecolor='k',facecolor='#2ab0a3',zorder=0.11)


def PlotTheoryMass(ax,file,y,ybar=0.035,color='blue',lw=5,label='',text_pos=[1.0,1.0],fs=20):
    m_low,m_high = loadtxt('limit_data/AxionMass/'+file+'.txt',unpack=True)
    ax.plot([m_low,m_high],[y,y],'-',color=color,lw=5,path_effects=line_background(6,'k'))
    ax.plot([m_low*0.98,m_low*0.98],[y-ybar,y+ybar],'-',lw=3,color=color)
    ax.plot([m_high*1.01,m_high*1.01],[y-ybar,y+ybar],'-',lw=3,color=color)
    
    ax.text(text_pos[0],text_pos[1],label,fontsize=fs,color=color,rotation=0,clip_on=True)
    return


PlotTheoryMass(ax2,'Ballesteros16',0.54,color='#0581a3',text_pos=[50e-6,0.57],label="Ballesteros '17")
PlotTheoryMass(ax2,'Dine17',0.87,color='#5068a6',text_pos=[1.5e-5,0.87],label="Dine '17")
PlotTheoryMass(ax2,'Borsanyi16',0.40,color='#32a8a6',text_pos=[5e-5,0.44],label="Borsanyi '16")
PlotTheoryMass(ax2,'Fleury15',0.09,color='#1c6ed9',text_pos=[5e-5,0.13],label="Fleury '15")
PlotTheoryMass(ax2,'Berkowitz15',0.24,color='#785fc9',text_pos=[15e-6,0.15],label="Berkowitz '15")
PlotTheoryMass(ax2,'Bonati16',0.6,color='royalblue',text_pos=[4e-6,0.67],label="Bonati '16")
PlotTheoryMass(ax2,'Petreczky16',0.5,color='navy',text_pos=[4e-6,0.37],label="Petreczky '16")
PlotTheoryMass(ax2,'Klaer17',0.6,color='#5da884',text_pos=[1.6e-5,0.62],label="Klaer '17")
PlotTheoryMass(ax2,'Benabou24',0.78,color='#266787',text_pos=[0.68e-4,0.77],label="Benabou '24")
PlotTheoryMass(ax2,'Buschmann20',0.5,color='#327273',text_pos=[1.443e-5,0.4],label="Buschmann '20")
PlotTheoryMass(ax2,'Co20',0.32,color='#7a5d94',text_pos=[38e-6,0.29],label="Co '20")
PlotTheoryMass(ax2,'Saikawa24',0.68,color='#324952',text_pos=[44e-6,0.67],label="Saikawa '24")


MySaveFig(fig,'AxionPhoton_RadioFreqCloseup_withTheory')
