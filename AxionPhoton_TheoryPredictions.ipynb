# %%
# %matplotlib inline
from numpy import *
import matplotlib.pyplot as plt
from PlotFuncs import MyDoublePlot_Vertical,AxionPhoton,MySaveFig,UpperFrequencyAxis,col_alpha,FigSetup,line_background

fig,ax1,ax2 = MyDoublePlot_Vertical('','$|g_{a\gamma\gamma}|$ [GeV$^{-1}$]','$m_a$ [eV]')

ax1.set_xlim([1e-6,3e-4])
ax1.set_ylim([2e-16,1e-9])
ax2.set_xlim([1e-6,3e-4])
ax2.set_ylim([0,1])
             
ax1.set_yscale('log')
ax1.set_xscale('log')
ax2.set_xscale('log')

ax1.set_xticklabels([])
ax2.set_yticks([])
UpperFrequencyAxis(ax1,N_Hz=1e6,tfs=30,xlabel=r"Frequency [MHz]",xlabel_pad=20)


y2 = 1e-9




# CAST
AxionPhoton.Helioscopes(ax1,projection=False,text_on=False)
plt.gcf().text(0.2*(1-0.005),0.805*(1+0.005),r'{\bf CAST}',color='k',fontsize=40,rotation=0,rotation_mode='anchor',ha='center',va='center')
plt.gcf().text(0.2,0.805,r'{\bf CAST}',color=col_alpha('crimson',0.0),fontsize=40,rotation=0,rotation_mode='anchor',ha='center',va='center')

# QCD axion
AxionPhoton.QCDAxion(ax1,text_on=False,C_center=abs(5/3-1.92)*(44/3-1.92)/2,C_width=0.7)
def g_x(C_ag,m_a):
        return 2e-10*C_ag*m_a
mvals = array([1e-6,3e-4])
ax1.plot(mvals,g_x(44/3-1.95,mvals),'--',lw=3,color='brown',zorder=0.0,alpha=0.2)
ax1.plot(mvals,g_x(abs(5/3-1.92),mvals),'--',lw=3,color='brown',zorder=0.1,alpha=0.2)
plt.gcf().text(0.89,0.64,r'$E/N = 44/3$',fontsize=20,color='brown',rotation=13,rotation_mode='anchor',ha='right',alpha=0.9)
plt.gcf().text(0.89,0.48,r'$E/N = 5/3$',fontsize=20,color='brown',rotation=13,rotation_mode='anchor',ha='right',alpha=0.9)
plt.gcf().text(0.89,0.575,r'KSVZ',fontsize=20,color='darkred',rotation=13,rotation_mode='anchor',ha='right',alpha=1)
plt.gcf().text(0.89,0.515,r'DFSZ',fontsize=20,color='darkred',rotation=13,rotation_mode='anchor',ha='right',alpha=1)



# RBF/UF
UF_col = [0.8,0,0]
RBF_col = 'Darkred'
dat = loadtxt("limit_data/AxionPhoton/RBF_UF_Haloscopes.txt")
plt.fill_between(dat[:,0],dat[:,1],y2=y2,edgecolor='k',facecolor='darkred',zorder=0.1)
dat = loadtxt("limit_data/AxionPhoton/UF.txt")
plt.fill_between(dat[:,0],dat[:,1],y2=y2,edgecolor='k',facecolor=[0.8,0,0],zorder=0.1)
plt.gcf().text(0.36*(1-0.003),0.48*(1+0.001),r'{\bf UF}',color='k',fontsize=30,rotation=0,rotation_mode='anchor',ha='center',va='center')
plt.gcf().text(0.36,0.48,r'{\bf UF}',color=col_alpha(UF_col,1),fontsize=30,rotation=0,rotation_mode='anchor',ha='center',va='center')
plt.gcf().text(0.407*(1-0.003),0.65*(1+0.003),r'{\bf RBF}',color='k',fontsize=30,rotation=0,rotation_mode='anchor',ha='center',va='center')
plt.gcf().text(0.407,0.65,r'{\bf RBF}',color=col_alpha(RBF_col,0.1),fontsize=30,rotation=0,rotation_mode='anchor',ha='center',va='center')


# ADMX
ADMX_col = 'crimson'
dat = loadtxt("limit_data/AxionPhoton/ADMX.txt")
plt.fill_between(dat[:,0],dat[:,1],y2=y2,edgecolor='k',facecolor=ADMX_col,zorder=0.1)
dat = loadtxt("limit_data/AxionPhoton/ADMX2018.txt")
plt.fill_between(dat[:,0],dat[:,1],y2=y2,edgecolor='k',facecolor=ADMX_col,zorder=0.1)
dat = loadtxt("limit_data/AxionPhoton/ADMX2019_1.txt")
plt.fill_between(dat[:,0],dat[:,1],y2=y2,edgecolor='k',facecolor=ADMX_col,zorder=0.1)
dat = loadtxt("limit_data/AxionPhoton/ADMX2019_2.txt")
plt.fill_between(dat[:,0],dat[:,1],y2=y2,edgecolor='k',facecolor=ADMX_col,zorder=0.1)
dat = loadtxt("limit_data/AxionPhoton/ADMX2021.txt")
plt.fill_between(dat[:,0],dat[:,1],y2=y2,edgecolor='k',facecolor=ADMX_col,zorder=0.1)
plt.gcf().text(0.24*(1-0.005),0.55*(1+0.005),r'{\bf ADMX}',color='k',fontsize=35,rotation=90,rotation_mode='anchor',ha='center',va='center')
plt.gcf().text(0.24,0.55,r'{\bf ADMX}',color=col_alpha(ADMX_col,0.2),fontsize=35,rotation=90,rotation_mode='anchor',ha='center',va='center')

# HAYSTAC
HAYSTAC_col = 'orangered'
dat = loadtxt("limit_data/AxionPhoton/HAYSTAC_highres.txt")
dat2 = loadtxt("limit_data/AxionPhoton/HAYSTAC_2020_highres.txt")
plt.fill_between(dat[:,0],dat[:,1],y2=y2,edgecolor='k',facecolor=HAYSTAC_col,zorder=0.1)
plt.fill_between(dat2[:,0],dat2[:,1],y2=y2,edgecolor='k',facecolor=HAYSTAC_col,zorder=0.1)
plt.gcf().text(0.505,0.52,r'{\bf HAYSTAC}',color=col_alpha(HAYSTAC_col,1),fontsize=17,rotation=90,rotation_mode='anchor',ha='center',va='center')
plt.gcf().text(0.546,0.6,r'{\bf HAYSTAC}',color=col_alpha(HAYSTAC_col,1),fontsize=17,rotation=90,rotation_mode='anchor',ha='center',va='center')


# CAPP
CAPP_col = [1, 0.1, 0.37]
dat1 = loadtxt("limit_data/AxionPhoton/CAPP-1.txt")
dat2 = loadtxt("limit_data/AxionPhoton/CAPP-2.txt")
dat3 = loadtxt("limit_data/AxionPhoton/CAPP-3.txt")
plt.fill_between(dat1[:,0],dat1[:,1],y2=y2,edgecolor='k',facecolor=CAPP_col,zorder=0.1)
plt.fill_between(dat2[:,0],dat2[:,1],y2=y2,edgecolor='k',facecolor=CAPP_col,zorder=0.1)
plt.fill_between(dat3[:,0],dat3[:,1],y2=y2,edgecolor='k',facecolor=CAPP_col,zorder=0.1)
plt.gcf().text(0.44,0.49,r'{\bf CAPP}',color=col_alpha(CAPP_col,1),fontsize=20,rotation=90,rotation_mode='anchor',ha='center',va='center')
plt.gcf().text(0.49,0.59,r'{\bf CAPP}',color=col_alpha(CAPP_col,1),fontsize=15,rotation=-90,rotation_mode='anchor',ha='center',va='center')
plt.gcf().text(0.393,0.5,r'{\bf CAPP}',color=col_alpha(CAPP_col,1),fontsize=15,rotation=-90,rotation_mode='anchor',ha='center',va='center')

# ORGAN
ORGAN_col = [0.7,0.2,0.05]
AxionPhoton.ORGAN(ax1,text_on=False,col=ORGAN_col)
plt.gcf().text(0.755,0.69,r'{\bf ORGAN}',color=col_alpha(ORGAN_col,1),fontsize=20,rotation=90,rotation_mode='anchor',ha='center',va='center')


# ADMX Sidecar
dat = loadtxt("limit_data/AxionPhoton/ADMX_Sidecar.txt")
plt.fill_between(dat[:,0],dat[:,1],y2=y2,edgecolor='k',facecolor=ADMX_col,zorder=0.1)

# QUAX
QUAX_col = [0.6,0.1,0.3]
dat = loadtxt("limit_data/AxionPhoton/QUAX.txt")
dat2 = loadtxt("limit_data/AxionPhoton/QUAX2.txt")
plt.plot([dat[0,0],dat[0,0]],[dat[0,1],y2],color=QUAX_col,lw=2,zorder=0.05)
plt.plot([dat2[0,0],dat2[0,0]],[dat2[0,1],y2],color=QUAX_col,lw=2,zorder=0.05)
plt.gcf().text(0.627,0.6,r'{\bf QUAX}-$a\gamma$',color=col_alpha(QUAX_col,1),fontsize=20,rotation=90,rotation_mode='anchor',ha='center',va='center')


# RADES
RADES_col = [0.95,0.1,0.1]
dat = loadtxt("limit_data/AxionPhoton/RADES.txt")
plt.plot([dat[0,0],dat[0,0]],[dat[0,1],y2],color=RADES_col,lw=2,zorder=0.05)
plt.gcf().text(0.602,0.63,r'{\bf RADES}',color=col_alpha(RADES_col,1),fontsize=15,rotation=90,rotation_mode='anchor',ha='center',va='center')

# GrAHal
GrAHal_col = '#b53e5a'
AxionPhoton.GrAHal(ax1,text_on=False,col=GrAHal_col)
plt.gcf().text(0.575,0.62,r'{\bf GrAHal}',color=col_alpha(GrAHal_col,1),fontsize=15,rotation=-90,rotation_mode='anchor',ha='center',va='center')



# Neutron stars
# dat = loadtxt('limit_data/AxionPhoton/NeutronStars_GreenBank.txt')
# plt.fill_between(dat[:,0],dat[:,1],y2=y2,edgecolor='k',facecolor='ForestGreen',zorder=0.11)
# dat = loadtxt('limit_data/AxionPhoton/NeutronStars_VLA.txt')
# plt.fill_between(dat[:,0],dat[:,1],y2=y2,edgecolor='k',facecolor='SeaGreen',zorder=0.11)
# dat = loadtxt('limit_data/AxionPhoton/NeutronStars_Battye.txt') 
# plt.plot(dat[:,0],dat[:,1],color='k',lw=1,zorder=0.2)
# plt.fill_between(dat[:,0],dat[:,1],y2=1e0,zorder=0.2,color='#4ad46a')
# plt.gcf().text(0.53*(1-0.002),0.85*(1+0.002),r'{\bf Neutron Stars}',color='k',fontsize=30,rotation=0,rotation_mode='anchor',ha='center',va='center')
# plt.gcf().text(0.53,0.85,r'{\bf Neutron Stars}',color=col_alpha('Green',0.4),fontsize=30,rotation=0,rotation_mode='anchor',ha='center',va='center')
# plt.gcf().text(0.41*(1-0.001),0.8*(1+0.001),r'{\bf Foster et al.}',color='k',fontsize=25,rotation=0,rotation_mode='anchor',ha='center',va='center',multialignment='center')
# plt.gcf().text(0.41,0.8,r'Foster et al.',color=col_alpha('ForestGreen',0.7),fontsize=25,rotation=0,rotation_mode='anchor',ha='center',va='center',multialignment='center')
# plt.gcf().text(0.52*(1-0.001),0.8*(1+0.001),r'{\bf Darling}',color='k',fontsize=25,rotation=0,rotation_mode='anchor',ha='center',va='center',multialignment='center')
# plt.gcf().text(0.52,0.8,r'Darling',color=col_alpha('SeaGreen',0.7),fontsize=25,rotation=0,rotation_mode='anchor',ha='center',va='center',multialignment='center')
# plt.gcf().text(0.65*(1-0.001),0.8*(1+0.001),r'{\bf Battye et al.}',color='k',fontsize=25,rotation=0,rotation_mode='anchor',ha='center',va='center',multialignment='center')
# plt.gcf().text(0.65,0.8,r'Battye et al.',color=col_alpha('#20c742',0.7),fontsize=25,rotation=0,rotation_mode='anchor',ha='center',va='center',multialignment='center')
plt.gcf().text(0.55*(1-0.002),0.8*(1+0.002),r'{\bf Neutron Stars}',color='k',fontsize=20,rotation=0,rotation_mode='anchor',ha='center',va='center')
plt.gcf().text(0.55,0.8,r'{\bf Neutron Stars}',color=col_alpha('ForestGreen',0.4),fontsize=20,rotation=0,rotation_mode='anchor',ha='center',va='center')
dat = loadtxt('limit_data/AxionPhoton/NeutronStars_BreakthroughListen.txt')
plt.fill_between(dat[:,0],dat[:,1],y2=y2,edgecolor='k',facecolor='ForestGreen',zorder=0.11)


def PlotTheoryMass(ax,file,y,ybar=0.035,color='blue',lw=5,label='',text_pos=[1.0,1.0],fs=20):
    m_low,m_high = loadtxt('limit_data/AxionMass/'+file+'.txt',unpack=True)
    ax.plot([m_low,m_high],[y,y],'-',color=color,lw=5,path_effects=line_background(6,'k'))
    ax.plot([m_low*0.98,m_low*0.98],[y-ybar,y+ybar],'-',lw=3,color=color)
    ax.plot([m_high*1.01,m_high*1.01],[y-ybar,y+ybar],'-',lw=3,color=color)
    
    ax.text(text_pos[0],text_pos[1],label,fontsize=fs,color=color,rotation=0,clip_on=True)
    return

PlotTheoryMass(ax2,'Ballesteros16',0.58,color='#0581a3',text_pos=[50e-6,0.62],label="Ballesteros '17")
PlotTheoryMass(ax2,'Dine17',0.85,color='#5068a6',text_pos=[1.5e-5,0.85],label="Dine '17")
PlotTheoryMass(ax2,'Borsanyi16',0.4,color='#32a8a6',text_pos=[5e-5,0.44],label="Borsanyi '16")
PlotTheoryMass(ax2,'Fleury15',0.1,color='#1c6ed9',text_pos=[5e-5,0.13],label="Fleury '15")
PlotTheoryMass(ax2,'Berkowitz15',0.3,color='#785fc9',text_pos=[15e-6,0.2],label="Berkowitz '15")
PlotTheoryMass(ax2,'Bonati16',0.6,color='royalblue',text_pos=[4e-6,0.67],label="Bonati '16")
PlotTheoryMass(ax2,'Petreczky16',0.5,color='navy',text_pos=[4e-6,0.37],label="Petreczky '16")
PlotTheoryMass(ax2,'Klaer17',0.6,color='#5da884',text_pos=[1.6e-5,0.62],label="Klaer '17")
PlotTheoryMass(ax2,'Buschmann21',0.78,color='#266787',text_pos=[0.7e-4,0.805],label="Buschmann '21")
PlotTheoryMass(ax2,'Buschmann20',0.5,color='#327273',text_pos=[1.443e-5,0.4],label="Buschmann '20")


MySaveFig(fig,'AxionPhoton_RadioFreqCloseup_withTheory')
