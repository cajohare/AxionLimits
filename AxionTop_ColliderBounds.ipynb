# %% [markdown]
# # Collider, accelerator and beam dump bounds
# ## Notebook courtesy of Maria Ubiali
# Compiled in Esser et al. https://arxiv.org/abs/2303.17634 and Esser et al.  https://arxiv.org/abs/2404.08062

# %%
# %matplotlib inline
from numpy import *
import matplotlib.pyplot as plt
from PlotFuncs import FigSetup, AxionTop, MySaveFig, BlackHoleSpins, FilledLimit, line_background

fig,ax = FigSetup(Shape='Rectangular',xlab=r'$m_a$ [GeV]',ylab=r'$|c_t/f_a|$ [GeV$^{-1}$]',mathpazo=True,
                  m_min=1e-2,m_max=1e4,g_min=1e-7,g_max=1.0e0,xtick_rotation=0)

AxionTop.ATLAS_direct(ax,text_on=False)
AxionTop.ATLAS_indirect(ax,text_on=False)
AxionTop.CMS_indirect(ax,text_on=False)
AxionTop.K_decay(ax,text_on=False)
AxionTop.B_decay(ax,text_on=False)
AxionTop.indirect_zz(ax,text_on=False)
AxionTop.indirect_gamgam(ax,text_on=False)
AxionTop.indirect_zgam(ax,text_on=False)
AxionTop.indirect_hhz(ax,text_on=False)

plt.text(1.1e-2,2e-3,r'{\bf ATLAS $t\bar{t}a$ search}',color='#531ee3',rotation=0,fontsize=20,path_effects=line_background(0.5,'k'))
plt.text(9e2,8e-3,r'{\bf ATLAS $t\bar{t}$}',color='#ad49a5',rotation=45,fontsize=20,path_effects=line_background(0.5,'k'))
plt.text(1.1e-2,1.2e-2,r'{\bf CMS $t\bar{t}$ non resonant}',color='#95991c',rotation=0,fontsize=20,path_effects=line_background(0.5,'k'))
plt.text(1.1e-2,3.2e-4,r'{\bf Kaon decays}',color='#37872f',rotation=0,fontsize=20,path_effects=line_background(0.5,'k'))
plt.text(1.1e-2,3.4e-6,r'{\bf B decays}',color='w',rotation=0,fontsize=20,path_effects=line_background(0.5,'k'))
plt.text(1.1e-2,4e-1,r'{\bf Indirect ZZ}',color='#8f110a',rotation=0,fontsize=20,path_effects=line_background(0.5,'k'))
plt.text(1.1e-2,5e-2,r'{\bf Indirect $\gamma\gamma$}',color='w',rotation=0,fontsize=20,path_effects=line_background(0.5,'k'))
plt.text(1.1e-2,1.3e-1,r'{\bf Indirect $Z\gamma$}',color='w',rotation=0,fontsize=20,path_effects=line_background(0.5,'k'))
plt.text(6.4e+1,2e-2,r'{\bf Indirect $hhZ$}',color='black',rotation=0,fontsize=20,path_effects=line_background(0.5,'k'))
plt.title("Axion-Top coupling constraints")
MySaveFig(fig,'AxionTop_Collider_hh')
