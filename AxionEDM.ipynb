# %% [markdown]
# # Axion coupling to neutron electric dipole moment
#
# QCD axion line defined by
# \begin{equation}
# m_{a}=5.70(7) \mu \mathrm{eV}\left(\frac{10^{12} \,\mathrm{GeV}}{f_{a}}\right)
# \end{equation}
#
# This can be related to the EDM coupling (the characteristic coupling of the QCD axion) via:
# \begin{equation}
# g_{a n \gamma}=-g_{a p \gamma}=e \frac{C_{\mathrm{EDM}}}{f_{a}}=(3.7 \pm 1.5) \times 10^{-3}\left(\frac{1}{f_{a}}\right) \frac{1}{\mathrm{GeV}}
# \end{equation}
# The shading the QCD line reflects this theoretical uncertainty, see https://arxiv.org/abs/1306.6088
#
# It must be noted that this plot and the 1/fa plot are, at best, challenging to interpret beyond a purely phenomenological point of view, and are at worst highly misleading. Most crucially, the area outside of the QCD line requires significant (and not always natural!) model-building. In essence one needs a "QCD" axion whose mass is different from than the mass arising just from the anomalous gluon coupling of the axion (which defines 1/f_a). There are very few models that achieve this naturally, such as the Z_N axion model of Hook (https://arxiv.org/abs/1802.10093), and developed phenomenologically by Di Luzio et al. (https://arxiv.org/pdf/2102.00012.pdf)

# %%
from numpy import *
import matplotlib.pyplot as plt
import matplotlib as mpl
from PlotFuncs import BlackHoleSpins,AxionEDM,MySaveFig,FigSetup,UpperFrequencyAxis_Simple,FilledLimit,line_background

fig,ax = FigSetup(Shape='Rectangular',ylab=r'$|g_{an\gamma}|$ [GeV$^{-2}$]',mathpazo=True,\
                              g_min=1e-22,g_max=1e-2,m_min=1e-20,m_max=1e0)
UpperFrequencyAxis_Simple(ax)

AxionEDM.QCDAxion(ax)
AxionEDM.nEDM(ax)
AxionEDM.BeamEDM(ax)
AxionEDM.HfF(ax)
AxionEDM.JEDI(ax)
AxionEDM.RbQuartz(ax)
AxionEDM.SN1987A(ax)
AxionEDM.CASPEr(ax)
AxionEDM.PlanckBAO(ax)
AxionEDM.BBN(ax)
AxionEDM.ONIX(ax)



# BlackHoleSpins(ax,6.4e-16*1e12,[0.7e-13,0.2e-18],fs=23,rotation=90,text_col='k',text_on=True,alpha=1,facecolor='gray')
# plt.gcf().text(0.475,0.29,'Stellar',ha='center',alpha=0.75)
# plt.gcf().text(0.475,0.26,'BHs',ha='center',alpha=0.75)
# plt.gcf().text(0.195,0.15,'SM \n BHs',alpha=0.75,ha='center')



MySaveFig(fig,'AxionEDM')

# %%
from numpy import *
import matplotlib.pyplot as plt
import matplotlib as mpl
from PlotFuncs import BlackHoleSpins,AxionEDM,MySaveFig,FigSetup,UpperFrequencyAxis_Simple,FilledLimit,line_background

fig,ax = FigSetup(Shape='Rectangular',ylab=r'$|g_{an\gamma}|$ [GeV$^{-2}$]',mathpazo=True,\
                              g_min=1e-22,g_max=1e-2,m_min=1e-20,m_max=1e0)
UpperFrequencyAxis_Simple(ax)

AxionEDM.QCDAxion(ax)
AxionEDM.nEDM(ax)
AxionEDM.BeamEDM(ax)
AxionEDM.HfF(ax)
AxionEDM.RbQuartz(ax)
AxionEDM.JEDI(ax)
AxionEDM.SN1987A(ax)
AxionEDM.CASPEr(ax,projection=True)
AxionEDM.PlanckBAO(ax)
AxionEDM.BBN(ax)
AxionEDM.ONIX(ax)

AxionEDM.PolarisationHaloscope(ax)

#BlackHoleSpins(ax,6.4e-16*1e12,[0.7e-13,0.2e-18],fs=23,rotation=90,text_col='k',text_on=True,alpha=1,facecolor='gray')
# plt.gcf().text(0.475,0.29,'Stellar',ha='center',alpha=0.75)
# plt.gcf().text(0.475,0.26,'BHs',ha='center',alpha=0.75)
# plt.gcf().text(0.195,0.18,'SM \n BHs',alpha=0.75,ha='center');

MySaveFig(fig,'AxionEDM_with_Projections')
