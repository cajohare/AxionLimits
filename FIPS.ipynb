# %%
# %matplotlib inline
from numpy import *
import matplotlib.pyplot as plt
import matplotlib as mpl
from PlotFuncs import MySquarePlot,AxionPhoton,MySaveFig,UpperFrequencyAxis_Simple,col_alpha,FigSetup,line_background,PlotBound
from PlotFuncs_ScalarVector import FuzzyDM

pek = line_background(0.75,'k')

lfs = 42

plt.rcParams.update({"text.usetex": True,"font.family": "serif","font.serif": ["Times"],})

fig,ax = FigSetup(Shape='Custom',xlab='',m_min=1e-24,m_max=1e12,g_min=1e-20,g_max=1e-1,mathpazo=False,figsize=(16,11),tickdir='in',TopAndRightTicks=True,majorticklength=15,minorticklength=11,xtick_rotation=0)
plt.gcf().text(0.025,0.64,'$g_{a\gamma}$ [GeV$^{-1}$]',rotation=90,fontsize=lfs)
plt.gcf().text(0.79,0.024,'$m_a$ [eV]',rotation=0,fontsize=lfs)


# colors
Astro = [0.65,0.65,0.65]
AstroDM = [0.85,0.85,0.85]
ExperimentDM = col_alpha('royalblue',0.5)
ExperimentLab = '#a64b7f'
ExperimentStellar = '#4c9c5d'
Collider = '#a64b7f'


PlotBound(ax,"limit_data/AxionPhoton/CAST_highm.txt",facecolor=ExperimentStellar,zorder=0.14,lw=1)
PlotBound(ax,"limit_data/AxionPhoton/CAST.txt",facecolor=ExperimentStellar,zorder=0.14,lw=1)

PlotBound(ax,"limit_data/AxionPhoton/GlobularClusters.txt",facecolor=Astro,zorder=0.1,lw=1)
PlotBound(ax,"limit_data/AxionPhoton/SolarNu.txt",facecolor=Astro,zorder=0.11,lw=1)
PlotBound(ax,"limit_data/AxionPhoton/WhiteDwarfs.txt",facecolor=Astro,zorder=0.09,lw=1)
PlotBound(ax,"limit_data/AxionPhoton/SN1987A_decay.txt",facecolor=Astro,zorder=0.0,lw=1)
PlotBound(ax,"limit_data/AxionPhoton/SNe-decay-Fiorillo.txt",facecolor=Astro,zorder=0.08,lw=1)
PlotBound(ax,"limit_data/AxionPhoton/SN1987A_PVO.txt",facecolor=Astro,zorder=0.079,lw=1)
PlotBound(ax,"limit_data/AxionPhoton/GW170817_Fermi.txt",facecolor=Astro,zorder=0.07,lw=1)
PlotBound(ax,"limit_data/AxionPhoton/GW170817.txt",facecolor=Astro,zorder=0.07,lw=1)
PlotBound(ax,"limit_data/AxionPhoton/DiffuseGammaRays.txt",facecolor=Astro,zorder=0.07,lw=1)
PlotBound(ax,"limit_data/AxionPhoton/SolarBasin_Beaufort.txt",facecolor=Astro,zorder=0.07,lw=1)
PlotBound(ax,"limit_data/AxionPhoton/IrreducibleFreezeIn.txt",facecolor=Astro,zorder=0.06,lw=1)
PlotBound(ax,"limit_data/AxionPhoton/BBN_10MeV.txt",facecolor=Astro,zorder=-0.9,lw=1,skip=1)
#PlotBound(ax,"limit_data/AxionPhoton/SN1987a_HeavyALP_nu.txt",facecolor=Astro,zorder=0.08,lw=1)


PlotBound(ax,"limit_data/AxionPhoton/BeamDump.txt",facecolor=Collider,zorder=0.13,lw=1)
PlotBound(ax,"limit_data/AxionPhoton/MiniBooNE.txt",facecolor=Collider,zorder=0.129,lw=1)
PlotBound(ax,"limit_data/AxionPhoton/BaBar.txt",facecolor=Collider,zorder=0.14,lw=1)
PlotBound(ax,"limit_data/AxionPhoton/LEP.txt",facecolor=Collider,zorder=0.12,lw=1)
PlotBound(ax,"limit_data/AxionPhoton/OPAL.txt",facecolor=Collider,zorder=0.11,lw=1)
PlotBound(ax,"limit_data/AxionPhoton/CMS_PbPb.txt",facecolor=Collider,zorder=0.06,lw=1)
PlotBound(ax,"limit_data/AxionPhoton/ATLAS_PbPb.txt",facecolor=Collider,zorder=0.05,lw=1)
PlotBound(ax,"limit_data/AxionPhoton/LHC_pp.txt",facecolor=Collider,zorder=0.00,lw=1)
PlotBound(ax,"limit_data/AxionPhoton/PrimEx.txt",facecolor=Collider,zorder=0.115,lw=1)
PlotBound(ax,"limit_data/AxionPhoton/BESIII.txt",facecolor=Collider,zorder=0.11,lw=1)
PlotBound(ax,"limit_data/AxionPhoton/BelleII.txt",facecolor=Collider,zorder=0.11,lw=1)


PlotBound(ax,"limit_data/AxionPhoton/Haloscopes_Combined_microeV-meV.txt",facecolor=ExperimentDM,zorder=0,lw=0.7)
PlotBound(ax,"limit_data/AxionPhoton/SHAFT.txt",facecolor=ExperimentDM,zorder=0.5,lw=0.7,skip=3)
PlotBound(ax,"limit_data/AxionPhoton/ABRACADABRA.txt",facecolor=ExperimentDM,zorder=0.5,lw=0.7,skip=20)
PlotBound(ax,"limit_data/AxionPhoton/ABRACADABRA_run2.txt",facecolor=ExperimentDM,zorder=0.5,lw=0.7,skip=10)
PlotBound(ax,"limit_data/AxionPhoton/LIDA.txt",facecolor=ExperimentDM,zorder=0.5,lw=0.5)
PlotBound(ax,"limit_data/AxionPhoton/SuperMAG_Combined.txt",facecolor=ExperimentDM,zorder=0.49,lw=1,skip=1)
PlotBound(ax,"limit_data/AxionPhoton/DANCE.txt",facecolor=ExperimentDM,zorder=0.51,lw=0.7,skip=1)
PlotBound(ax,"limit_data/AxionPhoton/UPLOAD.txt",facecolor=ExperimentDM,zorder=0.5,lw=0.7,skip=1)
PlotBound(ax,"limit_data/AxionPhoton/SPT.txt",facecolor=ExperimentDM,zorder=0.13,lw=1,edgecolor='k')
PlotBound(ax,"limit_data/AxionPhoton/BICEP-KECK.txt",facecolor=ExperimentDM,zorder=0.12,lw=1,edgecolor='k')
PlotBound(ax,"limit_data/AxionPhoton/SNIPE.txt",facecolor=ExperimentDM,zorder=0.5,lw=1)
PlotBound(ax,"limit_data/AxionPhoton/ADBC.txt",facecolor=ExperimentDM,zorder=0.141,lw=0.1)
PlotBound(ax,"limit_data/AxionPhoton/Eskdalemuir.txt",facecolor=ExperimentDM,zorder=0.48,lw=1,skip=1)

#PlotBound(ax,"limit_data/AxionPhoton/UPLOAD-2.txt",facecolor=ExperimentDM,zorder=0.5,lw=0.2,skip=1)
#PlotBound(ax,"limit_data/AxionPhoton/ADMX_SLIC.txt",facecolor=ExperimentDM,zorder=-10,lw=1)
#PlotBound(ax,"limit_data/AxionPhoton/BASE.txt",facecolor=ExperimentDM,zorder=0,lw=1)


edgecolor = [0.5,0.5,0.5]
PlotBound(ax,"limit_data/AxionPhoton/JWST_Pinetti.txt",facecolor=AstroDM,zorder=0,lw=1,edgecolor=edgecolor,skip=3)
PlotBound(ax,"limit_data/AxionPhoton/DESI.txt",facecolor=AstroDM,zorder=0,lw=1,skip=1,edgecolor=edgecolor)
PlotBound(ax,"limit_data/AxionPhoton/Telescopes_MUSE.txt",facecolor=AstroDM,zorder=0,lw=1,skip=30,edgecolor=edgecolor)
PlotBound(ax,"limit_data/AxionPhoton/HST.txt",facecolor=AstroDM,zorder=0,lw=1,edgecolor=edgecolor)
PlotBound(ax,"limit_data/AxionPhoton/LeoT.txt",facecolor=AstroDM,zorder=-1,lw=1,skip=1,edgecolor=edgecolor)
PlotBound(ax,"limit_data/AxionPhoton/CMB_Anisotropies.txt",facecolor=AstroDM,zorder=-1,lw=1,skip=1,edgecolor=edgecolor)
PlotBound(ax,"limit_data/AxionPhoton/x_ion.txt",facecolor=AstroDM,zorder=-0.9,lw=1,skip=1,edgecolor=edgecolor)
PlotBound(ax,"limit_data/AxionPhoton/CosmicBackground.txt",facecolor=AstroDM,zorder=-1,lw=1,skip=1,edgecolor=edgecolor,end_x=-2)
PlotBound(ax,"limit_data/AxionPhoton/GammaRayDecayCompilation.txt",facecolor=AstroDM,zorder=-1,lw=1,skip=1,edgecolor=edgecolor)
PlotBound(ax,"limit_data/AxionPhoton/GammaRayAttenuation.txt",facecolor=AstroDM,zorder=-1,lw=1,skip=1,edgecolor=edgecolor)
PlotBound(ax,"limit_data/AxionPhoton/XRAY.txt",facecolor=AstroDM,zorder=-2,lw=1,skip=1,edgecolor=edgecolor)
PlotBound(ax,"limit_data/AxionPhoton/XMM-Newton.txt",facecolor=AstroDM,zorder=-3,lw=1,skip=4,edgecolor=edgecolor)
PlotBound(ax,"limit_data/AxionPhoton/NuSTAR.txt",facecolor=AstroDM,zorder=-4,lw=1,skip=4,edgecolor=edgecolor)
PlotBound(ax,"limit_data/AxionPhoton/INTEGRAL.txt",facecolor=AstroDM,zorder=-3,lw=1,skip=1,edgecolor=edgecolor)
#PlotBound(ax,"limit_data/AxionPhoton/AxionStarExplosions-1.txt",facecolor=AstroDM,zorder=-10,lw=1,edgecolor=edgecolor)
#PlotBound(ax,"limit_data/AxionPhoton/AxionStarExplosions-2.txt",facecolor=AstroDM,zorder=-10,lw=1,edgecolor=edgecolor)
PlotBound(ax,"limit_data/AxionPhoton/PPTA-QUIJOTE.txt",facecolor=AstroDM,zorder=0.115,lw=1,edgecolor=edgecolor)
#PlotBound(ax,"limit_data/AxionPhoton/NeutronStars_BreakthroughListen.txt",facecolor=AstroDM,zorder=0.1,lw=1,edgealpha=0.5)

            
PlotBound(ax,"limit_data/AxionPhoton/SNe-gamma.txt",facecolor=Astro,zorder=-0.9,lw=1)
PlotBound(ax,"limit_data/AxionPhoton/Chandra_HYDRA_A.txt",facecolor=Astro,zorder=-0.2,lw=1)
PlotBound(ax,"limit_data/AxionPhoton/Chandra_M87.txt",facecolor=Astro,zorder=-0.3,lw=1)
PlotBound(ax,"limit_data/AxionPhoton/Mrk421.txt",facecolor=Astro,zorder=-0.3,lw=1)
PlotBound(ax,"limit_data/AxionPhoton/FermiQuasars.txt",facecolor=Astro,zorder=-0.31,lw=1)
AxionPhoton.Fermi(ax,zorder=-0.3,col=Astro,lw=1,text_on=False)
PlotBound(ax,"limit_data/AxionPhoton/Xray-SuperStarClusters.txt",facecolor=Astro,zorder=-0.25,lw=1)
PlotBound(ax,"limit_data/AxionPhoton/Chandra_NGC1275.txt",facecolor=Astro,zorder=-1.1,lw=1)
PlotBound(ax,"limit_data/AxionPhoton/Chandra_H1821643.txt",facecolor=Astro,zorder=-1,lw=1)
PlotBound(ax,"limit_data/AxionPhoton/SN1987A_gamma_ProgenitorBfield.txt",facecolor=Astro,zorder=-3,lw=1)
PlotBound(ax,"limit_data/AxionPhoton/MWDPolarisation_KeckLick.txt",facecolor=Astro,zorder=-100,lw=1)
PlotBound(ax,"limit_data/AxionPhoton/MWDXrays.txt",facecolor=Astro,zorder=0.11,lw=1)
PlotBound(ax,"limit_data/AxionPhoton/PulsarPolarCap.txt",facecolor=Astro,zorder=-3,lw=1)
PlotBound(ax,"limit_data/AxionPhoton/NuSTAR_Sun.txt",facecolor=Astro,zorder=-3.1,lw=1)
PlotBound(ax,"limit_data/AxionPhoton/HESS.txt",facecolor=Astro,zorder=-0.2,lw=1)
PlotBound(ax,"limit_data/AxionPhoton/HAWC.txt",facecolor=Astro,zorder=-0.3,lw=1)
PlotBound(ax,"limit_data/AxionPhoton/M82.txt",facecolor=Astro,zorder=-1,lw=1)
#PlotBound(ax,"limit_data/AxionPhoton/FIRAS.txt",facecolor=Astro,zorder=0.141,lw=1)
PlotBound(ax,"limit_data/AxionPhoton/Planck_unWISE.txt",facecolor=Astro,zorder=-0.1,lw=1)



PlotBound(ax,"limit_data/AxionPhoton/CROWS.txt",facecolor=ExperimentLab,zorder=0.4,lw=1)
PlotBound(ax,"limit_data/AxionPhoton/OSQAR.txt",facecolor=ExperimentLab,zorder=0.3,lw=1)
PlotBound(ax,"limit_data/AxionPhoton/PVLAS.txt",facecolor=ExperimentLab,zorder=0.3,lw=1)
PlotBound(ax,"limit_data/AxionPhoton/ALPS.txt",facecolor=ExperimentLab,zorder=0.3,lw=1)
PlotBound(ax,"limit_data/AxionPhoton/SAPPHIRES.txt",facecolor=ExperimentLab,zorder=0.3,lw=1)
PlotBound(ax,"limit_data/AxionPhoton/NOMAD.txt",facecolor=ExperimentLab,zorder=0.3,lw=1)
PlotBound(ax,"limit_data/AxionPhoton/EuXFL.txt",facecolor=ExperimentLab,zorder=0.3,lw=1)



PlotBound(ax,"limit_data/AxionPhoton/Projections/HaloscopeProjections_Combined.txt",edgecolor='royalblue',zorder=-0.1,alpha=0.0,lw=1.5,linestyle='--')
PlotBound(ax,"limit_data/AxionPhoton/Projections/BabyIAXO.txt",edgecolor=ExperimentStellar,zorder=-10,alpha=0.0,lw=1.5,linestyle='--')
#PlotBound(ax,"limit_data/AxionPhoton/Projections/IAXO.txt",edgecolor=ExperimentStellar,zorder=-10,alpha=0.0,lw=2.5,linestyle='--')
PlotBound(ax,"limit_data/AxionPhoton/Projections/ALPS-II.txt",edgecolor=ExperimentLab,zorder=0.2,alpha=0.0,lw=1.5,linestyle=(6, (4, 1.5,4,1)),edgealpha=0.85,start_x=1200,skip=5)
PlotBound(ax,"limit_data/AxionPhoton/Projections/WISPFI.txt",edgecolor=ExperimentLab,zorder=0.0,alpha=0.0,lw=1.5,linestyle=(6, (4, 1.5,4,1)),edgealpha=0.85)


# CMB 
mvals = logspace(-30,-10)
ax.fill_between(mvals,(mvals/1e-22)*9.670231994906073e-14,y2=1,color=AstroDM,alpha=1,zorder=0.11)
ax.plot(mvals,(mvals/1e-22)*9.670231994906073e-14,'-',color='k',lw=1.5,zorder=0.11,alpha=0.5)

# Fuzzy dark matter
FuzzyDM(ax,text_label=r'',alpha=0.01,facecolor='gray',zorder=0,text_shift=[1e-2,0.5e-4],rotation=0,text_col='gray',fs=40,path_effects=line_background(2,'k'))
ax.axvline(2e-20,zorder=-10,color=AstroDM,alpha=0.5)

# QCD axion hadronic band
m = array([1e-13,1e1])
ga = 2e-10*m
C1 = 44/3-1.92
C2 = abs(5/3-1.92)
for i in linspace(1,10,100):
    ax.fill_between(m,C1*ga/i,C2*ga*i,alpha=0.05,color='gold',zorder=-1000,lw=0)

ax.set_xticks(10.0**arange(-24,15,3),rotation=0);

# Add labels
ax.text(3e-24,1.2e-15,r'{\it Planck}',color='k',fontsize=20,rotation=53,alpha=0.6)
ax.text(5e-23,1.1e-13,r'{\it PPTA}',color='k',fontsize=11,rotation=53,alpha=0.6)
ax.text(2.2e-23,5e-13,r'{\bf BICEP/KECK}',color='k',fontsize=11,rotation=90)
ax.text(1e-21,6e-12,r'{\bf SPT}',color='k',fontsize=14,rotation=54)

ax.text(1e-16,2e-13,r'{\it Chandra}',color='k',fontsize=14,rotation=0)
ax.text(3.2e-11,4.5e-13,r'{\it NuSTAR}',color='k',fontsize=12,rotation=0)

#ax.text(1e-12,1.9e-13,r'{Axion star}',color='k',fontsize=13,rotation=31,alpha=0.4)
#ax.text(2e-12,0.8e-13,r'{explosions}',color='k',fontsize=13,rotation=31,alpha=0.4)


ax.text(0.4e-9,8e-12,r'{\it Fermi}',color='k',fontsize=13,rotation=0)
ax.text(6.2e-9,0.8e-12,r'{MWDs}',color='k',fontsize=12,rotation=0)
ax.text(5.8e-8,4e-12,r'{Pulsars}',color='k',fontsize=12,rotation=0)

ax.text(4e-17,1e-8,r'{\bf SuperMAG}',color='k',fontsize=18,rotation=90)
ax.text(6e-15,1e-2,r'{\bf DANCE}',color='k',fontsize=13,rotation=0)
ax.text(4e-11,0.8e-9,r'{\bf SHAFT}',color='k',fontsize=18,rotation=90)
ax.text(4e-10,0.8e-8,r'{\bf ABRACADABRA}',color='k',fontsize=16,rotation=90)
ax.text(0.85e-9,6e-10,r'{\bf LIDA}',color='k',fontsize=11,rotation=90)
ax.text(0.9e-8,0.8e-5,r'{\bf UPLOAD}',color='k',fontsize=10,rotation=90)
ax.text(0.4e-14,5e-6,r'{\bf SNIPE}',color='k',fontsize=15,rotation=90)
ax.text(45e-9,0.06e-8,r'{\bf ADBC}',color='k',fontsize=10,rotation=90,alpha=0.8)
ax.text(1.5e-14,0.6e-11,r'{\bf Eskdalemuir}',color='k',fontsize=15,rotation=90)


ax.text(2e-3,0.5e-9,r'{\bf CAST}',color='k',fontsize=25,rotation=0)
ax.text(5e0,1.5e-9,r'{\bf Solar $\nu$}',color='k',fontsize=21,rotation=0,alpha=0.8)
ax.text(0.7e-1,0.6e-10,r'{\bf Globular clusters}',color='k',fontsize=15,rotation=0,alpha=0.8)
ax.text(4e3,0.3e-11,r'{\it NuSTAR}',color='k',fontsize=12,rotation=95,alpha=0.8)
ax.text(0.6e6,3e-7,r'{\bf White} {\bf dwarfs}',color='k',fontsize=8,rotation=89,alpha=0.8)
ax.text(0.4e-12,0.5e-11,r'{\bf CMB}',color='k',fontsize=11,rotation=90,alpha=0.8)

ax.text(3e4,0.3e-13,r'{\bf Freeze-in}',color='k',fontsize=17,rotation=-62,alpha=0.8)
ax.text(1.2e5,1.3e-10,r'{\bf Diffuse-$\gamma$}',color='k',fontsize=14,rotation=0,alpha=0.8)
ax.text(4e5,0.3e-11,r'{\bf SN1987A}',color='k',fontsize=14,rotation=-32,alpha=0.8)
ax.text(33e5,1.5e-11,r'{\bf GW17}-$\gamma$',color='k',fontsize=9,rotation=-32,alpha=0.8)
ax.text(0.9e7,0.4e-6,r'\noindent {\bf Low-Energy}\newline \indent \indent \indent  {\bf SNe}',fontsize=17,color='k',rotation=-55,ha='center',va='top',alpha=0.8)
ax.text(0.4e7,0.9e-12,r'{\bf BBN}',color='k',fontsize=10,rotation=-30)
ax.text(0.4e9,0.9e-10,r'{\bf GW170817}',color='k',fontsize=8,rotation=0)



ax.text(3e-7,1e-15,r'{\bf Haloscopes}',color=ExperimentDM,fontsize=20,rotation=90,path_effects=pek)
ax.text(3e-18,6.7e-17,r'{\bf Haloscopes}',color='royalblue',fontsize=20,rotation=0,ha='center',alpha=0.8)
ax.text(3e-18,1.4e-17,r'{\bf (future)}',color='royalblue',fontsize=20,rotation=0,ha='center',alpha=0.8)

ax.text(0.2e-9,0.2e-17,r'{\bf QCD axion}',color='gold',fontsize=20,rotation=51.5,path_effects=pek)
ax.text(1.5e-4,2.1e-11,r'{\bf BabyIAXO}',fontsize=11,rotation=0,alpha=1,color=ExperimentStellar)

ax.text(2.7,0.2e-13,r'MUSE',color='k',fontsize=11,rotation=90,alpha=0.4)
ax.text(6.5,2.5e-13,r'DESI',color='k',fontsize=10,rotation=-90,alpha=0.4)
ax.text(6,2.5e-11,r'HST',color='k',fontsize=9,rotation=0,alpha=0.4)
ax.text(0.2,7e-12,r'JWST',color='k',fontsize=11,rotation=0,alpha=0.4)
ax.text(0.35e2,9.8e-13,r'Ionisation',color='k',fontsize=13,rotation=90,alpha=0.4)
ax.text(1e2,9.5e-13,r'fraction',color='k',fontsize=13,rotation=90,alpha=0.4)
ax.text(4.1e1,0.45e-14,r'LeoT',color='k',fontsize=10,rotation=-60,alpha=0.4)
ax.text(6e0,2e-18,r'XMM-Newton',color='k',fontsize=12,rotation=0,alpha=0.4)
ax.text(0.4e3,0.25e-18,r'{\it NuSTAR}',color='k',fontsize=12,rotation=0,alpha=0.4)
ax.text(0.25e3,0.4e-19,r'INTEGRAL',color='k',fontsize=12,rotation=0,alpha=0.4)
ax.text(3e-3,0.6e-8,r'{\bf ALPS-II}',color=ExperimentLab,fontsize=19,rotation=69,alpha=0.8)
ax.text(0.03,6.5e-12,r'{\bf WISPFI}',rotation=90,fontsize=9,color=ExperimentLab,ha='left',va='top')
ax.text(1e6,3e-18,r'\begin{center} Dark matter \linebreak decay\end{center}',color='k',fontsize=22,rotation=0,alpha=0.4)


ax.text(0.3e-7,1.5e-7,r'{\bf CROWS}',color='k',fontsize=14,rotation=0)
ax.text(2e-5,1e-7,r'{\bf ALPS}',color='k',fontsize=14,rotation=0)
ax.text(5e-7,0.15e-7,r'{\bf OSQAR}',color='k',fontsize=14,rotation=0)
ax.text(3.5e-3,1e-6,r'{\bf PVLAS}',color='k',fontsize=10,rotation=53)
ax.text(2.8e-2,0.24e-5,r'{\bf SAPPHIRES}',color='k',fontsize=10,rotation=-78)
ax.text(25e-2,2.0e-4,r'{\bf NOMAD}',color='k',fontsize=13,rotation=0)
ax.text(30e-2,6.3e-4,r'{\bf EuXFL}',color='k',fontsize=13,rotation=0)
ax.text(0.5e6,2.5e-4,r'{\bf BaBar}',color='k',fontsize=14,rotation=0)
ax.text(0.7e6,0.6e-6,r'{\bf Beam dump}',color='k',fontsize=16,rotation=-50)
ax.text(0.4e9,1.3e-2,r'{\bf LEP}',color='k',fontsize=16,rotation=0)
ax.text(0.22e9,1.4e-3,r'{\bf Belle-II}',color='k',fontsize=10,rotation=30)
ax.text(0.25e9,1.5e-4,r'{\bf BESIII}',color='k',fontsize=10,rotation=0)
ax.text(6e9,4e-4,r'{\bf CMS}',color='k',fontsize=10,rotation=0)
ax.text(1.1e9,0.3e-4,r'{\bf ATLAS}',color='k',fontsize=10,rotation=0)
ax.text(0.35e11,0.25e-4,r'{\bf LHC}',color='k',fontsize=10,rotation=0)
ax.text(0.5e8,0.15e-3,r'{\bf PrimEX}',color='k',fontsize=8,rotation=-70)
ax.text(0.25e7,0.8e-7,r'{\bf MiniBooNE}',color='k',fontsize=10,rotation=-53)

ax.text(0.4e-20,1e-19,r'Lyman-$\alpha$',fontsize=18,rotation=90,alpha=0.4)

MySaveFig(fig,'AxionPhoton_FIPS')

# %%
# %matplotlib inline
from numpy import *
import matplotlib.pyplot as plt
import matplotlib as mpl
from PlotFuncs import MySquarePlot,AxionPhoton,MySaveFig,UpperFrequencyAxis_Simple,col_alpha,FigSetup,line_background,PlotBound
from PlotFuncs_ScalarVector import FuzzyDM

fig,ax = FigSetup(Shape='Custom',xlab='',m_min=2e-7,m_max=2e-1,g_min=1e-17,g_max=1e-9,mathpazo=False,figsize=(16,11),tickdir='in',TopAndRightTicks=True,majorticklength=15,minorticklength=11,xtick_rotation=0)
UpperFrequencyAxis_Simple(ax,tickdir='in',tick_pad=6)
plt.gcf().text(0.02,0.64,'$g_{a\gamma}$ [GeV$^{-1}$]',rotation=90,fontsize=lfs)
plt.gcf().text(0.79,0.024,'$m_a$ [eV]',rotation=0,fontsize=lfs)



PlotBound(ax,"limit_data/AxionPhoton/CAST_highm.txt",facecolor=ExperimentStellar,zorder=0.14,lw=1)
PlotBound(ax,"limit_data/AxionPhoton/CAST.txt",facecolor=ExperimentStellar,zorder=0.14,lw=1)
PlotBound(ax,"limit_data/AxionPhoton/GlobularClusters.txt",facecolor=Astro,zorder=0.1,lw=1)
PlotBound(ax,"limit_data/AxionPhoton/NeutronStars_BreakthroughListen.txt",facecolor=AstroDM,zorder=0.1,lw=0.5,skip=2)
PlotBound(ax,"limit_data/AxionPhoton/NeutronStars_Battye2.txt",facecolor=AstroDM,zorder=0.12,lw=0.5,skip=2)

            
PlotBound(ax,"limit_data/AxionPhoton/SNe-gamma.txt",facecolor=Astro,zorder=-0.9,lw=1)
PlotBound(ax,"limit_data/AxionPhoton/Chandra_HYDRA_A.txt",facecolor=Astro,zorder=-0.2,lw=1)
PlotBound(ax,"limit_data/AxionPhoton/Chandra_M87.txt",facecolor=Astro,zorder=-0.3,lw=1)
PlotBound(ax,"limit_data/AxionPhoton/Mrk421.txt",facecolor=Astro,zorder=-0.3,lw=1)
PlotBound(ax,"limit_data/AxionPhoton/FermiQuasars.txt",facecolor=Astro,zorder=-0.31,lw=1)
PlotBound(ax,"limit_data/AxionPhoton/MWDPolarisation.txt",facecolor=Astro,zorder=-1,lw=1)
PlotBound(ax,"limit_data/AxionPhoton/MWDXrays.txt",facecolor=Astro,zorder=0.11,lw=1)
PlotBound(ax,"limit_data/AxionPhoton/PulsarPolarCap.txt",facecolor=Astro,zorder=-3,lw=1)
PlotBound(ax,"limit_data/AxionPhoton/NuSTAR_Sun.txt",facecolor=Astro,zorder=-3,lw=1)
PlotBound(ax,"limit_data/AxionPhoton/HESS.txt",facecolor=Astro,zorder=-0.2,lw=1)
PlotBound(ax,"limit_data/AxionPhoton/HAWC.txt",facecolor=Astro,zorder=-0.3,lw=1)
PlotBound(ax,"limit_data/AxionPhoton/MAGIC.txt",facecolor=Astro,zorder=-1,lw=1)
PlotBound(ax,"limit_data/AxionPhoton/SN1987A_gamma_ProgenitorBfield.txt",facecolor=Astro,zorder=-3,lw=1)

PlotBound(ax,"limit_data/AxionPhoton/JWST_Pinetti.txt",facecolor=AstroDM,zorder=0,lw=1,edgecolor=edgecolor,skip=3)



PlotBound(ax,"limit_data/AxionPhoton/Haloscopes_Combined_microeV-meV.txt",facecolor=ExperimentDM,zorder=0,lw=0.9)
PlotBound(ax,"limit_data/AxionPhoton/ADMX_Sidecar.txt",facecolor=ExperimentDM,edgecolor=ExperimentDM,zorder=0,lw=1,start_x=105)

# Add a few of the skinny ones not captured in the combined limit
lw = 1.5
PlotBound(ax,"limit_data/AxionPhoton/ORGAN.txt",facecolor=ExperimentDM,edgecolor='k',zorder=0,lw=0.5)
PlotBound(ax,"limit_data/AxionPhoton/ORGAN-1a.txt",facecolor=ExperimentDM,edgecolor='k',zorder=0,lw=0.5)
PlotBound(ax,"limit_data/AxionPhoton/ORGAN-1b.txt",facecolor=ExperimentDM,edgecolor='k',zorder=0,lw=0.5)
PlotBound(ax,"limit_data/AxionPhoton/QUAX.txt",facecolor=ExperimentDM,edgecolor=ExperimentDM,zorder=0,lw=lw)
PlotBound(ax,"limit_data/AxionPhoton/QUAX2.txt",facecolor=ExperimentDM,edgecolor=ExperimentDM,zorder=0,lw=lw)
PlotBound(ax,"limit_data/AxionPhoton/QUAX3.txt",facecolor=ExperimentDM,edgecolor=ExperimentDM,zorder=0,lw=lw)
PlotBound(ax,"limit_data/AxionPhoton/GrAHal.txt",facecolor=ExperimentDM,edgecolor=ExperimentDM,zorder=0,lw=lw)
PlotBound(ax,"limit_data/AxionPhoton/RADES.txt",facecolor=ExperimentDM,edgecolor=ExperimentDM,zorder=0,lw=0)
PlotBound(ax,"limit_data/AxionPhoton/RADES2.txt",facecolor=ExperimentDM,edgecolor=ExperimentDM,zorder=0,lw=0)
PlotBound(ax,"limit_data/AxionPhoton/MADMAX.txt",facecolor=ExperimentDM,edgecolor=ExperimentDM,zorder=0,lw=lw)




lw = 1.7
col = 'royalblue'
PlotBound(ax,"limit_data/AxionPhoton/Projections/MADMAX.txt",edgecolor=col,zorder=0,alpha=0.0,lw=lw,linestyle='--',start_x=1,end_x=-1,AddMinorEdges=True)
PlotBound(ax,"limit_data/AxionPhoton/Projections/ALPHA.txt",edgecolor=col,zorder=0,alpha=0.0,lw=lw,linestyle=':',start_x=1,end_x=-1,AddMinorEdges=True)
PlotBound(ax,"limit_data/AxionPhoton/Projections/ORGAN_Projected.txt",edgecolor=col,zorder=0,alpha=0.0,lw=lw,linestyle='--',start_x=1,end_x=-1,AddMinorEdges=True)
PlotBound(ax,"limit_data/AxionPhoton/Projections/BREAD.txt",edgecolor=col,zorder=-0.1,alpha=0.0,lw=lw,linestyle='--',start_x=1,end_x=-1,AddMinorEdges=True,MinorEdgeScale=3)
PlotBound(ax,"limit_data/AxionPhoton/Projections/CADEx.txt",edgecolor=col,zorder=0,alpha=0.0,lw=lw,linestyle='--',start_x=1,end_x=-1,AddMinorEdges=True,MinorEdgeScale=3)
PlotBound(ax,"limit_data/AxionPhoton/Projections/ADMX_Projected.txt",edgecolor=col,zorder=0,alpha=0.0,lw=lw,linestyle='--',start_x=1,end_x=-1,AddMinorEdges=True,MinorEdgeScale=1.3)
PlotBound(ax,"limit_data/AxionPhoton/Projections/FLASH.txt",edgecolor=col,zorder=0,alpha=0.0,lw=lw,linestyle='--',start_x=1,end_x=-1,AddMinorEdges=True,MinorEdgeScale=2)
PlotBound(ax,"limit_data/AxionPhoton/Projections/DMRadio.txt",edgecolor=col,zorder=0,alpha=0.0,lw=lw,linestyle='--',start_x=1,end_x=-1,AddMinorEdges=True)
PlotBound(ax,"limit_data/AxionPhoton/Projections/QUAX.txt",edgecolor=col,zorder=0,alpha=0.0,lw=lw,linestyle='--',start_x=1,end_x=-1,AddMinorEdges=True,MinorEdgeScale=1.5)
PlotBound(ax,"limit_data/AxionPhoton/Projections/TOORAD_eV.txt",edgecolor=col,zorder=0,alpha=0.0,lw=lw,linestyle='--',start_x=1,end_x=-1,AddMinorEdges=True,MinorEdgeScale=1.2)
PlotBound(ax,"limit_data/AxionPhoton/Projections/LAMPOST2.txt",edgecolor=col,zorder=0,alpha=0.0,lw=lw,linestyle='--',start_x=1,end_x=-1,AddMinorEdges=True,MinorEdgeScale=1.5)
PlotBound(ax,"limit_data/AxionPhoton/Projections/BRASS.txt",edgecolor=col,zorder=0,alpha=0.0,lw=lw,linestyle='--',start_x=1,end_x=-1,AddMinorEdges=True,MinorEdgeScale=1.5,scale_y=1.2)
PlotBound(ax,"limit_data/AxionPhoton/Projections/BabyIAXO_RADES.txt",edgecolor=col,zorder=0,alpha=0.0,lw=lw,linestyle='--',start_x=1,end_x=-1,AddMinorEdges=True,MinorEdgeScale=2)


PlotBound(ax,"limit_data/AxionPhoton/Projections/BabyIAXO.txt",edgecolor=ExperimentStellar,zorder=-3.1,alpha=0.0,lw=2.5,linestyle='--')
PlotBound(ax,"limit_data/AxionPhoton/Projections/ALPS-II.txt",edgecolor=ExperimentLab,zorder=0.2,alpha=0.0,lw=2,linestyle=(6, (4, 1.5,4,1)),edgealpha=1,start_x=2350,skip=5)
PlotBound(ax,"limit_data/AxionPhoton/Projections/WISPFI.txt",edgecolor=ExperimentLab,zorder=0,alpha=0.0,lw=lw,linestyle='--',start_x=1,end_x=-1,AddMinorEdges=True,MinorEdgeScale=2)


# QCD axion hadronic band
m = array([1e-13,1e1])
ga = 2e-10*m
C1 = 44/3-1.92
C2 = abs(5/3-1.92)
ax.plot(m,C1*ga,'-',color='gold',lw=2,alpha=0.1,zorder=-1000)
ax.plot(m,C2*ga,'-',color='gold',lw=2,alpha=0.1,zorder=-1000)
ax.plot(m,1.92*ga,'-',color='k',lw=2,alpha=0.3,zorder=-1000)
ax.plot(m,0.75*ga,'-',color='k',lw=2,alpha=0.3,zorder=-1000)
for i in linspace(1,7,50):
    ax.fill_between(m,C1*ga/i,C2*ga*i,alpha=0.05,color='gold',zorder=-1000,lw=0)

# Add labels
ax.text(0.5e-6,2e-10,r'{\bf CAST}',fontsize=35)
ax.text(3.3e-4,1.2e-10,r'{\bf ALPS-II}',fontsize=20,rotation=44,alpha=1,color=ExperimentLab)

ax.text(3.3e-4,1.85e-11,r'{\bf BabyIAXO}',fontsize=20,rotation=0,alpha=1,color=ExperimentStellar)

ax.text(0.28e-6,1.6e-11,r'{MWD}',fontsize=18)
ax.text(0.55e-6,0.35e-11,r'{Pulsars}',fontsize=18,rotation=0)
ax.text(2.25e-5,1.2e-10,r'{Neutron}',fontsize=18,rotation=0,color='lightgray',alpha=0.9,ha='center')
ax.text(2.25e-5,0.8e-10,r'{stars}',fontsize=18,rotation=0,color='lightgray',alpha=0.9,ha='center')

ax.text(2.5e-6,0.3e-13,'ADMX',fontsize=27,rotation=90)
ax.text(6e-6,0.8e-12,'RBF+UF',fontsize=27,rotation=90)

ax.text(5.3e-6,3e-15,'CAPP',fontsize=16,rotation=-90)
ax.text(6.7e-6,1.3e-14,'CAPP',fontsize=12,rotation=-90)
ax.text(9.35e-6,1.0e-14,'CAPP',fontsize=12,rotation=-90)
ax.text(1.37e-5,8.0e-14,'CAPP',fontsize=12,rotation=-90)
ax.text(1.42e-5,9.0e-15,'HAYSTAC',fontsize=12,rotation=90)
ax.text(1.97e-5,1.4e-14,'CAPP',fontsize=9,rotation=-90)
ax.text(1.97e-5,4.4e-14,'TASEH',fontsize=9,rotation=-90)
ax.text(1.94e-5,4.4e-13,'CAST-CAPP',fontsize=8,rotation=-90)
ax.text(1.95e-5,4e-12,'ADMX',fontsize=9,rotation=-90)
ax.text(2.4e-5,3e-14,'HAYSTAC',fontsize=12,rotation=-90)
ax.text(2.65e-5,3e-13,'GrAHal',fontsize=9,rotation=-90)
ax.text(2.98e-5,1.2e-12,'ADMX',fontsize=7,rotation=-90)
ax.text(3.5e-5,4e-13,'RADES',fontsize=9,rotation=-90)
ax.text(3.75e-5,2e-12,'QUAX',fontsize=7,rotation=-90)
ax.text(4.32e-5,2e-13,'QUAX',fontsize=12,rotation=-90)
ax.text(5.2e-5,3e-12,'ORGAN',fontsize=12,rotation=90)
ax.text(7.4e-5,4e-12,'MADMAX',fontsize=12,rotation=90,path_effects=line_background(3,'w'))
ax.text(1.1e-4,3e-12,'ORGAN',fontsize=12,rotation=-90)

ax.text(0.13,7e-12,r'JWST',fontsize=20,rotation=-90,color='k')


ax.text(2.5e-7,1.7e-17,'DMRadio',fontsize=20,rotation=27,color='royalblue')
ax.text(4.7e-7,3.4e-16,'FLASH',fontsize=20,rotation=27,color='royalblue')
ax.text(0.95e-6,0.76e-16,'BabyIAXO- \n RADES',fontsize=13,rotation=27,color='royalblue',multialignment='center')

ax.text(0.7e-5,1.6e-16,'ADMX',fontsize=20,rotation=27,color='royalblue')
ax.text(1.5e-4,1.5e-14,'ALPHA',fontsize=20,rotation=27,color='royalblue')
ax.text(0.55e-4,1.6e-14,'MADMAX',fontsize=17,rotation=27,color='royalblue')
ax.text(0.27e-4,1.9e-14,'QUAX',fontsize=15,rotation=27,color='royalblue')
ax.text(0.8e-4,7.4e-14,'ORGAN',fontsize=16,rotation=39,color='royalblue')
ax.text(2.8e-4,1.9e-13,'CADEx',fontsize=16,rotation=15,color='royalblue')
ax.text(3.8e-4,1.5e-12,'BRASS',fontsize=17,rotation=32,color='royalblue')
ax.text(2.15e-3,1.2e-13,'BREAD',fontsize=20,rotation=40,color='royalblue')
ax.text(4.0e-3,5.2e-12,'TOORAD',fontsize=17,rotation=0,color='royalblue')
ax.text(4.2e-2,5.8e-13,'LAMPOST',fontsize=17,rotation=0,color='royalblue')

ax.text(3.8e-2,3.6e-12,r'WISPFI',fontsize=17,rotation=27,color=ExperimentLab)


ax.text(8.5e-2,1.1e-10,r'{Globular}',fontsize=20,ha='center')
ax.text(8.5e-2,0.6e-10,r'{clusters}',fontsize=20,ha='center')

MySaveFig(fig,'AxionPhoton_Closeup_FIPS')

# %%
fig,ax = FigSetup(Shape='Custom',xlab='',m_min=1e-18,m_max=1e5,g_min=1e-18,g_max=1,mathpazo=False,figsize=(16,11),tickdir='in',TopAndRightTicks=True,majorticklength=15,minorticklength=11,xtick_rotation=0)
#UpperFrequencyAxis_Simple(ax,tickdir='in')
plt.gcf().text(0.04,0.85,'$\epsilon$',rotation=90,fontsize=lfs)
plt.gcf().text(0.78,0.029,'$m_{A^\prime}$ [eV]',rotation=0,fontsize=lfs)



PlotBound(ax,"limit_data/DarkPhoton/Cavendish.txt",facecolor=ExperimentLab,zorder=0.5,lw=1)
PlotBound(ax,"limit_data/DarkPhoton/TEXONO.txt",facecolor=ExperimentLab,zorder=1.3,lw=1)
PlotBound(ax,"limit_data/DarkPhoton/PlimptonLawton.txt",facecolor=ExperimentLab,zorder=0.865,lw=1)
PlotBound(ax,"limit_data/DarkPhoton/Spectroscopy.txt",facecolor=ExperimentLab,zorder=1.3,lw=1)
PlotBound(ax,"limit_data/DarkPhoton/AFM.txt",facecolor=ExperimentLab,zorder=1.3,lw=1)

PlotBound(ax,"limit_data/DarkPhoton/SPring-8.txt",facecolor=ExperimentLab,zorder=1.2,lw=1)

PlotBound(ax,"limit_data/DarkPhoton/ALPS.txt",facecolor=ExperimentLab,zorder=0.9,lw=1)
PlotBound(ax,"limit_data/DarkPhoton/LSW_UWA.txt",facecolor=ExperimentLab,zorder=0.89,lw=1)
PlotBound(ax,"limit_data/DarkPhoton/LSW_ADMX.txt",facecolor=ExperimentLab,zorder=0.88,lw=1)
PlotBound(ax,"limit_data/DarkPhoton/CROWS.txt",facecolor=ExperimentLab,zorder=0.87,lw=1)
PlotBound(ax,"limit_data/DarkPhoton/DarkSRF.txt",facecolor=ExperimentLab,zorder=0.49,lw=1)

PlotBound(ax,"limit_data/DarkPhoton/Hinode.txt",facecolor=ExperimentStellar,zorder=0.92,lw=1)
PlotBound(ax,"limit_data/DarkPhoton/CAST.txt",facecolor=ExperimentStellar,zorder=0.91,lw=1)
PlotBound(ax,"limit_data/DarkPhoton/SHIPS.txt",facecolor=ExperimentStellar,zorder=0.6,lw=1)
PlotBound(ax,"limit_data/DarkPhoton/Crab.txt",facecolor=ExperimentStellar,zorder=1.2,lw=1)
PlotBound(ax,"limit_data/DarkPhoton/XENON1T_Solar_S2.txt",facecolor=ExperimentStellar,zorder=0.0,lw=1)

PlotBound(ax,"limit_data/DarkPhoton/Solar.txt",facecolor=Astro,zorder=0.03,lw=1)
PlotBound(ax,"limit_data/DarkPhoton/GlobularClusters.txt",facecolor=Astro,zorder=0.02,lw=1)
PlotBound(ax,"limit_data/DarkPhoton/NeutronStarCooling.txt",facecolor=Astro,zorder=1.2,lw=1)

PlotBound(ax,"limit_data/DarkPhoton/DAMIC.txt",facecolor=ExperimentDM,zorder=0.1,lw=1)
PlotBound(ax,"limit_data/DarkPhoton/SENSEI.txt",facecolor=ExperimentDM,zorder=0.0,lw=1)
PlotBound(ax,"limit_data/DarkPhoton/DarkSide.txt",facecolor=ExperimentDM,zorder=-1,lw=1)
PlotBound(ax,"limit_data/DarkPhoton/XENON1T_SE.txt",facecolor=ExperimentDM,zorder=0.0,lw=1)
PlotBound(ax,"limit_data/DarkPhoton/Xenon1T_S1S2.txt",facecolor=ExperimentDM,zorder=0.0,lw=1)
PlotBound(ax,"limit_data/DarkPhoton/Xenon1T.txt",scale_x=1e3,facecolor=ExperimentDM,zorder=0.0,lw=1)
PlotBound(ax,"limit_data/DarkPhoton/XENONnT.txt",facecolor=ExperimentDM,zorder=0.0,lw=1)
PlotBound(ax,"limit_data/DarkPhoton/SuperCDMS.txt",facecolor=ExperimentDM,zorder=0.01,lw=1)

PlotBound(ax,"limit_data/DarkPhoton/JWST.txt",facecolor=ExperimentDM,zorder=0.1,lw=1)
PlotBound(ax,"limit_data/DarkPhoton/FUNK.txt",facecolor=ExperimentDM,zorder=0.4,lw=1)
PlotBound(ax,"limit_data/DarkPhoton/Tokyo-Dish.txt",facecolor=ExperimentDM,zorder=0.4,lw=1)
PlotBound(ax,"limit_data/DarkPhoton/MuDHI.txt",facecolor=ExperimentDM,zorder=0.4,lw=1)
PlotBound(ax,"limit_data/DarkPhoton/LAMPOST.txt",facecolor=ExperimentDM,zorder=0.1,lw=1)

PlotBound(ax,"limit_data/DarkPhoton/DP_Combined_DarkMatterSearches.txt",facecolor=ExperimentDM,zorder=0.0,lw=0.5)
PlotBound(ax,"limit_data/DarkPhoton/DP_Combined_AxionSearchesRescaled.txt",facecolor=ExperimentDM,zorder=0.0,lw=0.5)
#PlotBound(ax,"limit_data/DarkPhoton/SuperMAG.txt",facecolor=ExperimentDM,zorder=0.25,lw=1)
PlotBound(ax,"limit_data/DarkPhoton/SuperMAG_Combined.txt",facecolor=ExperimentDM,zorder=0.25,lw=1)
PlotBound(ax,"limit_data/DarkPhoton/SNIPE.txt",facecolor=ExperimentDM,zorder=0.25,lw=1)
PlotBound(ax,"limit_data/DarkPhoton/AMAILS.txt",facecolor=ExperimentDM,zorder=0.25,lw=1)


PlotBound(ax,"limit_data/DarkPhoton/Cosmology_Arias.txt",facecolor=AstroDM,zorder=0.0,lw=1,edgecolor=edgecolor)
PlotBound(ax,"limit_data/DarkPhoton/Cosmology_Witte_inhomogeneous.txt",facecolor=AstroDM,zorder=0.0,lw=1,edgecolor=edgecolor)
PlotBound(ax,"limit_data/DarkPhoton/Cosmology_Caputo_HeII_.txt",facecolor=AstroDM,zorder=-1,lw=1,edgecolor=edgecolor,start_x=100)
PlotBound(ax,"limit_data/DarkPhoton/INTEGRAL.txt",facecolor=AstroDM,zorder=-1,lw=1,edgecolor=edgecolor,start_x=100)
#PlotBound(ax,"limit_data/DarkPhoton/Blazars.txt",facecolor=AstroDM,zorder=1,lw=1,edgecolor=edgecolor)


PlotBound(ax,"limit_data/DarkPhoton/LeoT.txt",facecolor=AstroDM,zorder=0.1,lw=1,edgecolor=edgecolor)
PlotBound(ax,"limit_data/DarkPhoton/ISM.txt",facecolor=AstroDM,zorder=0.12,lw=1,edgecolor=edgecolor)
PlotBound(ax,"limit_data/DarkPhoton/GasClouds.txt",facecolor=AstroDM,zorder=0.11,lw=1,edgecolor=edgecolor)

PlotBound(ax,"limit_data/DarkPhoton/Planck_unWISE.txt",facecolor=Astro,zorder=0.20,lw=1)
PlotBound(ax,"limit_data/DarkPhoton/COBEFIRAS_SpectralDistortions.txt",facecolor=Astro,zorder=0.21,lw=1)
PlotBound(ax,"limit_data/DarkPhoton/Earth.txt",facecolor=Astro,zorder=1.1,lw=1)
PlotBound(ax,"limit_data/DarkPhoton/Jupiter.txt",facecolor=Astro,zorder=1,lw=1)

PlotBound(ax,"limit_data/DarkPhoton/Projections/DP_Combined_DarkMatterSearches.txt",edgecolor='royalblue',zorder=-10,alpha=0.0,lw=1.5,linestyle='--')
PlotBound(ax,"limit_data/DarkPhoton/Projections/LSW_Projections_Combined.txt",edgecolor=ExperimentLab,zorder=0.19,alpha=0.0,lw=1.5,linestyle='--')

PlotBound(ax,"limit_data/DarkPhoton/Projections/IAXO-Longitudinal.txt",edgecolor=ExperimentStellar,zorder=-1,alpha=0.0,lw=1.5,linestyle='--',start_x=1,end_x=-1,AddMinorEdges=True,MinorEdgeScale=2.5,scale_y=sqrt(2/3/0.13))


# dat2 = loadtxt("limit_data/DarkPhoton/Cosmology_Witte_inhomogeneous.txt")
# dat4 = loadtxt("limit_data/DarkPhoton/Cosmology_Caputo_HeII.txt",delimiter=',')
# dat5 = loadtxt("limit_data/DarkPhoton/Cosmology_Arias.txt")

# Fuzzy dark matter
FuzzyDM(ax,text_label=r'',alpha=0.01,facecolor='gray',zorder=0,text_shift=[1e-2,0.5e-4],rotation=0,text_col='gray',fs=40,path_effects=line_background(2,'k'))
ax.axvline(2e-20,zorder=-10,color=AstroDM,alpha=0.5)

ax.set_xticks(10.0**arange(-18,6,3),rotation=0);

ax.text(2.0e-17,0.4e-5,r'{\bf SuperMAG}',color='k',fontsize=18,rotation=-55)
ax.text(0.1e-13,0.02e-2,r'{\bf AMAILS}',fontsize=14,color='k',rotation=-49)
ax.text(0.21e-14,0.3e-5,r'{\bf SNIPE}',color='k',fontsize=13,rotation=-42)

ax.text(0.4e-15,2.2e-2,r'{Jupiter}',color='k',fontsize=16,rotation=0,alpha=0.8)
ax.text(2e-14,1e-1,r'{Earth}',color='k',fontsize=16,rotation=0,alpha=0.8)
ax.text(0.4e-11,1.5e-7,r'{\bf COBE/FIRAS}',color='k',fontsize=23,rotation=-40,alpha=0.8)
ax.text(0.4e2,0.5e-14,r'{\bf Sun}',color='k',fontsize=20,rotation=-44,alpha=0.8)
ax.text(7.5e2,0.19e-14,r'{\bf GCs}',color='k',fontsize=20,rotation=-44,alpha=0.8)
ax.text(0.4e3,0.8e-7,r'{\bf Neutron stars}',color='k',fontsize=17,rotation=-44,alpha=0.8)
ax.text(0.6e-12,2.2e-8,r'\begin{center} {Planck+} \linebreak {unWISE}\end{center}',fontsize=12,rotation=30,alpha=1)

ax.text(1.5e-12,1e-9,r'{ISM}',color='k',fontsize=20,rotation=-42,alpha=0.4)
ax.text(0.2e-12,0.7e-10,r'{LeoT}',color='k',fontsize=20,rotation=-42,alpha=0.4)
ax.text(0.05e-13,3.9e-9,r'{Gas clouds}',color='k',fontsize=18,rotation=-42,alpha=0.4)
ax.text(0.7e-13,0.5e-12,r'{\bf Cosmology}',color='k',fontsize=26,rotation=0,alpha=0.4)


ax.text(3e-7,1.0e-9,r'{\bf Dark SRF}',color='k',fontsize=13,rotation=-45)
ax.text(2e-10,0.6e-7,r'{\bf Cavendish-Coulomb}',color='k',fontsize=18,rotation=-41)
ax.text(2.1e-11,0.26e-2,r'{\bf Plimpton-Lawton}',color='k',fontsize=14,rotation=-41)
ax.text(0.2e-7,9e-6,r'{\bf CROWS}',color='k',fontsize=18,rotation=-59)
ax.text(0.8e-7,8e-6,r'{\bf LSW-ADMX}',color='k',fontsize=16,rotation=-59)
ax.text(2.3e-6,1e-5,r'{\bf LSW-UWA}',color='k',fontsize=14,rotation=-59)
ax.text(18e-6,0.8e-5,r'{\bf ALPS}',color='k',fontsize=21,rotation=-59)
ax.text(0.1e0,6e-5,r'{\bf SPring-8}',color='k',fontsize=17,rotation=0)
ax.text(0.1e1,12e-5,r'{\bf Spectroscopy}',color='k',fontsize=17,rotation=-35)
ax.text(0.1e1,1.6e-1,r'{\bf AFM}',color='k',fontsize=14,rotation=0)
ax.text(0.4e1,1.2e-5,r'{\bf TEXONO}',color='k',fontsize=14,rotation=0)


ax.text(0.6e-6,1.75e-1,r'{\bf Crab}',color='k',fontsize=15,rotation=0)
ax.text(0.5e-6,0.65e-1,r'{\bf nebula}',color='k',fontsize=15,rotation=0)
ax.text(1.6e-1,1.5e-9,r'{\bf Hinode}',color='k',fontsize=14,rotation=-41)
ax.text(0.12e-2,1.1e-7,r'{\bf CAST}',color='k',fontsize=19,rotation=-60)
ax.text(0.08e-1,2.7e-9,r'{\bf SHIPS}',color='k',fontsize=14,rotation=-36)
ax.text(0.16e-2,5.4e-12,r'{\bf XENON1T}',color='k',fontsize=18,rotation=-41)


ax.text(0.76e-1,9.5e-11,r'{JWST}',color='k',fontsize=10,rotation=0)
ax.text(4e-1,1.5e-11,r'{LAMPOST}',color='k',fontsize=10,rotation=90)
ax.text(2.6e0,0.12e-11,r'{FUNK}',color='k',fontsize=8,rotation=90)
ax.text(0.9e0,0.5e-10,r'{MuDHI}',color='k',fontsize=7,rotation=90)
ax.text(0.8e0,0.5e-14,r'{SENSEI}',color='k',fontsize=12,rotation=0)
ax.text(1.4e0,0.12e-14,r'{SuperCDMS}',color='k',fontsize=12,rotation=0)
ax.text(1.4e1,0.72e-13,r'{DAMIC}',color='k',fontsize=12,rotation=90)
ax.text(0.8e2,0.04e-14,r'{XENON}',color='k',fontsize=12,rotation=0)

ax.text(1.5e1,0.6e-16,'DarkSide',rotation=90,fontsize=12)


ax.text(2*6.3e-9,3*5e-17,r'{\bf Haloscopes}',color='royalblue',fontsize=19,rotation=-40,ha='center')
ax.text(2*6.3e-9/2.5,3*3e-17,r'{\bf (future)}',color='royalblue',fontsize=19,rotation=-40,ha='center')


ax.text(2.3e-9,1.2e-11,r'{\bf LSW (future)}',color=ExperimentLab,fontsize=17,rotation=-41,ha='center')

ax.text(1e-4,4e-14,r'{\bf Haloscopes}',color=ExperimentDM,fontsize=20,rotation=-90,path_effects=pek)

ax.text(0.04e-1,0.3e-12,'IAXO \n (longitudinal)',fontsize=15,rotation=0,color=ExperimentStellar,multialignment='center')


MySaveFig(fig,'DarkPhoton_FIPS')

# %%
from PlotFuncs import DarkPhoton


fig,ax = FigSetup(Shape='Custom',xlab='',m_min=5e-8,m_max=100,g_min=1e-18,g_max=1e-8,mathpazo=False,figsize=(16,11),tickdir='in',TopAndRightTicks=True,majorticklength=15,minorticklength=11,xtick_rotation=0)
UpperFrequencyAxis_Simple(ax,tickdir='in',tick_pad=6)
plt.gcf().text(0.04,0.85,'$\epsilon$',rotation=90,fontsize=lfs)
plt.gcf().text(0.78,0.029,'$m_{A^\prime}$ [eV]',rotation=0,fontsize=lfs)


PlotBound(ax,"limit_data/DarkPhoton/XENON1T_Solar_S2.txt",facecolor=ExperimentStellar,zorder=-1,lw=1)
PlotBound(ax,"limit_data/DarkPhoton/Solar.txt",facecolor=Astro,zorder=-0.5,lw=1)

PlotBound(ax,"limit_data/DarkPhoton/DAMIC.txt",facecolor=ExperimentDM,zorder=0.1,lw=1,scale_y=sqrt(0.3/0.45))
PlotBound(ax,"limit_data/DarkPhoton/SENSEI.txt",facecolor=ExperimentDM,zorder=0.0,lw=1,scale_y=sqrt(0.3/0.45))
PlotBound(ax,"limit_data/DarkPhoton/XENON1T_SE.txt",facecolor=ExperimentDM,zorder=0.0,lw=1,scale_y=sqrt(0.3/0.45))
PlotBound(ax,"limit_data/DarkPhoton/Xenon1T_S1S2.txt",facecolor=ExperimentDM,zorder=0.0,lw=1,scale_y=sqrt(0.3/0.45))
PlotBound(ax,"limit_data/DarkPhoton/Xenon1T.txt",scale_x=1e3,facecolor=ExperimentDM,zorder=0.0,lw=1,scale_y=sqrt(0.3/0.45))
PlotBound(ax,"limit_data/DarkPhoton/XENONnT.txt",facecolor=ExperimentDM,zorder=0.0,lw=1,scale_y=sqrt(0.3/0.45))
PlotBound(ax,"limit_data/DarkPhoton/LAMPOST.txt",facecolor=ExperimentDM,zorder=0.1,lw=1,scale_y=sqrt(0.4/0.45)*sqrt(2/3/0.27),skip=3)
PlotBound(ax,"limit_data/DarkPhoton/DarkSide.txt",facecolor=ExperimentDM,zorder=-1,lw=1,scale_y=sqrt(0.3/0.45))
PlotBound(ax,"limit_data/DarkPhoton/SuperCDMS.txt",facecolor=ExperimentDM,zorder=0.1,lw=1,scale_y=sqrt(0.3/0.45))

PlotBound(ax,"limit_data/DarkPhoton/LOFAR.txt",facecolor=ExperimentDM,zorder=0.4,lw=1,skip=6)
PlotBound(ax,"limit_data/DarkPhoton/FUNK.txt",facecolor=ExperimentDM,zorder=0.4,lw=1,scale_y=sqrt(0.3/0.45)*sqrt(2/3/0.27))
PlotBound(ax,"limit_data/DarkPhoton/Tokyo-Dish.txt",facecolor=ExperimentDM,zorder=0.4,lw=1,scale_y=sqrt(2/3/0.6))
PlotBound(ax,"limit_data/DarkPhoton/MuDHI.txt",facecolor=ExperimentDM,zorder=0.4,lw=1,skip=3)
PlotBound(ax,"limit_data/DarkPhoton/SQMS.txt",facecolor=ExperimentDM,zorder=0.0,lw=1,scale_y=sqrt(1/3/0.019))
PlotBound(ax,"limit_data/DarkPhoton/ORPHEUS.txt",facecolor=ExperimentDM,zorder=0.0,lw=1,scale_y=sqrt(1/3/0.01944939))
PlotBound(ax,"limit_data/DarkPhoton/GigaBREAD.txt",facecolor=ExperimentDM,zorder=0.0,lw=1,scale_y=sqrt(1/3/0.25))


PlotBound(ax,"limit_data/DarkPhoton/DP_Combined_DarkMatterSearches.txt",facecolor=col_alpha('royalblue',0.5),zorder=0.0,lw=0.75)
PlotBound(ax,"limit_data/DarkPhoton/WISPDMX.txt",facecolor=col_alpha('royalblue',0.5),zorder=0.0,lw=0.75,scale_y=sqrt(0.3/0.45)*sqrt(1/3/0.23))
PlotBound(ax,"limit_data/DarkPhoton/DP_Combined_AxionSearchesRescaled.txt",facecolor=col_alpha('royalblue',0.4),zorder=0.0,lw=0.75)
PlotBound(ax,"limit_data/DarkPhoton/Cosmology_Arias.txt",facecolor=AstroDM,zorder=1,lw=1,edgecolor='k')
PlotBound(ax,"limit_data/DarkPhoton/JWST.txt",facecolor=col_alpha('royalblue',0.5),zorder=0.0,lw=0.75)

col0 = 'royalblue'
PlotBound(ax,"limit_data/DarkPhoton/Projections/DMRadio.txt",edgecolor=col0,zorder=-1,alpha=0.0,lw=2,linestyle='--',start_x=1,end_x=-1,AddMinorEdges=True,MinorEdgeScale=10,scale_y=1/sqrt(1/3)*sqrt(1/3/0.0036))
PlotBound(ax,"limit_data/DarkPhoton/Projections/DarkEfield.txt",edgecolor=col0,zorder=-1,alpha=0.0,lw=2,linestyle='--',start_x=1,end_x=-1,AddMinorEdges=True,MinorEdgeScale=2.5,scale_y=sqrt(0.3/0.45))
PlotBound(ax,"limit_data/DarkPhoton/Projections/MADMAX.txt",edgecolor=col0,zorder=-1,alpha=0.0,lw=2,linestyle='--',start_x=1,end_x=-1,AddMinorEdges=True,MinorEdgeScale=2.1,scale_y=sqrt(2/3/0.13))
PlotBound(ax,"limit_data/DarkPhoton/Projections/ALPHA.txt",edgecolor=col0,zorder=-1,alpha=0.0,lw=2,linestyle='--',start_x=1,end_x=-1,AddMinorEdges=True,MinorEdgeScale=1.4,scale_y=sqrt(1/3/0.0036))
PlotBound(ax,"limit_data/DarkPhoton/Projections/BREAD.txt",edgecolor=col0,zorder=-1,alpha=0.0,lw=2,linestyle='--',start_x=1,end_x=-1,AddMinorEdges=True,MinorEdgeScale=2.5,scale_y=sqrt(2/3/0.13))
PlotBound(ax,"limit_data/DarkPhoton/Projections/SuperCDMS.txt",edgecolor=col0,zorder=-1,alpha=0.0,lw=2,linestyle='--',start_x=1,end_x=-1,AddMinorEdges=True,MinorEdgeScale=2.5,scale_y=sqrt(0.3/0.45))
PlotBound(ax,"limit_data/DarkPhoton/Projections/LAMPOST.txt",edgecolor=col0,zorder=-1,alpha=0.0,lw=2,linestyle='--',start_x=1,end_x=-1,AddMinorEdges=True,MinorEdgeScale=2.5,scale_y=sqrt(2/3/0.13))
PlotBound(ax,"limit_data/DarkPhoton/Projections/Dandelion.txt",edgecolor=col0,zorder=-1,alpha=0.0,lw=2,linestyle='--',start_x=1,end_x=-1,AddMinorEdges=True,MinorEdgeScale=2.5,scale_y=sqrt(2/3/0.13))

PlotBound(ax,"limit_data/DarkPhoton/Projections/IAXO-Longitudinal.txt",edgecolor=ExperimentStellar,zorder=-1,alpha=0.0,lw=2,linestyle='--',start_x=1,end_x=-1,AddMinorEdges=True,MinorEdgeScale=2.5,scale_y=sqrt(2/3/0.13))


#PlotBound(ax,"limit_data/DarkPhoton/Projections/LSW_Projections_Combined.txt",edgecolor=ExperimentLab,zorder=0.209,alpha=0.0,lw=2,linestyle=(6, (4, 1.5,4,1)))


#ax.set_xticks(10.0**arange(-18,6,3),rotation=0);


ax.text(0.8e-7,0.5e-16,'DMRadio',fontsize=20,color='royalblue',rotation=-33)
ax.text(0.2e-3,0.4e-12,'Dark E-field',fontsize=20,color='royalblue',rotation=45)
ax.text(0.3e-4,1.7e-14,'ALPHA',fontsize=20,color='royalblue',rotation=0)
ax.text(0.38e-4,0.065e-14,'MADMAX',fontsize=20,color='royalblue',rotation=8)
ax.text(0.36e-2,2.5e-16,'BREAD',fontsize=20,color='royalblue',rotation=18)
ax.text(1.1e0,0.18e-14,'LAMPOST',fontsize=18,color='royalblue',rotation=18)
ax.text(0.6e0,2e-17,'SuperCDMS',fontsize=20,color='royalblue',rotation=0.1)

ax.text(0.3e-3,4e-11,'Dandelion',fontsize=15,color='royalblue',rotation=0)

ax.text(2e-7,3e-10,r'{\bf Cosmology}',color='k',fontsize=30,alpha=0.4)
ax.text(0.13e-1,3e-10,r'{\bf Sun}',color='k',fontsize=28,rotation=-51,alpha=0.7)
ax.text(0.07e-1,8e-12,r'{\bf XENON1T}',color='k',fontsize=24,rotation=-33,alpha=1)

ax.text(0.85e-7,3e-13,'LOFAR',fontsize=17,rotation=90)
ax.text(4e-7,0.6e-14,'Dark \n E-field',fontsize=17,rotation=0)
ax.text(3.5e-7,23e-13,'WISPDMX',fontsize=14,rotation=0)
ax.text(2.5e-6,1e-13,'ADMX',fontsize=17,rotation=90)
ax.text(5.7e-6,0.4e-15,'SQMS, SHANHE',fontsize=13,rotation=-90)
ax.text(4.68e-6,8.85e-12,'FAST',fontsize=11,rotation=-90)
ax.text(6.65e-6,8.85e-14,'CAPP',fontsize=13,rotation=-90)
ax.text(11e-6,3.3e-14,'CAPP',fontsize=13,rotation=-90)
ax.text(13.8e-6,3.3e-13,'HAYSTAC',fontsize=8,rotation=-90)
ax.text(2.56e-5,3.3e-13,'HAYSTAC',fontsize=8,rotation=-90)
ax.text(2.4e-5,7.3e-14,'SQuAD',fontsize=8,rotation=-90)
ax.text(3.1e-5,3.3e-12,'QUALIPHIDE',fontsize=11,rotation=-90)
ax.text(5.05e-5,5.3e-11,'ORGAN',fontsize=11,rotation=90)
ax.text(6.9e-5,4.3e-14,'ORPHEUS',fontsize=11,rotation=-90)
ax.text(8.7e-5,1.3e-12,'BRASS-p\, MADMAX',fontsize=11,rotation=-90)
ax.text(1.1e-4,15.3e-11,'DOSUE-RR',fontsize=14,rotation=-90)
ax.text(4.7e-5,15.3e-13,'GigaBREAD',fontsize=11,rotation=-90)


ax.text(1e-1,1e-10,'JWST',fontsize=19,rotation=0)
ax.text(0.5e0,0.5e-10,'LAMPOST',fontsize=17,rotation=90)
ax.text(1.1e0,1.75e-9,'MuDHI',fontsize=17,rotation=-17)
ax.text(3e0,0.1e-10,'Tokyo',fontsize=17,rotation=90)
ax.text(2.25e0,2e-12,'FUNK',fontsize=17,rotation=0)

ax.text(1.2e1,2e-13,'DAMIC',fontsize=19,rotation=90)
ax.text(0.35e1,0.9e-13,'SENSEI',fontsize=17,rotation=90)
ax.text(3e1,5e-16,'SuperCDMS',fontsize=12,rotation=-62)
ax.text(0.5e1,1.35e-15,'XENON1T',fontsize=15,rotation=0)
ax.text(0.75e1,1.35e-16,'DarkSide',fontsize=15,rotation=0)

ax.text(0.1e-1,0.5e-12,'IAXO \n (longitudinal)',fontsize=20,rotation=0,color=ExperimentStellar,multialignment='center')


MySaveFig(fig,'DarkPhoton_Closeup_FIPS')
