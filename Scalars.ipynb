# %%
from numpy import *
import matplotlib.pyplot as plt
import matplotlib as mpl
from PlotFuncs import MySaveFig,FigSetup,AlternativeCouplingAxis
from PlotFuncs_ScalarVector import ScalarPhoton,NaturalnessCorner
from PlotFuncs import *

M_pl = 2.4e18 # reduced planck mass (GeV)

# Figure setup
fig,ax = FigSetup(Shape='Rectangular',xlab='Scalar mass, $m_\phi$ [eV]',ylab=r'Scalar-EM coupling, $d_e$',mathpazo=True,\
                              g_min=1e-13,g_max=1e10,m_min=1e-24,m_max=5e-6)

AlternativeCouplingAxis(ax,scale=1/(sqrt(2)*M_pl),ylabel=r"$g_{\phi\gamma}$ [GeV$^{-1}$]")
UpperFrequencyAxis_Simple(ax)

# Natural corner (STILL UNDER DEBATE HOW TO SHOW THIS)
scale_e = sqrt(1/(4*pi)*(1/(sqrt(8*pi)*1e9*M_pl)**2))
NaturalnessCorner(ax,scale_e,511e3/1e12,2.0,mass_label=2e-24,fs=18,
                  text_label=r'Natural $d_{e}$ ($\Lambda = m_e$)',
                  zorder=0.101,Shading=False,text_shift=[1,30])
NaturalnessCorner(ax,scale_e,10.0,2.0,text_label=r'Natural $d_e$ ($\Lambda > 10$ TeV)',Shading=True)
#FuzzyDM(ax)


# # Limits
ScalarPhoton.EotWashEP(ax)
ScalarPhoton.MICROSCOPE(ax)
ScalarPhoton.FifthForce(ax)
ScalarPhoton.GlobularClusters(ax)

# # Dark matter
ScalarPhoton.AURIGA(ax)
ScalarPhoton.DyDy(ax)
ScalarPhoton.RbCs(ax)
ScalarPhoton.BACON(ax)
ScalarPhoton.HQuartzSapphire(ax)
ScalarPhoton.I2(ax)
ScalarPhoton.DAMNED(ax)
ScalarPhoton.GEO600(ax)
ScalarPhoton.Holometer(ax)
ScalarPhoton.DynamicDecoupling(ax)
ScalarPhoton.CsCav(ax)
ScalarPhoton.DyQuartz(ax)
ScalarPhoton.PTB(ax)
ScalarPhoton.QSNET(ax)
ScalarPhoton.SrSi(ax)
ScalarPhoton.LIGO(ax)
    
MySaveFig(fig,'ScalarPhoton')

        
# Projections
ScalarPhoton.AION(ax)
ScalarPhoton.QSNET_Projection(ax)
ScalarPhoton.AEDGE(ax)
ScalarPhoton.MAGIS(ax)
ScalarPhoton.NuclearClock(ax)
ScalarPhoton.DUAL(ax)
ScalarPhoton.Resonators(ax)
ScalarPhoton.FOCOS(ax) # <--- Fifth force projection


MySaveFig(fig,'ScalarPhoton_with_Projections')

# %%
from numpy import *
import matplotlib.pyplot as plt
import matplotlib as mpl
from PlotFuncs import MySaveFig,FigSetup,AlternativeCouplingAxis
from PlotFuncs_ScalarVector import ScalarElectron,NaturalnessCorner
from PlotFuncs import *

M_pl = 2.4e18 # reduced planck mass (GeV)
m_e = 511.0e3/1e9 # GeV

fig,ax = FigSetup(Shape='Rectangular',xlab='Scalar mass, $m_\phi$ [eV]',ylab=r'Scalar-electron coupling, $d_{m_e}$',mathpazo=True,\
                              g_min=1e-14,g_max=1e8,m_min=1e-24,m_max=4e-6,FrequencyAxis=False,N_Hz=1)

AlternativeCouplingAxis(ax,scale=m_e/(sqrt(2)*M_pl),ylabel=r"$g_{\phi e}$")
UpperFrequencyAxis_Simple(ax)

# Limits
ScalarElectron.MICROSCOPE(ax)
ScalarElectron.EotWashEP(ax)
ScalarElectron.FifthForce(ax)
ScalarElectron.WhiteDwarfs(ax)
#FuzzyDM(ax)

# Dark matter
ScalarElectron.HSi(ax)
ScalarElectron.AURIGA(ax)
ScalarElectron.I2(ax)
ScalarElectron.DAMNED(ax)
ScalarElectron.CsCav(ax)
ScalarElectron.HQuartzSapphire(ax)
ScalarElectron.Cavities(ax)
ScalarElectron.Holometer(ax)
ScalarElectron.GEO600(ax)
ScalarElectron.RbQuartz(ax)
ScalarElectron.YbCs(ax)
ScalarElectron.LIGO(ax)
ScalarElectron.NANOGrav(ax)

# Naturalness corner (STILL UNDER DEBATE HOW TO SHOW THIS)
scale_me = (m_e*1e9)*(2*pi/(sqrt(8*pi)*sqrt(2)*M_pl*1e9))/(4*pi)
# Lambda = 10 TeV:
# NaturalnessCorner(ax,scale_me,10.0,1,mass_label=1e-22,
#                   text_label=r'Natural $d_{m_e}$ ($\Lambda = 10$ TeV)',alpha=0.05,Shading=False)
# # Lambda = m_e
# NaturalnessCorner(ax,scale_me,511e3/1e12,1,mass_label=1.1e-20,fs=18,
#                   text_label=r'Natural $d_{m_e}$ ($\Lambda = m_e$)',
#                   zorder=0.101,Shading=False,text_shift=[1,30])

NaturalnessCorner(ax,scale_me,10.0,1,mass_label=1e-22,
                  text_label=r'Natural $d_{m_e}$ ($\Lambda > 10$ TeV)',
                  alpha=0.03,Shading=True,Lambda_max_TeV=1e30)


MySaveFig(fig,'ScalarElectron')

# Projections
ScalarElectron.AEDGE(ax)
ScalarElectron.AION(ax)
ScalarElectron.MAGIS(ax)
ScalarElectron.Resonators(ax)
ScalarElectron.OpticalMW(ax)
ScalarElectron.SrOH(ax)
ScalarElectron.CavityCavity(ax)
ScalarElectron.HELIOS(ax)
#ScalarElectron.IPTA(ax,zorder=-10)
ScalarElectron.QSNET_Projection(ax)

MySaveFig(fig,'ScalarElectron_with_Projections')

# %%
# Figure setup
fig,ax = FigSetup(Shape='Rectangular',xlab='Scalar mass, $m_\phi$ [eV]',ylab=r'Scalar-EM coupling, $d_e$',mathpazo=True,\
                              g_min=1e-13,g_max=1e10,m_min=1e-24,m_max=1e1)

ScalarPhoton.EotWashEP(ax)
ScalarPhoton.MICROSCOPE(ax)


dat = flipud(loadtxt('limit_data/ScalarBaryon/FifthForce_CI.txt'))
m1 = 0.1973*1e-6/dat[:,0]
d_e1 = 500*sqrt(dat[:,1])

dat = flipud(loadtxt('limit_data/ScalarBaryon/FifthForce_Mars.txt'))
m2 = 0.1973*1e-6/dat[:,0]
d_e2 = 500*sqrt(dat[:,1])

dat = loadtxt('limit_data/ScalarNucleon/Union_InverseSquareLaw.txt')
m3 = dat[:,0]
d_e3 = 500*dat[:,1]*sqrt(1.37e37)

mvals = logspace(-24,2,1000)
dvals1 = 10**interp(log10(mvals),log10(m1),log10(d_e1))
dvals2 = 10**interp(log10(mvals),log10(m2),log10(d_e2))
dvals3 = 10**interp(log10(mvals),log10(m3),log10(d_e3))
dvals2[mvals>amax(m2)] = inf
dvals1[mvals>amax(m1)] = inf
dvals = minimum(dvals1,dvals2)
dvals = minimum(dvals,dvals3)
plt.plot(mvals,dvals,lw=4)

DAT = column_stack((mvals,dvals))
savetxt('limit_data/ScalarPhoton/FifthForce.txt',DAT,
        header='Composition-independent fifth force combined constraints \n Union of ScalarBaryon/FifthForce_CI.txt and ScalarBaryon/FifthForce_Mars.txt assuming Q_e = 1/500 \n mass [eV] \t d_e')

# %%
# Figure setup
fig,ax = FigSetup(Shape='Rectangular',xlab='Scalar mass, $m_\phi$ [eV]',ylab=r'Scalar-electron coupling, $d_{m_e}$',mathpazo=True,\
                              g_min=1e-13,g_max=1e10,m_min=1e-24,m_max=1e1)

ScalarElectron.EotWashEP(ax)
ScalarElectron.MICROSCOPE(ax)


dat = flipud(loadtxt('limit_data/ScalarBaryon/FifthForce_CI.txt'))
m1 = 0.1973*1e-6/dat[:,0]
d_me1 = 4000*sqrt(dat[:,1])

dat = flipud(loadtxt('limit_data/ScalarBaryon/FifthForce_Mars.txt'))
m2 = 0.1973*1e-6/dat[:,0]
d_me2 = 4000*sqrt(dat[:,1])

dat = loadtxt('limit_data/ScalarNucleon/Union_InverseSquareLaw.txt')
m3 = dat[:,0]
d_me3 = 4000*dat[:,1]*sqrt(1.37e37)

mvals = logspace(-24,2,1000)
dvals1 = 10**interp(log10(mvals),log10(m1),log10(d_me1))
dvals2 = 10**interp(log10(mvals),log10(m2),log10(d_me2))
dvals3 = 10**interp(log10(mvals),log10(m3),log10(d_me3))
dvals2[mvals>amax(m2)] = inf
dvals1[mvals>amax(m1)] = inf
dvals = minimum(dvals1,dvals2)
dvals = minimum(dvals,dvals3)
plt.plot(mvals,dvals,lw=4)

DAT = column_stack((mvals,dvals))
savetxt('limit_data/ScalarElectron/FifthForce.txt',DAT,
        header='Composition-independent fifth force combined constraints \n Union of ScalarBaryon/FifthForce_CI.txt and ScalarBaryon/FifthForce_Mars.txt assuming Q_me = 1/4000 \n mass [eV] \t d_e')

# %%
# Force range for lambda in [m] and m_a in [eV]
def mLambda(m_a):
    return 0.1973*1e-6/m_a 


        

fig,ax = FigSetup(Shape='Square',xlab='Scalar mass [eV]',ylab=r'$|\alpha|$',m_min=1e-19,m_max=1e-1,g_min=1e-12,g_max=1e7)
dat = loadtxt('limit_data/ScalarElectron/FifthForce.txt')
plt.fill_between(dat[:,0],(dat[:,1]/4000)**2,y2=1e20,color='gray')
plt.plot(dat[:,0],(dat[:,1]/4000)**2,'k-')

ax2 = ax.twiny()
ax2.set_xscale('log')
ax2.set_xlabel(r"Force range, $\lambda$",fontsize=40,labelpad=15)
xticks = [1.496e11,696340e3,6371e3,1e3,1,0.01,1e-6,1e-9,1e-10]
xticklabels = [r'AU',r'$R_\odot$',r'$R_\oplus$','km','m','cm',r'\textmu m','nm',r'\AA']
ax2.set_xticks(xticks)
ax2.set_xticklabels(xticklabels)
ax2.tick_params(which='major',direction='out',width=2.5,length=13,pad=7)
ax2.tick_params(which='minor',direction='out',width=1,length=10)
ax2.set_xlim([mLambda(1e-19),mLambda(1e-1)])


MySaveFig(fig,'YukawaGravity_CompositionIndependent')
