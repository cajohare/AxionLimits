# %% [markdown]
# # Some slightly more condensed plots that I uploaded to wikipedia

# %%
from numpy import *
import matplotlib.pyplot as plt
from PlotFuncs import *

fig,ax = FigSetup(Shape='Square',xlab='Axion mass [eV]',ylab='Axion-photon coupling [GeV$^{-1}$]',xtick_rotation=0,mathpazo=True,m_min=1e-11,m_max=1e1,g_max=1e-6)

AxionPhoton.QCDAxion(ax,C_center=abs(5/3-1.92)*(44/3-1.92)/2,C_width=0.7,vmax=1.1,KSVZ_on=False,DFSZ_on=False)


# colors
Astro = 'seagreen'
AstroDM = [0.7,0.7,0.7]
ExperimentDM = 'royalblue'
ExperimentLab = '#a83246'
ExperimentStellar = 'seagreen'
Collider = '#a83246'


text_on=False
col = 'gray'
AxionPhoton.ALPS(ax,projection=False,text_on=text_on,col=ExperimentLab,lw=1.5)
AxionPhoton.PVLAS(ax,text_on=text_on,col=ExperimentLab,lw=1.5)
AxionPhoton.OSQAR(ax,text_on=text_on,col=ExperimentLab,lw=1.6)
        
AxionPhoton.Helioscopes(ax,text_on=False,col=ExperimentStellar)
AxionPhoton.HaloscopesUniform(ax,text_on=False,col=ExperimentDM)
AxionPhoton.GlobularClusters(ax,text_on=False,col=Astro)

AxionPhoton.Mrk421(ax,text_on=False,col=Astro,lw=0.5)
AxionPhoton.NGC1275(ax,text_on=False,col=Astro,lw=0.5)
AxionPhoton.HESS(ax,text_on=False,col=Astro,lw=0.5)
AxionPhoton.StarClusters(ax,text_on=False,col=Astro,lw=0.5)
AxionPhoton.SN1987A_gamma(ax,text_on=False,col=Astro,lw=0.5)
AxionPhoton.Fermi(ax,text_on=False,col=Astro,lw=0.5)
AxionPhoton.FermiQuasars(ax,text_on=False,col=Astro,lw=0.5)
AxionPhoton.MWDPolarisation(ax,col=Astro,text_on=False,lw=0.5)
AxionPhoton.MWDXrays(ax,col=Astro,text_on=False,lw=0.5)
AxionPhoton.PulsarPolarCap(ax,col=Astro,text_on=False,lw=0.5)
AxionPhoton.NuSTAR_Sun(ax,col=Astro,text_on=False,lw=0.5)
AxionPhoton.HAWC(ax,col=Astro,text_on=False,lw=0.5)
AxionPhoton.MAGIC(ax,col=Astro,text_on=False,lw=0.5)
AxionPhoton.M82(ax,col=Astro,text_on=False,lw=0.5)
AxionPhoton.Planck_unWISE(ax,col=Astro,text_on=False,lw=0.5)

AxionPhoton.NeutronStars(ax,col=AstroDM,text_on=False,lw=0.5)
AxionPhoton.MUSE(ax,col=AstroDM,text_on=False,lw=0)
AxionPhoton.DESI(ax,col=AstroDM,text_on=False,lw=0)
AxionPhoton.WINERED(ax,col=AstroDM,text_on=False,lw=0)
AxionPhoton.HST(ax,col=AstroDM,text_on=False,lw=0)
AxionPhoton.JWST(ax,col=AstroDM,text_on=False,lw=0)

plt.text(0.15e0,0.9e-13,r'\begin{center}{\bf Dark matter \linebreak decay}\end{center}',fontsize=20,color=AstroDM,rotation=0,path_effects=line_background(1,'k'))
plt.text(2.7e-10,0.8e-12,r'{\bf Astrophysics}',fontsize=20,color=Astro,rotation=0,path_effects=line_background(0.5,'k'))
plt.text(2.4e-11,2e-10,r'{\bf SHAFT}',rotation=0,color='w',fontsize=20,alpha=0.8,path_effects=line_background(0.5,'k'))
plt.text(0.7e-9,4e-10,r'{\bf ABRA}',rotation=0,color='w',fontsize=20,alpha=0.8,path_effects=line_background(0.5,'k'))
plt.text(0.7e-6,0.07e-13,r'{\bf Haloscopes}',rotation=90,color=ExperimentDM,path_effects=line_background(0.5,'k'))
plt.text(0.8e0,0.7e-10,r'{\bf Stars}',fontsize=30,color='w',path_effects=line_background(1.5,'k'))
plt.text(1e-3,0.9e-10,r'{\bf CAST}',fontsize=30,color='w',path_effects=line_background(1.5,'k'))
plt.text(0.2e-8,0.7e-18,r'{\bf QCD axion}',fontsize=30,color='goldenrod',rotation=43,alpha=1,path_effects=line_background(0.75,'k'))
plt.text(1.6e-8,2e-7,r'{\bf Light-shining-through-walls}',fontsize=23,color='w',path_effects=line_background(1,'k'))


MySaveFig(fig,'AxionPhoton_Simple')

# %%
fig,ax = FigSetup(Shape='Square',xlab='Axion mass [eV]',ylab='Axion-photon coupling [GeV$^{-1}$]',xtick_rotation=0,mathpazo=True,m_min=1e-11,m_max=1e1,g_max=1e-6)

AxionPhoton.QCDAxion(ax,C_center=abs(5/3-1.92)*(44/3-1.92)/2,C_width=0.7,vmax=1.1,KSVZ_on=False,DFSZ_on=False)

text_on=False
col = '#a83246'


plt.text(0.2e-8,0.7e-18,r'{\bf QCD axion}',fontsize=30,color='goldenrod',rotation=43,alpha=1,path_effects=line_background(0.75,'k'))

MySaveFig(fig,'AxionPhoton_Simple_QCDAxionOnly')

# %%
fig,ax = FigSetup(Shape='Square',xlab='Axion mass [eV]',ylab='Axion-photon coupling [GeV$^{-1}$]',xtick_rotation=0,mathpazo=True,m_min=1e-11,m_max=1e1,g_max=1e-6)

AxionPhoton.QCDAxion(ax,C_center=abs(5/3-1.92)*(44/3-1.92)/2,C_width=0.7,vmax=1.1,KSVZ_on=False,DFSZ_on=False)

text_on=False
col = '#a83246'

AxionPhoton.GlobularClusters(ax,text_on=False,col=[0.0, 0.66, 0.42])


plt.text(0.8e0,0.7e-10,r'{\bf Stars}',fontsize=30,color='w',path_effects=line_background(1.5,'k'))
plt.text(0.2e-8,0.7e-18,r'{\bf QCD axion}',fontsize=30,color='goldenrod',rotation=43,alpha=1,path_effects=line_background(0.75,'k'))


MySaveFig(fig,'AxionPhoton_Simple_StarsOnly')

# %%
from numpy import *
import matplotlib.pyplot as plt
from PlotFuncs import *

fig,ax = FigSetup(Shape='Rectangular',xlab='Axion mass [eV]',ylab='Axion-photon coupling [GeV$^{-1}$]',lfs=38,xtick_rotation=0,mathpazo=True,m_min=1e-11,m_max=1e1,g_max=1e-6)

AxionPhoton.QCDAxion(ax,C_center=abs(5/3-1.92)*(44/3-1.92)/2,C_width=0.7,vmax=1.1,KSVZ_on=False,DFSZ_on=False)

text_on=False

# colors
Astro = 'seagreen'
AstroDM = [0.7,0.7,0.7]
ExperimentDM = 'royalblue'
ExperimentLab = '#a83246'
ExperimentStellar = 'seagreen'
Collider = '#a83246'

AxionPhoton.ALPS(ax,projection=False,text_on=text_on,col=ExperimentLab,lw=1.5)
AxionPhoton.PVLAS(ax,text_on=text_on,col=ExperimentLab,lw=1.5)
AxionPhoton.OSQAR(ax,text_on=text_on,col=ExperimentLab,lw=1.6)
        
AxionPhoton.Helioscopes(ax,text_on=False,col=ExperimentStellar)
AxionPhoton.HaloscopesUniform(ax,text_on=False,col=ExperimentDM)
AxionPhoton.GlobularClusters(ax,text_on=False,col=Astro)

AxionPhoton.Mrk421(ax,text_on=False,col=Astro,lw=0.5)
AxionPhoton.NGC1275(ax,text_on=False,col=Astro,lw=0.5)
AxionPhoton.HESS(ax,text_on=False,col=Astro,lw=0.5)
AxionPhoton.StarClusters(ax,text_on=False,col=Astro,lw=0.5)
AxionPhoton.SN1987A_gamma(ax,text_on=False,col=Astro,lw=0.5)
AxionPhoton.Fermi(ax,text_on=False,col=Astro,lw=0.5)
AxionPhoton.FermiQuasars(ax,text_on=False,col=Astro,lw=0.5)
AxionPhoton.MWDPolarisation(ax,col=Astro,text_on=False,lw=0.5)
AxionPhoton.MWDXrays(ax,col=Astro,text_on=False,lw=0.5)
AxionPhoton.PulsarPolarCap(ax,col=Astro,text_on=False,lw=0.5)
AxionPhoton.NuSTAR_Sun(ax,col=Astro,text_on=False,lw=0.5)
AxionPhoton.HAWC(ax,col=Astro,text_on=False,lw=0.5)
AxionPhoton.MAGIC(ax,col=Astro,text_on=False,lw=0.5)
AxionPhoton.M82(ax,col=Astro,text_on=False,lw=0.5)
AxionPhoton.Planck_unWISE(ax,col=Astro,text_on=False,lw=0.5)

AxionPhoton.NeutronStars(ax,col=AstroDM,text_on=False,lw=0.5)
AxionPhoton.MUSE(ax,col=AstroDM,text_on=False,lw=0)
AxionPhoton.DESI(ax,col=AstroDM,text_on=False,lw=0)
AxionPhoton.WINERED(ax,col=AstroDM,text_on=False,lw=0)
AxionPhoton.HST(ax,col=AstroDM,text_on=False,lw=0)
AxionPhoton.JWST(ax,col=AstroDM,text_on=False,lw=0)

plt.text(0.15e0,0.9e-13,r'\begin{center}{\bf Dark matter \linebreak decay}\end{center}',fontsize=20,color=AstroDM,rotation=0,path_effects=line_background(1,'k'))
plt.text(2.7e-10,0.8e-12,r'{\bf Astrophysics}',fontsize=20,color=Astro,rotation=0,path_effects=line_background(0.5,'k'))
plt.text(2.4e-11,2e-10,r'{\bf SHAFT}',rotation=0,color='w',fontsize=20,alpha=0.8,path_effects=line_background(0.5,'k'))
plt.text(0.7e-9,4e-10,r'{\bf ABRA}',rotation=0,color='w',fontsize=20,alpha=0.8,path_effects=line_background(0.5,'k'))
plt.text(0.7e-6,0.05e-13,r'{\bf Haloscopes}',rotation=90,color=ExperimentDM,path_effects=line_background(0.5,'k'))
plt.text(0.8e0,0.7e-10,r'{\bf Stars}',fontsize=30,color='w',path_effects=line_background(1.5,'k'))
plt.text(1e-3,0.9e-10,r'{\bf CAST}',fontsize=30,color='w',path_effects=line_background(1.5,'k'))
plt.text(0.2e-8,0.7e-18,r'{\bf QCD axion}',fontsize=30,color='goldenrod',rotation=31,alpha=1,path_effects=line_background(0.75,'k'))
plt.text(1.6e-8,2e-7,r'{\bf Light-shining-through-walls}',fontsize=23,color='w',path_effects=line_background(1,'k'))


MySaveFig(fig,'AxionPhoton_Simple_Wide')

# %%
from numpy import *
import matplotlib.pyplot as plt
from PlotFuncs import *

fig,ax = FigSetup(Shape='Rectangular',xlab='Axion mass [eV]',ylab='Axion-photon coupling [GeV$^{-1}$]',lfs=38,xtick_rotation=0,mathpazo=True,m_min=1e-11,m_max=1e1,g_max=1e-6)

AxionPhoton.QCDAxion(ax,C_center=abs(5/3-1.92)*(44/3-1.92)/2,C_width=0.7,vmax=1.1,KSVZ_on=False,DFSZ_on=False)

text_on=False

# colors
Astro = 'seagreen'
AstroDM = [0.7,0.7,0.7]
ExperimentDM = 'royalblue'
ExperimentLab = '#a83246'
ExperimentStellar = 'seagreen'
Collider = '#a83246'

AxionPhoton.ALPS(ax,projection=False,text_on=text_on,col=ExperimentLab,lw=1.5)
AxionPhoton.PVLAS(ax,text_on=text_on,col=ExperimentLab,lw=1.5)
AxionPhoton.OSQAR(ax,text_on=text_on,col=ExperimentLab,lw=1.6)
        
AxionPhoton.Helioscopes(ax,text_on=False,col=ExperimentStellar)
AxionPhoton.GlobularClusters(ax,text_on=False,col=Astro)

AxionPhoton.Mrk421(ax,text_on=False,col=Astro,lw=0.5)
AxionPhoton.NGC1275(ax,text_on=False,col=Astro,lw=0.5)
AxionPhoton.HESS(ax,text_on=False,col=Astro,lw=0.5)
AxionPhoton.StarClusters(ax,text_on=False,col=Astro,lw=0.5)
AxionPhoton.SN1987A_gamma(ax,text_on=False,col=Astro,lw=0.5)
AxionPhoton.Fermi(ax,text_on=False,col=Astro,lw=0.5)
AxionPhoton.FermiQuasars(ax,text_on=False,col=Astro,lw=0.5)
AxionPhoton.MWDPolarisation(ax,col=Astro,text_on=False,lw=0.5)
AxionPhoton.MWDXrays(ax,col=Astro,text_on=False,lw=0.5)
AxionPhoton.PulsarPolarCap(ax,col=Astro,text_on=False,lw=0.5)
AxionPhoton.NuSTAR_Sun(ax,col=Astro,text_on=False,lw=0.5)
AxionPhoton.HAWC(ax,col=Astro,text_on=False,lw=0.5)
AxionPhoton.MAGIC(ax,col=Astro,text_on=False,lw=0.5)
AxionPhoton.M82(ax,col=Astro,text_on=False,lw=0.5)
AxionPhoton.Planck_unWISE(ax,col=Astro,text_on=False,lw=0.5)

plt.text(2.7e-10,0.8e-12,r'{\bf Astrophysics}',fontsize=20,color=Astro,rotation=0,path_effects=line_background(0.5,'k'))
plt.text(0.8e0,0.7e-10,r'{\bf Stars}',fontsize=30,color='w',path_effects=line_background(1.5,'k'))
plt.text(1e-3,0.9e-10,r'{\bf CAST}',fontsize=30,color='w',path_effects=line_background(1.5,'k'))
plt.text(0.2e-8,0.7e-18,r'{\bf QCD axion}',fontsize=30,color='goldenrod',rotation=31,alpha=1,path_effects=line_background(0.75,'k'))
plt.text(1.6e-8,2e-7,r'{\bf Light-shining-through-walls}',fontsize=23,color='w',path_effects=line_background(1,'k'))


MySaveFig(fig,'AxionPhoton_Simple_Wide_NoDarkMatter')

# %%
fig,ax = FigSetup(Shape='Square',ylab=r'Axion-electron coupling',xlab='Axion mass [eV]',mathpazo=True,\
                  g_min=1e-15,g_max=1e-10,m_min=1e-6,m_max=1e5,xtick_rotation=0)

AxionElectron.QCDAxion(ax,Hadronic_on=False,KSVZ_on=False,text_on=False)
AxionElectron.XENONnT_Solar(ax,text_shift=[4e4,0.9],fs=30)
AxionElectron.PandaX(ax,col='darkred',text_on=False,lw=1)
AxionElectron.XENON1T(ax,col='darkred',text_on=False,lw=1)
AxionElectron.XENONnT(ax,col='darkred',text_on=False,lw=1)
AxionElectron.SuperCDMS(ax,col='darkred',text_on=False,lw=0.5)
AxionElectron.DarkSide(ax,col='darkred',text_on=False,lw=0.5)
AxionElectron.EDELWEISS(ax,col='darkred',text_on=False,lw=1)
AxionElectron.RedGiants(ax,text_pos=[0.9e-4,1.8e-13],fs=30)
AxionElectron.SolarNu(ax,text_pos=[0.1e-4,3.8e-11],fs=30)
AxionElectron.Xrays(ax)


plt.text(2e3,1e-11,r'{\bf Underground}',fontsize=30,color='w',ha='center',alpha=1,path_effects=line_background(1.5,'k'))
plt.text(2e3,0.55e-11,r'{\bf detectors}',fontsize=30,color='w',ha='center',alpha=1,path_effects=line_background(1.5,'k'))


plt.text(0.9e-2,0.4e-14,r'{\bf QCD axion}',fontsize=40,color='goldenrod',rotation=63,alpha=0.9,path_effects=line_background(1.5,'k'))

MySaveFig(fig,'AxionElectron_Simple')

# %%
fig,ax = FigSetup(Shape='Square',ylab=r'Axion-electron coupling',xlab='Axion mass [eV]',mathpazo=True,\
                  g_min=1e-15,g_max=1e-10,m_min=1e-6,m_max=1e5,xtick_rotation=0)

#AxionElectron.QCDAxion(ax,Hadronic_on=False,KSVZ_on=False,text_on=False)


g_min=1e-15
g_max=1e-10
m_min=1e-6
m_max=1e5

# Mass-coupling relation
def g_x(C_ae,m_a):
    return 8.943e-11*C_ae*m_a
cmap = 'YlOrBr'
C_center = 10.0**((log10(2.0e-5)+log10(1.0/3.0))/2)
C_width = 2
C_logwidth = 0.3
vmax = 0.9

# Plot Band
n = 200
g = logspace(log10(g_min),log10(g_max),n)
m = logspace(log10(m_min),log10(m_max),n)
QCD = zeros(shape=(n,n))
for i in range(0,n):
    QCD[:,i] = norm.pdf(log10(g)-log10(g_x(C_center,m[i])),0.0,C_width)
cols = cm.get_cmap(cmap)

cols.set_under('w') # Set lowest color to white
vmax = amax(QCD)*1.5
vmin = 0.12
plt.contourf(m, g, QCD, 50,cmap=cols,vmin=vmin,vmax=vmax,zorder=0)
plt.contourf(m, g, QCD, 50,cmap=cols,vmin=vmin,vmax=vmax,zorder=0)
plt.contourf(m, g, QCD, 50,cmap=cols,vmin=vmin,vmax=vmax,zorder=0)


plt.text(0.9e-2,0.4e-14,r'{\bf QCD axion}',fontsize=40,color='goldenrod',rotation=63,alpha=0.9,path_effects=line_background(1.5,'k'))

MySaveFig(fig,'AxionElectron_Simple_QCDAxionOnly')
# Out:
# /var/folders/c5/ms4qz_795ll784bwyy3sqj3m0000gn/T/ipykernel_56086/3374325143.py:30: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. This has been deprecated since 3.3 and in 3.6, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = mpl.cm.get_cmap("YlOrBr").copy()
#   cols.set_under('w') # Set lowest color to white

# %%
fig,ax = FigSetup(Shape='Square',ylab=r'Axion-electron coupling',xlab='Axion mass [eV]',mathpazo=True,\
                  g_min=1e-15,g_max=1e-10,m_min=1e-6,m_max=1e5,xtick_rotation=0)

#AxionElectron.QCDAxion(ax,Hadronic_on=False,KSVZ_on=False,text_on=False)


g_min=1e-15
g_max=1e-10
m_min=1e-6
m_max=1e5

# Mass-coupling relation
def g_x(C_ae,m_a):
    return 8.943e-11*C_ae*m_a
cmap = 'YlOrBr'
C_center = 10.0**((log10(2.0e-5)+log10(1.0/3.0))/2)
C_width = 2
C_logwidth = 0.3
vmax = 0.9

# Plot Band
n = 200
g = logspace(log10(g_min),log10(g_max),n)
m = logspace(log10(m_min),log10(m_max),n)
QCD = zeros(shape=(n,n))
for i in range(0,n):
    QCD[:,i] = norm.pdf(log10(g)-log10(g_x(C_center,m[i])),0.0,C_width)
cols = cm.get_cmap(cmap)

cols.set_under('w') # Set lowest color to white
vmax = amax(QCD)*1.5
vmin = 0.12
plt.contourf(m, g, QCD, 50,cmap=cols,vmin=vmin,vmax=vmax,zorder=0)
plt.contourf(m, g, QCD, 50,cmap=cols,vmin=vmin,vmax=vmax,zorder=0)
plt.contourf(m, g, QCD, 50,cmap=cols,vmin=vmin,vmax=vmax,zorder=0)

AxionElectron.RedGiants(ax,text_pos=[1e-4,1.7e-13],fs=30)


plt.text(0.9e-2,0.4e-14,r'{\bf QCD axion}',fontsize=40,color='goldenrod',rotation=63,alpha=0.9,path_effects=line_background(1.5,'k'))

MySaveFig(fig,'AxionElectron_Simple_StarsOnly')
# Out:
# /var/folders/c5/ms4qz_795ll784bwyy3sqj3m0000gn/T/ipykernel_56086/3381137933.py:30: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. This has been deprecated since 3.3 and in 3.6, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = mpl.cm.get_cmap("YlOrBr").copy()
#   cols.set_under('w') # Set lowest color to white

# %%
fig,ax = FigSetup(Shape='Square',ylab=r'Axion-electron coupling',xlab='Axion mass [eV]',mathpazo=True,\
                  g_min=1e-15,g_max=1e-10,m_min=1e-6,m_max=2e5,xtick_rotation=0)

#AxionElectron.QCDAxion(ax,Hadronic_on=False,KSVZ_on=False,text_on=False)


g_min=1e-15
g_max=1e-10
m_min=1e-6
m_max=1e5

# Mass-coupling relation
def g_x(C_ae,m_a):
    return 8.943e-11*C_ae*m_a
cmap = 'YlOrBr'
C_center = 10.0**((log10(2.0e-5)+log10(1.0/3.0))/2)
C_width = 2
C_logwidth = 0.3
vmax = 0.9

# Plot Band
n = 200
g = logspace(log10(g_min),log10(g_max),n)
m = logspace(log10(m_min),log10(m_max),n)
QCD = zeros(shape=(n,n))
for i in range(0,n):
    QCD[:,i] = norm.pdf(log10(g)-log10(g_x(C_center,m[i])),0.0,C_width)
cols = cm.get_cmap(cmap)

cols.set_under('w') # Set lowest color to white
vmax = amax(QCD)*1.5
vmin = 0.12
plt.contourf(m, g, QCD, 50,cmap=cols,vmin=vmin,vmax=vmax,zorder=0)
plt.contourf(m, g, QCD, 50,cmap=cols,vmin=vmin,vmax=vmax,zorder=0)
plt.contourf(m, g, QCD, 50,cmap=cols,vmin=vmin,vmax=vmax,zorder=0)

AxionElectron.XENONnT_Solar(ax,text_shift=[4e4,0.9],fs=30)
AxionElectron.PandaX(ax,col='darkred',text_on=False,lw=1)
AxionElectron.XENON1T(ax,col='darkred',text_on=False,lw=1)
AxionElectron.XENONnT(ax,col='darkred',text_on=False,lw=1)
AxionElectron.SuperCDMS(ax,col='darkred',text_on=False,lw=0.5)
AxionElectron.EDELWEISS(ax,col='darkred',text_on=False,lw=1)
AxionElectron.RedGiants(ax,text_pos=[0.9e-4,1.8e-13],fs=30)
AxionElectron.SolarNu(ax,text_pos=[0.1e-4,3.8e-11],fs=30)
AxionElectron.Xrays(ax)
AxionElectron.IrreducibleFreezeIn(ax)


plt.text(2e3,1e-11,r'{\bf Underground}',fontsize=30,color='w',ha='center',alpha=1,path_effects=line_background(1.5,'k'))
plt.text(2e3,0.55e-11,r'{\bf detectors}',fontsize=30,color='w',ha='center',alpha=1,path_effects=line_background(1.5,'k'))


plt.text(0.9e-2,0.4e-14,r'{\bf QCD axion}',fontsize=40,color='goldenrod',rotation=63,alpha=0.9,path_effects=line_background(1.5,'k'))

MySaveFig(fig,'AxionElectron_Simple')
# Out:
# /var/folders/c5/ms4qz_795ll784bwyy3sqj3m0000gn/T/ipykernel_56086/3092283422.py:30: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. This has been deprecated since 3.3 and in 3.6, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = mpl.cm.get_cmap("YlOrBr").copy()
#   cols.set_under('w') # Set lowest color to white
