# %% [markdown]
# # Some slightly more condensed plots that I uploaded to wikipedia

# %%
from numpy import *
import matplotlib.pyplot as plt
from PlotFuncs import *

fig,ax = FigSetup(Shape='Square',xlab='Axion mass [eV]',ylab='Axion-photon coupling [GeV$^{-1}$]',xtick_rotation=0,mathpazo=True,m_min=1e-11,m_max=1e1,g_max=1e-6)

AxionPhoton.QCDAxion(ax,C_center=abs(5/3-1.92)*(44/3-1.92)/2,C_width=0.7,vmax=1.1,KSVZ_on=False,DFSZ_on=False)

text_on=False
col = '#a83246'
AxionPhoton.ALPS(ax,projection=False,text_on=text_on,col=col,lw=1)
AxionPhoton.PVLAS(ax,text_on=text_on,col=col,lw=1)
AxionPhoton.OSQAR(ax,text_on=text_on,col=col,lw=1)
        
AxionPhoton.Helioscopes(ax,text_on=False,col='darkred')
AxionPhoton.HaloscopesUniform(ax,text_on=False,col='crimson')
AxionPhoton.HorizontalBranch(ax,text_on=False,col='darkgreen')
AxionPhoton.Mrk421(ax,text_on=False,col='SeaGreen')
AxionPhoton.NGC1275(ax,text_on=False,col='SeaGreen')
AxionPhoton.HESS(ax,text_on=False,col='SeaGreen')
AxionPhoton.StarClusters(ax,text_on=False,col='SeaGreen')
AxionPhoton.SN1987A_gamma(ax,text_on=False,col='SeaGreen')
AxionPhoton.Fermi(ax,text_on=False,col='SeaGreen')
AxionPhoton.MUSE(ax,col='seagreen',text_on=False)
AxionPhoton.VIMOS(ax,col='seagreen',text_on=False)
AxionPhoton.MWDPolarisation(ax,col='seagreen',text_on=False)
AxionPhoton.MWDXrays(ax,col='seagreen',text_on=False)

plt.text(1.3e0,1e-12,r'{\bf Telescopes}',fontsize=20,color='seagreen',rotation=90)
plt.text(0.7e-10,2.5e-12,r'{\bf Astrophysics}',fontsize=20,color='seagreen',rotation=0)
plt.text(2.4e-11,2e-10,r'{\bf SHAFT}',rotation=0,color='w',fontsize=20,alpha=0.8)
plt.text(0.7e-9,4e-10,r'{\bf ABRA}',rotation=0,color='w',fontsize=20,alpha=0.8)
plt.text(0.7e-6,1e-13,r'{\bf Haloscopes}',rotation=90,color='crimson')
plt.text(0.8e0*(1-0.03),0.9e-10*(1+0.03),r'{\bf Stars}',fontsize=30,color='k')
plt.text(0.8e0,0.9e-10,r'{\bf Stars}',fontsize=30,color='w')
plt.text(1e-3*(1-0.03),0.9e-10*(1+0.03),r'{\bf CAST}',fontsize=30,color='k')
plt.text(1e-3,0.9e-10,r'{\bf CAST}',fontsize=30,color='w')
plt.text(0.2e-8*(1-0.03),0.7e-18*(1+0.03),r'{\bf QCD axion}',fontsize=30,color='w',rotation=43,alpha=1)
plt.text(0.2e-8,0.7e-18,r'{\bf QCD axion}',fontsize=30,color='brown',rotation=43,alpha=0.9)

plt.text(1.6e-8,2e-7,r'{\bf Light-shining-through-walls}',fontsize=23,color='w')

MySaveFig(fig,'AxionPhoton_Simple')

# %%
from numpy import *
import matplotlib.pyplot as plt
from PlotFuncs import *

fig,ax = FigSetup(Shape='Rectangular',xlab='Axion mass [eV]',ylab='Axion-photon coupling [GeV$^{-1}$]',lfs=38,xtick_rotation=0,mathpazo=True,m_min=1e-11,m_max=1e1,g_max=1e-6)

AxionPhoton.QCDAxion(ax,C_center=abs(5/3-1.92)*(44/3-1.92)/2,C_width=0.7,vmax=1.1,KSVZ_on=False,DFSZ_on=False)

text_on=False
col = '#a83246'
AxionPhoton.ALPS(ax,projection=False,text_on=text_on,col=col,lw=1)
AxionPhoton.PVLAS(ax,text_on=text_on,col=col,lw=1)
AxionPhoton.OSQAR(ax,text_on=text_on,col=col,lw=1)
        
AxionPhoton.Helioscopes(ax,text_on=False,col='darkred')
AxionPhoton.HaloscopesUniform(ax,text_on=False,col='crimson')
AxionPhoton.HorizontalBranch(ax,text_on=False,col='darkgreen')
AxionPhoton.Mrk421(ax,text_on=False,col='SeaGreen')
AxionPhoton.NGC1275(ax,text_on=False,col='SeaGreen')
AxionPhoton.HESS(ax,text_on=False,col='SeaGreen')
AxionPhoton.StarClusters(ax,text_on=False,col='SeaGreen')
AxionPhoton.SN1987A_gamma(ax,text_on=False,col='SeaGreen')
AxionPhoton.Fermi(ax,text_on=False,col='SeaGreen')
AxionPhoton.MUSE(ax,col='seagreen',text_on=False)
AxionPhoton.VIMOS(ax,col='seagreen',text_on=False)
AxionPhoton.MWDPolarisation(ax,col='seagreen',text_on=False)
AxionPhoton.MWDXrays(ax,col='seagreen',text_on=False)
plt.text(1.3e0,0.5e-12,r'{\bf Telescopes}',fontsize=20,color='seagreen',rotation=90)
plt.text(0.7e-10,2e-12,r'{\bf Astrophysics}',fontsize=20,color='seagreen',rotation=0)
plt.text(2.4e-11,2e-10,r'{\bf SHAFT}',rotation=0,color='w',fontsize=20,alpha=0.8)
plt.text(0.7e-9,4e-10,r'{\bf ABRA}',rotation=0,color='w',fontsize=20,alpha=0.8)
plt.text(0.9e-6,0.3e-13,r'{\bf Haloscopes}',rotation=90,color='crimson')
plt.text(0.99e0*(1-0.03),0.9e-10*(1+0.03),r'{\bf Stars}',fontsize=30,color='k')
plt.text(0.99e0,0.9e-10,r'{\bf Stars}',fontsize=30,color='w')
plt.text(1e-3*(1-0.03),0.9e-10*(1+0.03),r'{\bf CAST}',fontsize=30,color='k')
plt.text(1e-3,0.9e-10,r'{\bf CAST}',fontsize=30,color='w')
plt.text(0.2e-8*(1-0.03),0.5e-18*(1+0.03),r'{\bf QCD axion}',fontsize=30,color='w',rotation=32,alpha=1)
plt.text(0.2e-8,0.5e-18,r'{\bf QCD axion}',fontsize=30,color='brown',rotation=32,alpha=0.9)

plt.text(1.6e-8,2e-7,r'{\bf Light-shining-through-walls}',fontsize=23,color='w')

MySaveFig(fig,'AxionPhoton_Simple_Wide')

# %%
fig,ax = FigSetup(Shape='Square',ylab=r'Axion-electron coupling',xlab='Axion mass [eV]',mathpazo=True,\
                  g_min=1e-15,g_max=1e-10,m_min=1e-6,m_max=1e5,xtick_rotation=0)

AxionElectron.QCDAxion(ax,Hadronic_on=False,KSVZ_on=False,text_on=False)
AxionElectron.LUX(ax,text_pos=[0.2e-5,7e-12])
AxionElectron.PandaX(ax,col='darkred',text_on=False,lw=1)
AxionElectron.XENON1T(ax,col='darkred',text_on=False,lw=1)
AxionElectron.SuperCDMS(ax,col='darkred',text_on=False,lw=1)
AxionElectron.EDELWEISS(ax,col='darkred',text_on=False,lw=1)
AxionElectron.RedGiants(ax,text_pos=[0.2e-5,2e-13])
AxionElectron.SolarNu(ax,text_pos=[0.2e-5,3.8e-11])
AxionElectron.Xrays(ax)


plt.text(2e3,1e-11,r'{\bf Underground}',fontsize=30,color='w',ha='center',alpha=0.7)
plt.text(2e3,0.55e-11,r'{\bf detectors}',fontsize=30,color='w',ha='center',alpha=0.7)

plt.text(0.9e-2*(1-0.03),0.4e-14*(1+0.02),r'{\bf QCD axion}',fontsize=40,color='k',rotation=63,alpha=0.9)
plt.text(0.9e-2,0.4e-14,r'{\bf QCD axion}',fontsize=40,color='goldenrod',rotation=63,alpha=0.9)

MySaveFig(fig,'AxionElectron_Simple')

# %% [markdown]
# # Yuck

# %%
from numpy import *
import matplotlib.pyplot as plt
from PlotFuncs import *

def FigSetup_xkcd(xlab=r'$m_a$ [eV]',ylab='',\
                 g_min = 1.0e-19,g_max = 1.0e-6,\
                 m_min = 1.0e-12,m_max = 1.0e7,\
                 lw=2.5,lfs=45,tfs=29,tickdir='out',\
                 Grid=False,Shape='Rectangular',\
                 mathpazo=False,TopAndRightTicks=False,\
                xtick_rotation=20.0,tick_pad=8,x_labelpad=10,y_labelpad=10,\
             FrequencyAxis=False,N_Hz=1,upper_xlabel=r"$\nu_a$ [Hz]",**freq_kwargs):

    plt.xkcd()
    
    plt.rcParams['axes.linewidth'] = lw

    if Shape=='Wide':
        fig = plt.figure(figsize=(16.5,5))
    elif Shape=='Rectangular':
        fig = plt.figure(figsize=(16.5,11))
    elif Shape=='Square':
        fig = plt.figure(figsize=(14.2,14))

    ax = fig.add_subplot(111)

    ax.set_xlabel(xlab,fontsize=lfs,labelpad=x_labelpad)
    ax.set_ylabel(ylab,fontsize=lfs,labelpad=y_labelpad)

    ax.tick_params(which='major',direction=tickdir,width=2.5,length=13,right=TopAndRightTicks,top=TopAndRightTicks,pad=tick_pad)
    ax.tick_params(which='minor',direction=tickdir,width=1,length=10,right=TopAndRightTicks,top=TopAndRightTicks)

    ax.set_yscale('log')
    ax.set_xscale('log')
    ax.set_xlim([m_min,m_max])
    ax.set_ylim([g_min,g_max])

    locmaj = mpl.ticker.LogLocator(base=10.0, subs=(1.0, ), numticks=50)
    locmin = mpl.ticker.LogLocator(base=10.0, subs=arange(2, 10)*.1,numticks=100)
    ax.xaxis.set_major_locator(locmaj)
    ax.xaxis.set_minor_locator(locmin)
    ax.xaxis.set_minor_formatter(mpl.ticker.NullFormatter())

    locmaj = mpl.ticker.LogLocator(base=10.0, subs=(1.0, ), numticks=100)
    locmin = mpl.ticker.LogLocator(base=10.0, subs=arange(2, 10)*.1,numticks=100)
    ax.yaxis.set_major_locator(locmaj)
    ax.yaxis.set_minor_locator(locmin)
    ax.yaxis.set_minor_formatter(mpl.ticker.NullFormatter())

    plt.xticks(rotation=xtick_rotation)

    if Grid:
        ax.grid(zorder=0)

    if FrequencyAxis:
        UpperFrequencyAxis(ax,N_Hz=N_Hz,tickdir='out',\
                           xtick_rotation=xtick_rotation,\
                           xlabel=upper_xlabel,\
                           lfs=lfs/1.3,tfs=tfs,tick_pad=tick_pad-2,**freq_kwargs)

    return fig,ax



fig,ax = FigSetup_xkcd(Shape='Square',xlab='Axion mass [eV]',ylab='Axion-photon coupling [GeV$^{-1}$]',xtick_rotation=0,mathpazo=True,m_min=1e-11,m_max=1e1,g_max=1e-6)


AxionPhoton.QCDAxion(ax,C_center=abs(5/3-1.92)*(44/3-1.92)/2,C_width=0.7,vmax=1.1,KSVZ_on=False,DFSZ_on=False)

text_on=False
col = '#a83246'
AxionPhoton.ALPS(ax,projection=False,text_on=text_on,col=col,lw=0)
AxionPhoton.PVLAS(ax,text_on=text_on,col=col,lw=0)
AxionPhoton.OSQAR(ax,text_on=text_on,col=col,lw=0)
        
AxionPhoton.Helioscopes(ax,text_on=False,col='darkred')
AxionPhoton.HaloscopesUniform(ax,text_on=False,col='crimson')
AxionPhoton.HorizontalBranch(ax,text_on=False,col='darkgreen')
AxionPhoton.Mrk421(ax,text_on=False,col='SeaGreen')
AxionPhoton.NGC1275(ax,text_on=False,col='SeaGreen')
AxionPhoton.HESS(ax,text_on=False,col='SeaGreen')
AxionPhoton.StarClusters(ax,text_on=False,col='SeaGreen')
AxionPhoton.SN1987A_gamma(ax,text_on=False,col='SeaGreen')
AxionPhoton.Fermi(ax,text_on=False,col='SeaGreen')
AxionPhoton.MUSE(ax,col='seagreen',text_on=False)
AxionPhoton.VIMOS(ax,col='seagreen',text_on=False)
plt.text(1.3e0,1e-12,r'Telescopes',fontsize=20,color='seagreen',rotation=90)
plt.text(0.7e-10,2.5e-12,r'Astrophysics',fontsize=20,color='seagreen',rotation=0)
plt.text(2.4e-11,2e-10,r'SHAFT',rotation=0,color='crimson',fontsize=20,alpha=0.8)
plt.text(0.7e-9,4e-10,r'ABRA',rotation=0,color='crimson',fontsize=20,alpha=0.8)
plt.text(0.7e-6,1e-13,r'Haloscopes',rotation=90,color='crimson',fontsize=25)
plt.text(0.8e0,0.9e-10,r'Stars',fontsize=25,color='forestgreen')
plt.text(1e-3,0.9e-10,r'CAST',fontsize=30,color='k')
plt.text(0.2e-8,0.7e-18,r'QCD axion',fontsize=30,color='brown',rotation=43,alpha=0.9)

plt.text(2e-8,2e-7,r'Light-shining-through-walls',fontsize=23,color='#a83246')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-5-a3605cfc5c8f> in <module>
#      63
#      64
# ---> 65 fig,ax = FigSetup_xkcd(Shape='Square',xlab='Axion mass [eV]',ylab='Axion-photon coupling [GeV$^{-1}$]',xtick_rotation=0,mathpazo=True,m_min=1e-11,m_max=1e1,g_max=1e-6)
#      66
#      67
#
# <ipython-input-5-a3605cfc5c8f> in FigSetup_xkcd(xlab, ylab, g_min, g_max, m_min, m_max, lw, lfs, tfs, tickdir, Grid, Shape, mathpazo, TopAndRightTicks, xtick_rotation, tick_pad, x_labelpad, y_labelpad, FrequencyAxis, N_Hz, upper_xlabel, **freq_kwargs)
#      12              FrequencyAxis=False,N_Hz=1,upper_xlabel=r"$\nu_a$ [Hz]",**freq_kwargs):
#      13
# ---> 14     plt.xkcd()
#      15
#      16     plt.rcParams['axes.linewidth'] = lw
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in xkcd(scale, length, randomness)
# ...
